# %%
import pandas as pd

# Begin by loading in zpids dataset
zpids_units = pd.read_csv('D:/DataSets/msc_group_project/property_keys_units.csv')
zpids_non_units = pd.read_csv('D:/DataSets/msc_group_project/property_keys_non_units.csv')

zpids_df = zpids_units + zpids_non_units

zpids_df = pd.concat([zpids_units,zpids_non_units], ignore_index=True)

#save new dataframe 

#save it
import os # package for checking/ removing file
save_path = 'D:/dataSets/msc_group_project/all_property_keys.csv'

# delete file path if it exists, this is needed as dataset keeps being modified
if os.path.exists(save_path):
    os.remove(save_path)
    
zpids_df.to_csv(save_path, index=False)

# %%
len(zpids_df)
# Out:
# 2836

# %%
response2 = retrive_property_details(90005746)

# %%
# create function that sends out a request
import requests

def retrive_property_details(zpid):

    url = "https://zillow-com1.p.rapidapi.com/property"

    querystring = {"zpid":zpid}

    headers = {
        "X-RapidAPI-Key": "0f64ef61f3msh8589bcbe6519721p1fd4adjsn7b6792b52973",
        "X-RapidAPI-Host": "zillow-com1.p.rapidapi.com"
    }

    response = requests.get(url, headers=headers, params=querystring)

    return response.json()

# %%
response = response1

# %%
response = response2
zpids_df["zpids"][i]
# Out:
# 2075342017

# %%
len(response["resoFacts"]["utilities"])
# Out:
# 1

# %%
def check_feature(check_str, res, return_statement):
    if res is not None and check_str in res:
        if isinstance(res[check_str], dict) and return_statement in res[check_str]:
            return res[check_str][return_statement]
    return None

# %%
import time
# create loop that makes a request for each property
# each of these lists represent a table that will be in our schema

new_row_main_details = []
new_row_addresses = []
new_row_features = [] # includes window features, associated amenities, utilities, lot features, parking, patio and porch
new_row_exterior_features = []
new_row_at_a_glance = []
new_row_fees = []
new_row_price_history = []
new_row_schools_nearby = []

iterations = len(zpids_df["zpids"])
for i in range(iterations):
    print("iteration : " + str(i) + ", zpid = " + str(zpids_df["zpids"][i]))
    
    url = "https://zillow-com1.p.rapidapi.com/property"

    querystring = {"zpid":zpids_df["zpids"][i]}

    headers = {
        "X-RapidAPI-Key": "0f64ef61f3msh8589bcbe6519721p1fd4adjsn7b6792b52973",
        "X-RapidAPI-Host": "zillow-com1.p.rapidapi.com"
    }

    try:
        response = requests.get(url, headers=headers, params=querystring).json()

        if response is not None:
            # a temportary main information dictionary we create just for this iteration
            temp_main_details = {}
            temp_main_details["zpid"] = response.get("zpid")
            temp_main_details["geoLocation"] = str(str(response["latitude"]) + ", " + str(response["longitude"]))
            temp_main_details["buildingName"] = check_feature("building",response,"buildingName")

            temp_main_details["postingGroupName"] = response["listingProvider"]["postingGroupName"]
            temp_main_details["agentName"] = response["listingProvider"]["agentName"]
            temp_main_details["overview"] = response["description"]
            temp_main_details["url"] = response["url"]
            temp_main_details["timeOnHME"] = response["timeOnZillow"]
            temp_main_details["price"] = response["price"]
            temp_main_details["lvingAreaValue"] = response["livingAreaValue"]       
            temp_main_details["bathrooms"] = response["resoFacts"]["bathrooms"]
            temp_main_details["bathroomsHalf"] = response["resoFacts"]["bathroomsHalf"]
            temp_main_details["bathroomsFull"] = response["resoFacts"]["bathroomsFull"]
            temp_main_details["bedrooms"] = response["resoFacts"]["bedrooms"]
            temp_main_details["livingArea"] = response["resoFacts"]["livingArea"]
            temp_main_details["livingAreaValue"] = response["livingAreaValue"]
            temp_main_details["stories"] = response["resoFacts"]["stories"]
            temp_main_details["yearBuilt"] = response["resoFacts"]["yearBuilt"]
            temp_main_details["homeType"] = response["resoFacts"]["homeType"]
            temp_main_details["homeStatus"] = response["homeStatus"]
            temp_main_details["datePosted"] = response["datePosted"]
            temp_main_details["rentEstimate"] = response["rentZestimate"]

            # a temportary addresses dictionary we create just for this iteration
            temp_addresses = {}
            temp_addresses["zpid"] = response["zpid"]
            temp_addresses["geoLocation"] = str(str(response["latitude"]) + ", " + str(response["longitude"]))
            temp_addresses["buildingName"] = check_feature("building",response,"buildingName")

            temp_addresses["city"] = response["address"].get("city")
            temp_addresses["state"] = response["address"].get("state")
            temp_addresses["streetAddress"] = response["address"].get("streetAddress")
            temp_addresses["zipcode"] = response["address"].get("zipcode")
            temp_addresses["cityRegion"] = response["resoFacts"].get("cityRegion")

            temp_addresses["stateId"] = response.get("stateId")
            temp_addresses["cityId"] = response.get("cityId")
            temp_addresses["country"] = response.get("country")
            temp_addresses["zillowBuildingUrl"] = str("https:/zillow.com/") + str(check_feature("building",response,"bdpUrl"))

            # a temporary features information dictionary we create just for this iteration
            temp_features = {}
            count = 0
            temp_features["zpid"] = response["zpid"]
            temp_features["geoLocation"] = str(str(response["latitude"]) + ", " + str(response["longitude"]))
            temp_features["buildingName"] = check_feature("building",response,"buildingName")

            if response["resoFacts"].get("appliances"):
                for i in range(len(response["resoFacts"]["appliances"])):
                    temp_features["feature " + str(count) ] = response["resoFacts"]["appliances"][i]
                    count += 1
            if response["resoFacts"].get("lotFeatures"):
                for i in range(len(response["resoFacts"]["lotFeatures"])):
                    temp_features["feature" + str(count)] = response["resoFacts"]["lotFeatures"][i]
                    count += 1
            if response["resoFacts"].get("communityFeatures"):
                for i in range(len(response["resoFacts"]["communityFeatures"])):
                    temp_features["feature" + str(count)] = response["resoFacts"]["communityFeatures"][i]
                    count += 1
            if  response["resoFacts"].get("utilities"):
                for i in range(len(response["resoFacts"]["utilities"])):
                    temp_features["feature" + str(count)] = response["resoFacts"]["utilities"][i]
                    count += 1
            if response["resoFacts"].get("windowFeatures"):
                for i in range(len(response["resoFacts"]["windowFeatures"])):
                    temp_features["feature" + str(count)] = response["resoFacts"]["windowFeatures"][i]
                    count += 1
            if response["resoFacts"].get("laundryFeatures"):
                for i in range(len(response["resoFacts"]["laundryFeatures"])):
                    temp_features["feature" + str(count)] = "Laundry Features: " + response["resoFacts"]["laundryFeatures"][i]
                    count += 1
            if response["resoFacts"].get("patioAndPorchFeatures"):
                for i in range(len(response["resoFacts"]["patioAndPorchFeatures"])):
                    temp_features["feature" + str(count)] = response["resoFacts"]["patioAndPorchFeatures"][i]
                    count += 1
            if response["resoFacts"].get("associationAmenities"):
                for i in range(len(response["resoFacts"]["associationAmenities"])):
                    temp_features["feature" + str(count)] = response["resoFacts"]["associationAmenities"][i]
                    count += 1

            # a temporary exterior features information dictionary we create just for this iteration
            temp_exterior_features = {}
            temp_exterior_features["zpid"] = response["zpid"]
            temp_exterior_features["geoLocation"] = str(str(response["latitude"]) + ", " + str(response["longitude"]))
            temp_exterior_features["buildingName"] = check_feature("building",response,"buildingName")

            if response["resoFacts"].get("exteriorFeatures"):
                for i in range(len(response["resoFacts"]["exteriorFeatures"])):
                    temp_exterior_features["exterior feature " + str(i)] = response["resoFacts"]["exteriorFeatures"][i]

            # a temporary at a glance information dictionary we create just for this iteration
            temp_atAGlance = {}
            temp_atAGlance["zpid"] = response["zpid"]
            temp_atAGlance["geoLocation"] = str(str(response["latitude"]) + ", " + str(response["longitude"]))
            temp_atAGlance["buildingName"] = check_feature("building",response,"buildingName")
            if response["resoFacts"].get("atAGlanceFacts"):
                for prop in response["resoFacts"]["atAGlanceFacts"]:
                    temp_atAGlance[str(prop["factLabel"])] = str(prop["factValue"])

            # a temporary fees information dictionary we create just for this iteration
            temp_fees = {}
            temp_fees["zpid"] = response["zpid"]
            temp_fees["geoLocation"] = str(str(response["latitude"]) + ", " + str(response["longitude"]))
            temp_fees["buildingName"] = check_feature("building",response,"buildingName")

            if response["resoFacts"].get("feesAndDues"):
                for prop in response["resoFacts"]["feesAndDues"]:
                    temp_fees[str(prop["type"] + " fee")] = prop["fee"]

            # a temporary price history information dictionary we create just for this iteration
            temp_price_history = {}
            temp_price_history["zpid"] = response["zpid"]
            temp_price_history["geoLocation"] = str(str(response["latitude"]) + ", " + str(response["longitude"]))
            temp_price_history["buildingName"] = check_feature("building",response,"buildingName")
            if response.get("priceHistory"):
                for index, prop in enumerate(response["priceHistory"]):
                    temp_price_history["change_" + str(index) + "_date"] = prop["date"]
                    temp_price_history["change_" + str(index) + "_priceChangeRate"] = prop["priceChangeRate"]
                    temp_price_history["change_" + str(index) + "_postingIsRental"] = prop["postingIsRental"]
                    temp_price_history["change_" + str(index) + "_time"] = prop["time"]
                    temp_price_history["change_" + str(index) + "_event"] = prop["event"]
                    temp_price_history["change_" + str(index) + "_price"] = prop["price"]

            # a temporary school nearby information dictionary we create just for this iteration
            temp_schools_nearby = {}
            temp_schools_nearby["zpid"] = response["zpid"]
            temp_schools_nearby["geoLocation"] = str(str(response["latitude"]) + ", " + str(response["longitude"]))
            temp_schools_nearby["buildingName"] = check_feature("building",response,"buildingName")

            if response.get("schools"):
                for index, prop in enumerate(response["schools"]):
                    temp_schools_nearby["school_" + str(index) + "_name"] = prop["name"]
                    temp_schools_nearby["school_" + str(index) + "_rating"] = prop["rating"]
                    temp_schools_nearby["school_" + str(index) + "_distance"] = prop["distance"]
                    temp_schools_nearby["school_" + str(index) + "_link"] = prop["link"]
                    temp_schools_nearby["school_" + str(index) + "_level"] = prop["level"]
                    temp_schools_nearby["school_" + str(index) + "_grades"] = prop["grades"]
                    temp_schools_nearby["school_" + str(index) + "_type"] = prop["type"]

        else:
            # Handle the case where the JSON response is not as expected
            error_message = "Invalid JSON response"

    except Exception as e:
        # Handle any exceptions that occur during the request
        print(f"An error occurred during the request: {str(e)}")
        
    new_row_main_details.append(temp_main_details)
    new_row_addresses.append(temp_addresses)
    new_row_features.append(temp_features)
    new_row_exterior_features.append(temp_exterior_features)
    new_row_at_a_glance.append(temp_atAGlance)
    new_row_fees.append(temp_fees)
    new_row_price_history.append(temp_price_history)
    new_row_schools_nearby.append(temp_schools_nearby)
    
    
        # If we have made 1 requests and it's not the last iteration, sleep for 2 seconds
    time.sleep(1)
    
main_details_df = pd.DataFrame(new_row_main_details)
address_details_df = pd.DataFrame(new_row_addresses)
indoor_features_df = pd.DataFrame(new_row_features)
exterior_features_df = pd.DataFrame(new_row_exterior_features)
at_a_glance_df = pd.DataFrame(new_row_at_a_glance)
fees_df = pd.DataFrame(new_row_fees)
price_history_df = pd.DataFrame(new_row_price_history)
schools_nearby_df = pd.DataFrame(new_row_schools_nearby)

pd.set_option('display.max_columns', None)
# Out:
# iteration : 0, zpid = 2075342017
# iteration : 1, zpid = 2075330457
# iteration : 2, zpid = 2069661399
# iteration : 3, zpid = 2068739347
# iteration : 4, zpid = 2057534299
# iteration : 5, zpid = 2075652105
# iteration : 6, zpid = 2075119575
# iteration : 7, zpid = 2067797682
# iteration : 8, zpid = 2071152602
# iteration : 9, zpid = 2075652104
# iteration : 10, zpid = 2072105027
# iteration : 11, zpid = 2062003721
# iteration : 12, zpid = 2078692687
# iteration : 13, zpid = 2078284715
# iteration : 14, zpid = 2056426687
# iteration : 15, zpid = 2057597584
# iteration : 16, zpid = 2055783116
# iteration : 17, zpid = 2079758736
# iteration : 18, zpid = 2061338347
# iteration : 19, zpid = 2078217448
# iteration : 20, zpid = 2079746270
# iteration : 21, zpid = 2058365311
# iteration : 22, zpid = 2055464704
# iteration : 23, zpid = 2078657076
# iteration : 24, zpid = 2055587413
# iteration : 25, zpid = 2055587412
# iteration : 26, zpid = 2057558335
# iteration : 27, zpid = 2057564784
# iteration : 28, zpid = 2055222389
# iteration : 29, zpid = 2056604091
# iteration : 30, zpid = 2056596911
# iteration : 31, zpid = 2056694751
# iteration : 32, zpid = 2056694744
# iteration : 33, zpid = 2056596593
# iteration : 34, zpid = 2056581602
# iteration : 35, zpid = 2056579311
# iteration : 36, zpid = 2056597961
# iteration : 37, zpid = 2056585701
# iteration : 38, zpid = 2056584431
# iteration : 39, zpid = 2057004312
# iteration : 40, zpid = 2056483383
# iteration : 41, zpid = 2056483385
# iteration : 42, zpid = 2055306551
# iteration : 43, zpid = 2057005862
# iteration : 44, zpid = 2057007743
# iteration : 45, zpid = 2057476294
# iteration : 46, zpid = 2057481936
# iteration : 47, zpid = 2057223533
# iteration : 48, zpid = 2057167350
# iteration : 49, zpid = 2056325402
# iteration : 50, zpid = 2057240485
# iteration : 51, zpid = 2057235872
# iteration : 52, zpid = 2056064711
# iteration : 53, zpid = 2057477440
# iteration : 54, zpid = 2056975229
# iteration : 55, zpid = 2057476296
# iteration : 56, zpid = 2056585702
# iteration : 57, zpid = 2055311995
# iteration : 58, zpid = 2056551106
# iteration : 59, zpid = 2057481930
# iteration : 60, zpid = 2057481941
# iteration : 61, zpid = 2056585706
# iteration : 62, zpid = 2055363499
# iteration : 63, zpid = 2055509933
# iteration : 64, zpid = 2056387566
# iteration : 65, zpid = 2057240469
# iteration : 66, zpid = 2056604084
# iteration : 67, zpid = 2056604081
# iteration : 68, zpid = 2056597241
# iteration : 69, zpid = 2057481932
# iteration : 70, zpid = 2057476301
# iteration : 71, zpid = 2057153197
# iteration : 72, zpid = 2056604087
# iteration : 73, zpid = 2056604093
# iteration : 74, zpid = 2056604089
# iteration : 75, zpid = 2056604088
# iteration : 76, zpid = 2056604096
# iteration : 77, zpid = 2056604098
# iteration : 78, zpid = 2056604101
# iteration : 79, zpid = 2056694750
# iteration : 80, zpid = 2056694749
# iteration : 81, zpid = 2056694732
# iteration : 82, zpid = 2056694730
# iteration : 83, zpid = 2056694729
# iteration : 84, zpid = 2056694757
# iteration : 85, zpid = 2076760649
# iteration : 86, zpid = 2080508973
# iteration : 87, zpid = 2056935874
# iteration : 88, zpid = 2078972993
# iteration : 89, zpid = 2065733127
# iteration : 90, zpid = 2071349184
# iteration : 91, zpid = 2072829946
# iteration : 92, zpid = 2080711373
# iteration : 93, zpid = 2080711371
# iteration : 94, zpid = 2078199550
# iteration : 95, zpid = 2080065951
# iteration : 96, zpid = 2067764552
# iteration : 97, zpid = 2077475453
# iteration : 98, zpid = 2056973831
# iteration : 99, zpid = 2056519643
# iteration : 100, zpid = 2079601724
# iteration : 101, zpid = 2080312723
# iteration : 102, zpid = 2065917981
# iteration : 103, zpid = 2079617458
# iteration : 104, zpid = 2079641272
# iteration : 105, zpid = 2078406239
# iteration : 106, zpid = 2080508979
# iteration : 107, zpid = 2066584593
# iteration : 108, zpid = 2078347504
# iteration : 109, zpid = 2074564294
# iteration : 110, zpid = 2065733151
# iteration : 111, zpid = 2079503015
# iteration : 112, zpid = 2078366396
# iteration : 113, zpid = 2056278810
# iteration : 114, zpid = 2080170973
# iteration : 115, zpid = 2070095147
# iteration : 116, zpid = 2065401952
# iteration : 117, zpid = 2078183890
# iteration : 118, zpid = 2067360392
# iteration : 119, zpid = 2073399074
# iteration : 120, zpid = 2072163924
# iteration : 121, zpid = 2078177790
# iteration : 122, zpid = 2063162903
# iteration : 123, zpid = 2076940094
# iteration : 124, zpid = 2080593563
# iteration : 125, zpid = 2079207884
# iteration : 126, zpid = 2057390452
# iteration : 127, zpid = 2067776343
# iteration : 128, zpid = 2078028581
# iteration : 129, zpid = 2080423048
# iteration : 130, zpid = 2066628753
# iteration : 131, zpid = 2072163899
# iteration : 132, zpid = 2066844381
# iteration : 133, zpid = 2055385826
# iteration : 134, zpid = 2055461302
# iteration : 135, zpid = 2055461342
# iteration : 136, zpid = 2055461341
# iteration : 137, zpid = 2055447690
# iteration : 138, zpid = 2055461332
# iteration : 139, zpid = 2055461336
# iteration : 140, zpid = 2055461355
# iteration : 141, zpid = 2055461354
# iteration : 142, zpid = 2055461344
# iteration : 143, zpid = 2055461345
# iteration : 144, zpid = 2055461323
# iteration : 145, zpid = 2055461325
# iteration : 146, zpid = 2055461331
# iteration : 147, zpid = 2055461335
# iteration : 148, zpid = 2055461326
# iteration : 149, zpid = 2055461324
# iteration : 150, zpid = 2055461327
# iteration : 151, zpid = 2055461322
# iteration : 152, zpid = 2055461346
# iteration : 153, zpid = 2055461347
# iteration : 154, zpid = 2055461330
# iteration : 155, zpid = 2055461329
# iteration : 156, zpid = 2055461328
# iteration : 157, zpid = 2055450667
# iteration : 158, zpid = 2055461339
# iteration : 159, zpid = 2055461340
# iteration : 160, zpid = 2055461333
# iteration : 161, zpid = 2055461338
# iteration : 162, zpid = 2055450668
# iteration : 163, zpid = 2055461366
# iteration : 164, zpid = 2055450097
# iteration : 165, zpid = 2055461350
# iteration : 166, zpid = 2055461348
# iteration : 167, zpid = 2055461359
# iteration : 168, zpid = 2055461358
# iteration : 169, zpid = 2055431598
# iteration : 170, zpid = 2055461321
# iteration : 171, zpid = 2055461320
# iteration : 172, zpid = 2055461361
# iteration : 173, zpid = 2055461364
# iteration : 174, zpid = 2055461362
# iteration : 175, zpid = 2055461363
# iteration : 176, zpid = 2055461357
# iteration : 177, zpid = 2055461360
# iteration : 178, zpid = 2055461349
# iteration : 179, zpid = 2055461351
# iteration : 180, zpid = 2055461352
# iteration : 181, zpid = 2055461314
# iteration : 182, zpid = 2055450670
# iteration : 183, zpid = 2055461318
# iteration : 184, zpid = 2055461311
# iteration : 185, zpid = 2055461313
# iteration : 186, zpid = 2055461315
# iteration : 187, zpid = 2055461316
# iteration : 188, zpid = 2055461304
# iteration : 189, zpid = 2055461309
# iteration : 190, zpid = 2078124109
# iteration : 191, zpid = 2096028778
# iteration : 192, zpid = 2095982916
# iteration : 193, zpid = 2096001189
# iteration : 194, zpid = 2093471045
# iteration : 195, zpid = 2089409062
# iteration : 196, zpid = 2059828309
# iteration : 197, zpid = 2059930169
# iteration : 198, zpid = 2059930171
# iteration : 199, zpid = 2059930143
# iteration : 200, zpid = 2059930146
# iteration : 201, zpid = 2059930147
# iteration : 202, zpid = 2057807590
# iteration : 203, zpid = 2057783882
# iteration : 204, zpid = 2057807581
# iteration : 205, zpid = 2059930145
# iteration : 206, zpid = 2059890096
# iteration : 207, zpid = 2059930092
# iteration : 208, zpid = 2059927371
# iteration : 209, zpid = 2059930090
# iteration : 210, zpid = 2059930134
# iteration : 211, zpid = 2059890094
# iteration : 212, zpid = 2059925679
# iteration : 213, zpid = 2059930128
# iteration : 214, zpid = 2059927380
# iteration : 215, zpid = 2059925676
# iteration : 216, zpid = 2059923633
# iteration : 217, zpid = 2059927376
# iteration : 218, zpid = 2059833710
# iteration : 219, zpid = 2059822872
# iteration : 220, zpid = 2059813706
# iteration : 221, zpid = 2059927401
# iteration : 222, zpid = 2059890095
# iteration : 223, zpid = 2059930164
# iteration : 224, zpid = 2059930130
# iteration : 225, zpid = 2059930132
# iteration : 226, zpid = 2059930131
# iteration : 227, zpid = 2059930137
# iteration : 228, zpid = 2059930139
# iteration : 229, zpid = 2059930135
# iteration : 230, zpid = 2059927399
# iteration : 231, zpid = 2059930156
# iteration : 232, zpid = 2059930157
# iteration : 233, zpid = 2059930154
# iteration : 234, zpid = 2059930152
# iteration : 235, zpid = 2059930153
# iteration : 236, zpid = 2059930148
# iteration : 237, zpid = 2059930151
# iteration : 238, zpid = 2059925680
# iteration : 239, zpid = 2059930142
# iteration : 240, zpid = 2059930144
# iteration : 241, zpid = 2059930161
# iteration : 242, zpid = 2059930163
# iteration : 243, zpid = 2059930110
# iteration : 244, zpid = 2059930114
# iteration : 245, zpid = 2059930176
# iteration : 246, zpid = 2055658242
# iteration : 247, zpid = 2059930120
# iteration : 248, zpid = 2057807563
# iteration : 249, zpid = 2057807580
# iteration : 250, zpid = 2059930172
# iteration : 251, zpid = 2057807562
# iteration : 252, zpid = 2057807589
# iteration : 253, zpid = 2059930105
# iteration : 254, zpid = 2059930106
# iteration : 255, zpid = 2059930121
# iteration : 256, zpid = 2059930170
# iteration : 257, zpid = 2059930160
# iteration : 258, zpid = 2057912892
# iteration : 259, zpid = 2059930162
# iteration : 260, zpid = 2059930159
# iteration : 261, zpid = 2057807571
# iteration : 262, zpid = 2084886858
# iteration : 263, zpid = 2089864371
# iteration : 264, zpid = 2089864376
# iteration : 265, zpid = 2089864352
# iteration : 266, zpid = 2089864373
# iteration : 267, zpid = 2089864333
# iteration : 268, zpid = 2088290445
# iteration : 269, zpid = 2089864327
# iteration : 270, zpid = 2089864310
# iteration : 271, zpid = 2089864354
# iteration : 272, zpid = 2086572667
# iteration : 273, zpid = 2086804380
# iteration : 274, zpid = 2089864276
# iteration : 275, zpid = 2078549505
# iteration : 276, zpid = 2081228638
# iteration : 277, zpid = 2089864281
# iteration : 278, zpid = 2084323042
# iteration : 279, zpid = 2089864267
# iteration : 280, zpid = 2089864265
# iteration : 281, zpid = 2089202430
# iteration : 282, zpid = 2091587233
# iteration : 283, zpid = 2087816753
# iteration : 284, zpid = 2089643451
# iteration : 285, zpid = 2089511267
# iteration : 286, zpid = 2089713960
# iteration : 287, zpid = 2094228300
# iteration : 288, zpid = 2094231440
# iteration : 289, zpid = 2078459072
# iteration : 290, zpid = 2094231167
# iteration : 291, zpid = 2090498289
# iteration : 292, zpid = 2094231533
# iteration : 293, zpid = 2094231449
# iteration : 294, zpid = 2089174303
# iteration : 295, zpid = 2093592217
# iteration : 296, zpid = 2087530439
# iteration : 297, zpid = 2094231307
# iteration : 298, zpid = 2094231319
# iteration : 299, zpid = 2094231499
# iteration : 300, zpid = 2094187005
# iteration : 301, zpid = 2086920605
# iteration : 302, zpid = 2093107996
# iteration : 303, zpid = 2091512911
# iteration : 304, zpid = 2093683997
# iteration : 305, zpid = 2093907130
# iteration : 306, zpid = 2089127301
# iteration : 307, zpid = 2092165901
# iteration : 308, zpid = 2092182336
# iteration : 309, zpid = 2058854883
# iteration : 310, zpid = 2080468688
# iteration : 311, zpid = 2065691296
# iteration : 312, zpid = 2070272699
# iteration : 313, zpid = 2068701355
# iteration : 314, zpid = 2078445075
# iteration : 315, zpid = 2055767445
# iteration : 316, zpid = 2055282471
# iteration : 317, zpid = 2067439559
# iteration : 318, zpid = 2079321636
# iteration : 319, zpid = 2078559671
# iteration : 320, zpid = 2055557080
# iteration : 321, zpid = 2079966641
# iteration : 322, zpid = 2067560027
# iteration : 323, zpid = 2069801154
# iteration : 324, zpid = 2079300186
# iteration : 325, zpid = 2077216125
# iteration : 326, zpid = 2075154613
# iteration : 327, zpid = 2057530620
# iteration : 328, zpid = 2057934954
# iteration : 329, zpid = 2062911307
# iteration : 330, zpid = 2058489462
# iteration : 331, zpid = 2056169809
# iteration : 332, zpid = 2068510769
# iteration : 333, zpid = 2080711838
# iteration : 334, zpid = 2071908718
# iteration : 335, zpid = 2067255914
# iteration : 336, zpid = 2069291185
# iteration : 337, zpid = 2055334770
# iteration : 338, zpid = 2079244209
# iteration : 339, zpid = 2069234785
# iteration : 340, zpid = 2068470421
# iteration : 341, zpid = 2080711840
# iteration : 342, zpid = 2055767446
# iteration : 343, zpid = 2077257590
# iteration : 344, zpid = 2078426313
# iteration : 345, zpid = 2077837957
# iteration : 346, zpid = 2069616727
# iteration : 347, zpid = 2069972233
# iteration : 348, zpid = 2056401213
# iteration : 349, zpid = 2073670297
# iteration : 350, zpid = 2056465546
# iteration : 351, zpid = 2057590923
# iteration : 352, zpid = 2055938496
# iteration : 353, zpid = 2080334635
# iteration : 354, zpid = 2055429998
# iteration : 355, zpid = 2068729332
# iteration : 356, zpid = 2080711806
# iteration : 357, zpid = 2057590924
# iteration : 358, zpid = 2072533529
# iteration : 359, zpid = 2057590933
# iteration : 360, zpid = 2057530623
# iteration : 361, zpid = 2067313543
# iteration : 362, zpid = 2057193480
# iteration : 363, zpid = 2070836437
# iteration : 364, zpid = 2067005029
# iteration : 365, zpid = 2055334771
# iteration : 366, zpid = 2063483623
# iteration : 367, zpid = 2076978943
# iteration : 368, zpid = 2069801153
# iteration : 369, zpid = 2062728135
# iteration : 370, zpid = 2072282556
# iteration : 371, zpid = 2077615442
# iteration : 372, zpid = 2066847248
# iteration : 373, zpid = 2061483443
# iteration : 374, zpid = 2061922347
# iteration : 375, zpid = 2080711829
# iteration : 376, zpid = 2077737879
# iteration : 377, zpid = 2078263035
# iteration : 378, zpid = 2077685999
# iteration : 379, zpid = 2065774662
# iteration : 380, zpid = 2055811005
# iteration : 381, zpid = 2080402996
# iteration : 382, zpid = 2057530622
# iteration : 383, zpid = 2062925378
# iteration : 384, zpid = 2065417711
# iteration : 385, zpid = 2056528947
# iteration : 386, zpid = 2078373459
# iteration : 387, zpid = 2067370608
# iteration : 388, zpid = 2065129517
# iteration : 389, zpid = 2070461903
# iteration : 390, zpid = 2056154456
# iteration : 391, zpid = 2076766600
# iteration : 392, zpid = 2073962522
# iteration : 393, zpid = 2075684249
# iteration : 394, zpid = 2070167872
# iteration : 395, zpid = 2056154455
# iteration : 396, zpid = 2061709157
# iteration : 397, zpid = 2065511049
# iteration : 398, zpid = 2071189018
# iteration : 399, zpid = 2060935997
# iteration : 400, zpid = 2056401313
# iteration : 401, zpid = 2077853683
# iteration : 402, zpid = 2058830252
# iteration : 403, zpid = 2056985785
# iteration : 404, zpid = 2057622965
# iteration : 405, zpid = 2055688236
# iteration : 406, zpid = 2055999680
# iteration : 407, zpid = 2055203722
# iteration : 408, zpid = 2056039799
# iteration : 409, zpid = 2055203723
# iteration : 410, zpid = 2055250815
# iteration : 411, zpid = 2096340086
# iteration : 412, zpid = 2055544908
# iteration : 413, zpid = 2055882259
# iteration : 414, zpid = 2056582909
# iteration : 415, zpid = 2055904531
# iteration : 416, zpid = 2058110903
# iteration : 417, zpid = 2055882260
# iteration : 418, zpid = 2057281822
# iteration : 419, zpid = 2057281830
# iteration : 420, zpid = 2057281756
# iteration : 421, zpid = 2057281805
# iteration : 422, zpid = 2057281794
# iteration : 423, zpid = 2057281835
# iteration : 424, zpid = 2057281834
# iteration : 425, zpid = 2057281824
# iteration : 426, zpid = 2057099844
# iteration : 427, zpid = 2057032311
# iteration : 428, zpid = 2057149810
# iteration : 429, zpid = 2057007850
# iteration : 430, zpid = 2057281818
# iteration : 431, zpid = 2057281724
# iteration : 432, zpid = 2057281839
# iteration : 433, zpid = 2057281838
# iteration : 434, zpid = 2057281743
# iteration : 435, zpid = 2057281754
# iteration : 436, zpid = 2056032334
# iteration : 437, zpid = 2055716589
# iteration : 438, zpid = 2055280592
# iteration : 439, zpid = 2055274216
# iteration : 440, zpid = 2055216519
# iteration : 441, zpid = 2055205342
# iteration : 442, zpid = 2055205335
# iteration : 443, zpid = 2057281780
# iteration : 444, zpid = 2057281776
# iteration : 445, zpid = 2057281773
# iteration : 446, zpid = 2057281702
# iteration : 447, zpid = 2057281701
# iteration : 448, zpid = 2057281753
# iteration : 449, zpid = 2057281766
# iteration : 450, zpid = 2057281764
# iteration : 451, zpid = 2057281717
# iteration : 452, zpid = 2057281711
# iteration : 453, zpid = 2057281820
# iteration : 454, zpid = 2057281817
# iteration : 455, zpid = 2057281812
# iteration : 456, zpid = 2055959813
# iteration : 457, zpid = 2057281807
# iteration : 458, zpid = 2057281802
# iteration : 459, zpid = 2057281793
# iteration : 460, zpid = 2055919522
# iteration : 461, zpid = 2057281837
# iteration : 462, zpid = 2057281836
# iteration : 463, zpid = 2057281832
# iteration : 464, zpid = 2057281831
# iteration : 465, zpid = 2057281828
# iteration : 466, zpid = 2057281827
# iteration : 467, zpid = 2057025872
# iteration : 468, zpid = 2057281746
# iteration : 469, zpid = 2057281736
# iteration : 470, zpid = 2055826280
# iteration : 471, zpid = 2057281789
# iteration : 472, zpid = 2056247146
# iteration : 473, zpid = 2057092979
# iteration : 474, zpid = 2055999715
# iteration : 475, zpid = 2057281772
# iteration : 476, zpid = 2055821446
# iteration : 477, zpid = 2055824351
# iteration : 478, zpid = 2057281722
# iteration : 479, zpid = 2057281823
# iteration : 480, zpid = 2057281829
# iteration : 481, zpid = 2057281825
# iteration : 482, zpid = 2057281816
# iteration : 483, zpid = 2057281804
# iteration : 484, zpid = 2057281784
# iteration : 485, zpid = 2057281720
# iteration : 486, zpid = 2057281778
# iteration : 487, zpid = 2057281710
# iteration : 488, zpid = 2057281763
# iteration : 489, zpid = 2057281728
# iteration : 490, zpid = 2057281771
# iteration : 491, zpid = 2057281712
# iteration : 492, zpid = 2057281708
# iteration : 493, zpid = 2057281704
# iteration : 494, zpid = 2057281699
# iteration : 495, zpid = 2057281706
# iteration : 496, zpid = 2057281700
# iteration : 497, zpid = 2057281740
# iteration : 498, zpid = 2057281732
# iteration : 499, zpid = 2057281721
# iteration : 500, zpid = 2057281811
# iteration : 501, zpid = 2057281819
# iteration : 502, zpid = 2057281813
# iteration : 503, zpid = 2057281745
# iteration : 504, zpid = 2057281752
# iteration : 505, zpid = 2057281758
# iteration : 506, zpid = 2057281769
# iteration : 507, zpid = 2057281810
# iteration : 508, zpid = 2057281788
# iteration : 509, zpid = 2057281791
# iteration : 510, zpid = 2057281774
# iteration : 511, zpid = 2057281768
# iteration : 512, zpid = 2057281715
# iteration : 513, zpid = 2057281781
# iteration : 514, zpid = 2087418056
# iteration : 515, zpid = 2071537136
# iteration : 516, zpid = 2069671958
# iteration : 517, zpid = 2087418058
# iteration : 518, zpid = 2067903468
# iteration : 519, zpid = 2069987343
# iteration : 520, zpid = 2056478314
# iteration : 521, zpid = 2071935717
# iteration : 522, zpid = 2069341995
# iteration : 523, zpid = 2065662320
# iteration : 524, zpid = 2067696478
# iteration : 525, zpid = 2067696479
# iteration : 526, zpid = 2057470817
# iteration : 527, zpid = 2067719262
# iteration : 528, zpid = 2062751947
# iteration : 529, zpid = 2069771348
# iteration : 530, zpid = 2056521604
# iteration : 531, zpid = 2068714536
# iteration : 532, zpid = 2055314732
# iteration : 533, zpid = 2063395650
# iteration : 534, zpid = 2066394899
# iteration : 535, zpid = 2057743658
# iteration : 536, zpid = 2057128085
# iteration : 537, zpid = 2077778546
# iteration : 538, zpid = 2055213405
# iteration : 539, zpid = 2078914281
# iteration : 540, zpid = 2078478249
# iteration : 541, zpid = 2079150497
# iteration : 542, zpid = 2079626945
# iteration : 543, zpid = 2055670023
# iteration : 544, zpid = 2079758581
# iteration : 545, zpid = 2057471220
# iteration : 546, zpid = 2078914281
# iteration : 547, zpid = 2078478249
# iteration : 548, zpid = 2055251238
# iteration : 549, zpid = 2055927394
# iteration : 550, zpid = 2056372755
# iteration : 551, zpid = 2057181222
# iteration : 552, zpid = 2060323107
# iteration : 553, zpid = 2056138590
# iteration : 554, zpid = 2055607199
# iteration : 555, zpid = 2058063177
# iteration : 556, zpid = 2055899125
# iteration : 557, zpid = 2060834349
# iteration : 558, zpid = 2079031579
# iteration : 559, zpid = 2060617129
# iteration : 560, zpid = 2075427440
# iteration : 561, zpid = 2078485478
# iteration : 562, zpid = 2084824617
# iteration : 563, zpid = 2080809159
# iteration : 564, zpid = 2078485465
# iteration : 565, zpid = 2080840064
# iteration : 566, zpid = 2056600250
# iteration : 567, zpid = 2068521878
# iteration : 568, zpid = 2061306028
# iteration : 569, zpid = 2061419174
# iteration : 570, zpid = 2055811687
# iteration : 571, zpid = 2055811686
# iteration : 572, zpid = 2063003809
# iteration : 573, zpid = 2055811690
# iteration : 574, zpid = 2091210570
# iteration : 575, zpid = 2084151088
# iteration : 576, zpid = 2091210591
# iteration : 577, zpid = 2077077800
# iteration : 578, zpid = 2091210544
# iteration : 579, zpid = 2091210540
# iteration : 580, zpid = 2078919144
# iteration : 581, zpid = 2082209676
# iteration : 582, zpid = 2083801177
# iteration : 583, zpid = 2075162146
# iteration : 584, zpid = 2090917123
# iteration : 585, zpid = 2083801180
# iteration : 586, zpid = 2072586253
# iteration : 587, zpid = 2071973322
# iteration : 588, zpid = 2078587073
# iteration : 589, zpid = 2068428122
# iteration : 590, zpid = 2071615803
# iteration : 591, zpid = 2076937634
# iteration : 592, zpid = 2077394435
# iteration : 593, zpid = 2070338446
# iteration : 594, zpid = 2071538104
# iteration : 595, zpid = 2093217519
# iteration : 596, zpid = 2078678419
# iteration : 597, zpid = 2077036480
# iteration : 598, zpid = 2093705843
# iteration : 599, zpid = 2080468181
# iteration : 600, zpid = 2063083561
# iteration : 601, zpid = 2077685774
# iteration : 602, zpid = 2078540648
# iteration : 603, zpid = 2085178119
# iteration : 604, zpid = 2060251924
# iteration : 605, zpid = 2080374513
# iteration : 606, zpid = 2061274786
# iteration : 607, zpid = 2079588257
# iteration : 608, zpid = 2077215778
# iteration : 609, zpid = 2089953286
# iteration : 610, zpid = 2078098136
# iteration : 611, zpid = 2080144053
# iteration : 612, zpid = 2080032848
# iteration : 613, zpid = 2080515631
# iteration : 614, zpid = 2081147998
# iteration : 615, zpid = 2080588564
# iteration : 616, zpid = 2080802085
# iteration : 617, zpid = 2079570280
# iteration : 618, zpid = 2080020437
# iteration : 619, zpid = 2063132852
# iteration : 620, zpid = 2085178129
# iteration : 621, zpid = 2076819641
# iteration : 622, zpid = 2080449397
# iteration : 623, zpid = 2081841438
# iteration : 624, zpid = 2063132849
# iteration : 625, zpid = 2063132850
# iteration : 626, zpid = 2077651647
# iteration : 627, zpid = 2078262836
# iteration : 628, zpid = 2079293279
# iteration : 629, zpid = 2094076876
# iteration : 630, zpid = 2080219084
# iteration : 631, zpid = 2080563618
# iteration : 632, zpid = 2057530576
# iteration : 633, zpid = 2081964197
# iteration : 634, zpid = 2056020467
# iteration : 635, zpid = 2078848489
# iteration : 636, zpid = 2079979268
# iteration : 637, zpid = 2080208395
# iteration : 638, zpid = 2078910191
# iteration : 639, zpid = 2083721141
# iteration : 640, zpid = 2056154273
# iteration : 641, zpid = 2085178111
# iteration : 642, zpid = 2085178124
# iteration : 643, zpid = 2062940372
# iteration : 644, zpid = 2085178121
# iteration : 645, zpid = 2093588607
# iteration : 646, zpid = 2077417270
# iteration : 647, zpid = 2056521572
# iteration : 648, zpid = 2077691358
# iteration : 649, zpid = 2078869762
# iteration : 650, zpid = 2078269362
# iteration : 651, zpid = 2077106551
# iteration : 652, zpid = 2078567775
# iteration : 653, zpid = 2077916259
# iteration : 654, zpid = 2069123515
# iteration : 655, zpid = 2079456063
# iteration : 656, zpid = 2067678596
# iteration : 657, zpid = 2063289914
# iteration : 658, zpid = 2068930905
# iteration : 659, zpid = 2080472311
# iteration : 660, zpid = 2078383043
# iteration : 661, zpid = 2089411748
# iteration : 662, zpid = 2077824153
# iteration : 663, zpid = 2093450345
# iteration : 664, zpid = 2092202495
# iteration : 665, zpid = 2061701755
# iteration : 666, zpid = 2084839489
# iteration : 667, zpid = 2090374490
# iteration : 668, zpid = 2090893600
# iteration : 669, zpid = 2091216438
# iteration : 670, zpid = 2055506835
# iteration : 671, zpid = 2090540730
# iteration : 672, zpid = 2092909818
# iteration : 673, zpid = 2087057082
# iteration : 674, zpid = 2093450283
# iteration : 675, zpid = 2081044531
# iteration : 676, zpid = 2057743657
# iteration : 677, zpid = 2098796892
# iteration : 678, zpid = 2056310017
# iteration : 679, zpid = 2058002797
# iteration : 680, zpid = 2065451746
# iteration : 681, zpid = 2062332384
# iteration : 682, zpid = 2055541079
# iteration : 683, zpid = 2075659118
# iteration : 684, zpid = 2055447765
# iteration : 685, zpid = 2077900072
# iteration : 686, zpid = 2063502250
# iteration : 687, zpid = 2066857722
# iteration : 688, zpid = 2079746650
# iteration : 689, zpid = 2072998946
# iteration : 690, zpid = 2080145966
# iteration : 691, zpid = 2080694224
# iteration : 692, zpid = 2059996501
# iteration : 693, zpid = 2077158275
# iteration : 694, zpid = 2057648984
# iteration : 695, zpid = 2065698313
# iteration : 696, zpid = 2080243380
# iteration : 697, zpid = 2073007718
# iteration : 698, zpid = 2071672507
# iteration : 699, zpid = 2066818089
# iteration : 700, zpid = 2067725446
# iteration : 701, zpid = 2078508875
# iteration : 702, zpid = 2087184479
# iteration : 703, zpid = 2066976914
# iteration : 704, zpid = 2061991499
# iteration : 705, zpid = 2078898616
# iteration : 706, zpid = 2080552072
# iteration : 707, zpid = 2055745827
# iteration : 708, zpid = 2057079585
# iteration : 709, zpid = 2066963462
# iteration : 710, zpid = 2055893857
# iteration : 711, zpid = 2057550673
# iteration : 712, zpid = 2061865597
# iteration : 713, zpid = 2065798859
# iteration : 714, zpid = 2065798864
# iteration : 715, zpid = 2066963481
# iteration : 716, zpid = 2079760556
# iteration : 717, zpid = 2066382168
# iteration : 718, zpid = 2079760591
# iteration : 719, zpid = 2068622578
# iteration : 720, zpid = 2063383716
# iteration : 721, zpid = 2072068928
# iteration : 722, zpid = 2071737831
# iteration : 723, zpid = 2069673601
# iteration : 724, zpid = 2062831265
# iteration : 725, zpid = 2067663716
# iteration : 726, zpid = 2056930246
# iteration : 727, zpid = 2070354029
# iteration : 728, zpid = 2079760588
# iteration : 729, zpid = 2056072972
# iteration : 730, zpid = 2079760573
# iteration : 731, zpid = 2067192153
# iteration : 732, zpid = 2072068922
# iteration : 733, zpid = 2079760585
# iteration : 734, zpid = 2079760562
# iteration : 735, zpid = 2072068914
# iteration : 736, zpid = 2055256323
# iteration : 737, zpid = 2056140568
# iteration : 738, zpid = 2085143041
# iteration : 739, zpid = 2078051132
# iteration : 740, zpid = 2094230564
# iteration : 741, zpid = 2094230452
# iteration : 742, zpid = 2094230497
# iteration : 743, zpid = 2094230431
# iteration : 744, zpid = 2089347135
# iteration : 745, zpid = 2090292819
# iteration : 746, zpid = 2079049723
# iteration : 747, zpid = 2089806562
# iteration : 748, zpid = 2091659552
# iteration : 749, zpid = 2079104240
# iteration : 750, zpid = 2094230486
# iteration : 751, zpid = 2088883200
# iteration : 752, zpid = 2086122352
# iteration : 753, zpid = 2085062312
# iteration : 754, zpid = 2072581500
# iteration : 755, zpid = 2094230328
# iteration : 756, zpid = 2078956533
# iteration : 757, zpid = 2078758227
# iteration : 758, zpid = 2094230406
# iteration : 759, zpid = 2094230356
# iteration : 760, zpid = 2077808791
# iteration : 761, zpid = 2084010527
# iteration : 762, zpid = 2091989095
# iteration : 763, zpid = 2092205475
# iteration : 764, zpid = 2094230344
# iteration : 765, zpid = 2094230511
# iteration : 766, zpid = 2084739635
# iteration : 767, zpid = 2094230401
# iteration : 768, zpid = 2080025543
# iteration : 769, zpid = 2087332136
# iteration : 770, zpid = 2071947784
# iteration : 771, zpid = 2071907484
# iteration : 772, zpid = 2068979004
# iteration : 773, zpid = 2077889253
# iteration : 774, zpid = 2086887134
# iteration : 775, zpid = 2070475347
# iteration : 776, zpid = 2080520199
# iteration : 777, zpid = 2073174515
# iteration : 778, zpid = 2073392780
# iteration : 779, zpid = 2077118119
# iteration : 780, zpid = 2081969990
# iteration : 781, zpid = 2080118525
# iteration : 782, zpid = 2068679069
# iteration : 783, zpid = 2071202450
# iteration : 784, zpid = 2078102686
# iteration : 785, zpid = 2077501243
# iteration : 786, zpid = 2080045555
# iteration : 787, zpid = 2077118120
# iteration : 788, zpid = 2070919137
# iteration : 789, zpid = 2066518954
# iteration : 790, zpid = 2071952056
# iteration : 791, zpid = 2068391446
# iteration : 792, zpid = 2075606098
# iteration : 793, zpid = 2076896194
# iteration : 794, zpid = 2079339605
# iteration : 795, zpid = 2067892800
# iteration : 796, zpid = 2067892798
# iteration : 797, zpid = 2091269702
# iteration : 798, zpid = 2093136006
# iteration : 799, zpid = 2089581933
# iteration : 800, zpid = 2093107982
# iteration : 801, zpid = 2088767568
# iteration : 802, zpid = 2079246804
# iteration : 803, zpid = 2088590935
# iteration : 804, zpid = 2070785971
# iteration : 805, zpid = 2060386640
# iteration : 806, zpid = 2079394215
# iteration : 807, zpid = 2080374687
# iteration : 808, zpid = 2080374684
# iteration : 809, zpid = 2080374682
# iteration : 810, zpid = 2080374679
# iteration : 811, zpid = 2080374678
# iteration : 812, zpid = 2080374692
# iteration : 813, zpid = 2069333995
# iteration : 814, zpid = 2061761068
# iteration : 815, zpid = 2079381698
# iteration : 816, zpid = 2077432361
# iteration : 817, zpid = 2080374685
# iteration : 818, zpid = 2080374681
# iteration : 819, zpid = 2080374693
# iteration : 820, zpid = 2090912764
# iteration : 821, zpid = 2082197697
# iteration : 822, zpid = 2078301687
# iteration : 823, zpid = 2090402311
# iteration : 824, zpid = 2088942045
# iteration : 825, zpid = 2091339499
# iteration : 826, zpid = 2079389361
# iteration : 827, zpid = 2092766484
# iteration : 828, zpid = 2078488692
# iteration : 829, zpid = 2082378016
# iteration : 830, zpid = 2069330637
# iteration : 831, zpid = 2093020429
# iteration : 832, zpid = 2093020430
# iteration : 833, zpid = 2088145554
# iteration : 834, zpid = 2088389946
# iteration : 835, zpid = 2093020438
# iteration : 836, zpid = 2090647824
# iteration : 837, zpid = 2092962297
# iteration : 838, zpid = 2079761271
# iteration : 839, zpid = 2088479758
# iteration : 840, zpid = 2088211562
# iteration : 841, zpid = 2082378022
# iteration : 842, zpid = 2088753858
# iteration : 843, zpid = 2092116186
# iteration : 844, zpid = 2093020439
# iteration : 845, zpid = 2093020426
# iteration : 846, zpid = 2089519876
# iteration : 847, zpid = 2092181499
# iteration : 848, zpid = 2089032083
# iteration : 849, zpid = 2088493840
# iteration : 850, zpid = 2082162265
# iteration : 851, zpid = 2092728415
# iteration : 852, zpid = 2089000475
# iteration : 853, zpid = 2091545015
# iteration : 854, zpid = 2072277684
# iteration : 855, zpid = 2082378025
# iteration : 856, zpid = 2093020406
# iteration : 857, zpid = 2090488208
# iteration : 858, zpid = 2090554688
# iteration : 859, zpid = 2081002088
# iteration : 860, zpid = 2079908534
# iteration : 861, zpid = 2090416375
# iteration : 862, zpid = 2078579094
# iteration : 863, zpid = 2124248020
# iteration : 864, zpid = 2078899907
# iteration : 865, zpid = 2078899837
# iteration : 866, zpid = 2078899823
# iteration : 867, zpid = 2078899890
# iteration : 868, zpid = 2078900013
# iteration : 869, zpid = 2078899716
# iteration : 870, zpid = 2078899852
# iteration : 871, zpid = 2078900004
# iteration : 872, zpid = 2078899785
# iteration : 873, zpid = 2078900016
# iteration : 874, zpid = 2078899975
# iteration : 875, zpid = 2078899997
# iteration : 876, zpid = 2078899792
# iteration : 877, zpid = 2078900011
# iteration : 878, zpid = 2078899863
# iteration : 879, zpid = 2078899878
# iteration : 880, zpid = 2078899913
# iteration : 881, zpid = 2078899950
# iteration : 882, zpid = 2078899741
# iteration : 883, zpid = 2078899806
# iteration : 884, zpid = 2078899732
# iteration : 885, zpid = 2078899845
# iteration : 886, zpid = 2078899994
# iteration : 887, zpid = 2078899775
# iteration : 888, zpid = 2078899934
# iteration : 889, zpid = 2063284230
# iteration : 890, zpid = 2065474096
# iteration : 891, zpid = 2055681531
# iteration : 892, zpid = 2057495857
# iteration : 893, zpid = 2075177680
# iteration : 894, zpid = 2056233515
# iteration : 895, zpid = 2055234111
# iteration : 896, zpid = 2056203722
# iteration : 897, zpid = 2055465060
# iteration : 898, zpid = 2060116431
# iteration : 899, zpid = 2056233516
# iteration : 900, zpid = 2067409514
# iteration : 901, zpid = 2079691110
# iteration : 902, zpid = 2055639125
# iteration : 903, zpid = 2055465059
# iteration : 904, zpid = 2055522102
# iteration : 905, zpid = 2066534917
# iteration : 906, zpid = 2055204877
# iteration : 907, zpid = 2063176009
# iteration : 908, zpid = 2055711387
# iteration : 909, zpid = 2056814752
# iteration : 910, zpid = 2055612892
# iteration : 911, zpid = 2055207536
# iteration : 912, zpid = 2056556126
# iteration : 913, zpid = 2056814747
# iteration : 914, zpid = 2056814749
# iteration : 915, zpid = 2077331236
# iteration : 916, zpid = 2055274227
# iteration : 917, zpid = 2061983692
# iteration : 918, zpid = 2061983700
# iteration : 919, zpid = 2061886105
# iteration : 920, zpid = 2055820595
# iteration : 921, zpid = 2076992290
# iteration : 922, zpid = 2068597532
# iteration : 923, zpid = 2055274419
# iteration : 924, zpid = 2064142182
# iteration : 925, zpid = 2072139468
# iteration : 926, zpid = 2056053599
# iteration : 927, zpid = 2086604268
# iteration : 928, zpid = 2087343934
# iteration : 929, zpid = 2081118894
# iteration : 930, zpid = 2064397851
# iteration : 931, zpid = 2085486483
# iteration : 932, zpid = 2068503359
# iteration : 933, zpid = 2084332432
# iteration : 934, zpid = 2083305260
# iteration : 935, zpid = 2082987776
# iteration : 936, zpid = 2078961672
# iteration : 937, zpid = 2082706643
# iteration : 938, zpid = 2083867280
# iteration : 939, zpid = 2086282920
# iteration : 940, zpid = 2072796114
# iteration : 941, zpid = 2066992270
# iteration : 942, zpid = 2067055258
# iteration : 943, zpid = 2067039647
# iteration : 944, zpid = 2067039651
# iteration : 945, zpid = 2067039703
# iteration : 946, zpid = 2067053058
# iteration : 947, zpid = 2056465329
# iteration : 948, zpid = 2060174234
# iteration : 949, zpid = 2062673555
# iteration : 950, zpid = 2067050282
# iteration : 951, zpid = 2066823013
# iteration : 952, zpid = 2063461017
# iteration : 953, zpid = 2066477096
# iteration : 954, zpid = 2067050256
# iteration : 955, zpid = 2055236062
# iteration : 956, zpid = 2056967805
# iteration : 957, zpid = 2067050292
# iteration : 958, zpid = 2067050293
# iteration : 959, zpid = 2067050294
# iteration : 960, zpid = 2067050290
# iteration : 961, zpid = 2064297626
# iteration : 962, zpid = 2067039709
# iteration : 963, zpid = 2062658302
# iteration : 964, zpid = 2065616697
# iteration : 965, zpid = 2058738329
# iteration : 966, zpid = 2065739285
# iteration : 967, zpid = 2062109374
# iteration : 968, zpid = 2067050328
# iteration : 969, zpid = 2061517154
# iteration : 970, zpid = 2061517155
# iteration : 971, zpid = 2066856628
# iteration : 972, zpid = 2067039658
# iteration : 973, zpid = 2067039645
# iteration : 974, zpid = 2060104449
# iteration : 975, zpid = 2055900525
# iteration : 976, zpid = 2067053062
# iteration : 977, zpid = 2067042864
# iteration : 978, zpid = 2067058053
# iteration : 979, zpid = 2067039764
# iteration : 980, zpid = 2067039710
# iteration : 981, zpid = 2067039705
# iteration : 982, zpid = 2067055248
# iteration : 983, zpid = 2067058043
# iteration : 984, zpid = 2067051462
# iteration : 985, zpid = 2067050274
# iteration : 986, zpid = 2067042858
# iteration : 987, zpid = 2067050261
# iteration : 988, zpid = 2067039769
# iteration : 989, zpid = 2067039668
# iteration : 990, zpid = 2067039679
# iteration : 991, zpid = 2067039698
# iteration : 992, zpid = 2067039704
# iteration : 993, zpid = 2067050302
# iteration : 994, zpid = 2067039661
# iteration : 995, zpid = 2067039701
# iteration : 996, zpid = 2067050280
# iteration : 997, zpid = 2067039767
# iteration : 998, zpid = 2067039772
# iteration : 999, zpid = 2067050269
# iteration : 1000, zpid = 2067050270
# iteration : 1001, zpid = 2067039740
# iteration : 1002, zpid = 2067039739
# iteration : 1003, zpid = 2062623424
# iteration : 1004, zpid = 2067050324
# iteration : 1005, zpid = 2067050311
# iteration : 1006, zpid = 2067050318
# iteration : 1007, zpid = 2067050315
# iteration : 1008, zpid = 2067039664
# iteration : 1009, zpid = 2067039665
# iteration : 1010, zpid = 2067039667
# iteration : 1011, zpid = 2067039660
# iteration : 1012, zpid = 2067039726
# iteration : 1013, zpid = 2067039727
# iteration : 1014, zpid = 2067039689
# iteration : 1015, zpid = 2067039779
# iteration : 1016, zpid = 2067039655
# iteration : 1017, zpid = 2067039707
# iteration : 1018, zpid = 2067039750
# iteration : 1019, zpid = 2067039745
# iteration : 1020, zpid = 2067039753
# iteration : 1021, zpid = 2061685882
# iteration : 1022, zpid = 2067039736
# iteration : 1023, zpid = 2067039682
# iteration : 1024, zpid = 2061611605
# iteration : 1025, zpid = 2067058046
# iteration : 1026, zpid = 2067039683
# iteration : 1027, zpid = 2067039755
# iteration : 1028, zpid = 2067058073
# iteration : 1029, zpid = 2067042865
# iteration : 1030, zpid = 2067039765
# iteration : 1031, zpid = 2067039732
# iteration : 1032, zpid = 2067039653
# iteration : 1033, zpid = 2067039773
# iteration : 1034, zpid = 2067039747
# iteration : 1035, zpid = 2061013753
# iteration : 1036, zpid = 2067039737
# iteration : 1037, zpid = 2064410436
# iteration : 1038, zpid = 2067039720
# iteration : 1039, zpid = 2055868734
# iteration : 1040, zpid = 2068469999
# iteration : 1041, zpid = 2063394252
# iteration : 1042, zpid = 2069998035
# iteration : 1043, zpid = 2066962537
# iteration : 1044, zpid = 2055447161
# iteration : 1045, zpid = 2075644969
# iteration : 1046, zpid = 2055314510
# iteration : 1047, zpid = 2067446900
# iteration : 1048, zpid = 2062658536
# iteration : 1049, zpid = 2055802271
# iteration : 1050, zpid = 2057069907
# iteration : 1051, zpid = 2071230227
# iteration : 1052, zpid = 2078851773
# iteration : 1053, zpid = 2080570227
# iteration : 1054, zpid = 2077635292
# iteration : 1055, zpid = 2072721134
# iteration : 1056, zpid = 2079915419
# iteration : 1057, zpid = 2062279276
# iteration : 1058, zpid = 2080269426
# iteration : 1059, zpid = 2080657456
# iteration : 1060, zpid = 2078116769
# iteration : 1061, zpid = 2080657458
# iteration : 1062, zpid = 2094076827
# iteration : 1063, zpid = 2079842973
# iteration : 1064, zpid = 2071132266
# iteration : 1065, zpid = 2080145857
# iteration : 1066, zpid = 2072257464
# iteration : 1067, zpid = 2071930800
# iteration : 1068, zpid = 2057609275
# iteration : 1069, zpid = 2070205219
# iteration : 1070, zpid = 2057163888
# iteration : 1071, zpid = 2058052484
# iteration : 1072, zpid = 2074401181
# iteration : 1073, zpid = 2067092799
# iteration : 1074, zpid = 2072099619
# iteration : 1075, zpid = 2055490828
# iteration : 1076, zpid = 2056947983
# iteration : 1077, zpid = 2066785704
# iteration : 1078, zpid = 2069156964
# iteration : 1079, zpid = 2067330802
# iteration : 1080, zpid = 2056229150
# iteration : 1081, zpid = 2058104289
# iteration : 1082, zpid = 2068009023
# iteration : 1083, zpid = 2066600649
# iteration : 1084, zpid = 2068721175
# iteration : 1085, zpid = 2058928549
# iteration : 1086, zpid = 2076625963
# iteration : 1087, zpid = 2080174241
# iteration : 1088, zpid = 2080645491
# iteration : 1089, zpid = 2055926995
# iteration : 1090, zpid = 2070902710
# iteration : 1091, zpid = 2076625964
# iteration : 1092, zpid = 2071743873
# iteration : 1093, zpid = 2065654287
# iteration : 1094, zpid = 2080552064
# iteration : 1095, zpid = 2075308140
# iteration : 1096, zpid = 2057286425
# iteration : 1097, zpid = 2056386762
# iteration : 1098, zpid = 2057286437
# iteration : 1099, zpid = 2057286434
# iteration : 1100, zpid = 2057286438
# iteration : 1101, zpid = 2057286432
# iteration : 1102, zpid = 2057286429
# iteration : 1103, zpid = 2057286426
# iteration : 1104, zpid = 2057286430
# iteration : 1105, zpid = 2057286431
# iteration : 1106, zpid = 2091145273
# iteration : 1107, zpid = 2091145241
# iteration : 1108, zpid = 2091145282
# iteration : 1109, zpid = 2091145370
# iteration : 1110, zpid = 2091145217
# iteration : 1111, zpid = 2091145245
# iteration : 1112, zpid = 2091145341
# iteration : 1113, zpid = 2091145279
# iteration : 1114, zpid = 2091145200
# iteration : 1115, zpid = 2091109063
# iteration : 1116, zpid = 2091145452
# iteration : 1117, zpid = 2055459898
# iteration : 1118, zpid = 2094118282
# iteration : 1119, zpid = 2057196601
# iteration : 1120, zpid = 2055459897
# iteration : 1121, zpid = 2069994702
# iteration : 1122, zpid = 2080060076
# iteration : 1123, zpid = 2055326086
# iteration : 1124, zpid = 2055283441
# iteration : 1125, zpid = 2055973627
# iteration : 1126, zpid = 2079494597
# iteration : 1127, zpid = 2063288928
# iteration : 1128, zpid = 2078617777
# iteration : 1129, zpid = 2078926867
# iteration : 1130, zpid = 2058154240
# iteration : 1131, zpid = 2058154205
# iteration : 1132, zpid = 2058122567
# iteration : 1133, zpid = 2057682868
# iteration : 1134, zpid = 2057776082
# iteration : 1135, zpid = 2061794761
# iteration : 1136, zpid = 2055775894
# iteration : 1137, zpid = 2055229467
# iteration : 1138, zpid = 2061764766
# iteration : 1139, zpid = 2059490410
# iteration : 1140, zpid = 2059083827
# iteration : 1141, zpid = 2061794774
# iteration : 1142, zpid = 2056328418
# iteration : 1143, zpid = 2056211917
# iteration : 1144, zpid = 2056211916
# iteration : 1145, zpid = 2055970030
# iteration : 1146, zpid = 2055373876
# iteration : 1147, zpid = 2061811519
# iteration : 1148, zpid = 2056972195
# iteration : 1149, zpid = 2061811593
# iteration : 1150, zpid = 2058170015
# iteration : 1151, zpid = 2057940836
# iteration : 1152, zpid = 2057511112
# iteration : 1153, zpid = 2061811584
# iteration : 1154, zpid = 2061794820
# iteration : 1155, zpid = 2058053221
# iteration : 1156, zpid = 2060860136
# iteration : 1157, zpid = 2061794795
# iteration : 1158, zpid = 2061811582
# iteration : 1159, zpid = 2061811579
# iteration : 1160, zpid = 2061811587
# iteration : 1161, zpid = 2061811591
# iteration : 1162, zpid = 2057157978
# iteration : 1163, zpid = 2061811589
# iteration : 1164, zpid = 2057570304
# iteration : 1165, zpid = 2061802366
# iteration : 1166, zpid = 2058084366
# iteration : 1167, zpid = 2061811625
# iteration : 1168, zpid = 2061811577
# iteration : 1169, zpid = 2061811554
# iteration : 1170, zpid = 2061811552
# iteration : 1171, zpid = 2055931429
# iteration : 1172, zpid = 2055613081
# iteration : 1173, zpid = 2055999782
# iteration : 1174, zpid = 2056518919
# iteration : 1175, zpid = 2055931433
# iteration : 1176, zpid = 2058136244
# iteration : 1177, zpid = 2055960012
# iteration : 1178, zpid = 2061811575
# iteration : 1179, zpid = 2061811528
# iteration : 1180, zpid = 2060900432
# iteration : 1181, zpid = 2057892776
# iteration : 1182, zpid = 2057091384
# iteration : 1183, zpid = 2056962734
# iteration : 1184, zpid = 2061811604
# iteration : 1185, zpid = 2061811601
# iteration : 1186, zpid = 2061811603
# iteration : 1187, zpid = 2061811624
# iteration : 1188, zpid = 2061811531
# iteration : 1189, zpid = 2061811527
# iteration : 1190, zpid = 2061794817
# iteration : 1191, zpid = 2061811532
# iteration : 1192, zpid = 2061811539
# iteration : 1193, zpid = 2061811594
# iteration : 1194, zpid = 2061583558
# iteration : 1195, zpid = 2061811536
# iteration : 1196, zpid = 2061794806
# iteration : 1197, zpid = 2061794805
# iteration : 1198, zpid = 2061794804
# iteration : 1199, zpid = 2061811545
# iteration : 1200, zpid = 2061811544
# iteration : 1201, zpid = 2061811525
# iteration : 1202, zpid = 2061811523
# iteration : 1203, zpid = 2089732924
# iteration : 1204, zpid = 2063502009
# iteration : 1205, zpid = 2070495146
# iteration : 1206, zpid = 2078598349
# iteration : 1207, zpid = 2080527606
# iteration : 1208, zpid = 2056972438
# iteration : 1209, zpid = 2056972439
# iteration : 1210, zpid = 2055288501
# iteration : 1211, zpid = 2055288554
# iteration : 1212, zpid = 2055288542
# iteration : 1213, zpid = 2055288618
# iteration : 1214, zpid = 2084886858
# iteration : 1215, zpid = 2089864371
# iteration : 1216, zpid = 2089864376
# iteration : 1217, zpid = 2089864373
# iteration : 1218, zpid = 2088609584
# iteration : 1219, zpid = 2089864333
# iteration : 1220, zpid = 2088290445
# iteration : 1221, zpid = 2089864327
# iteration : 1222, zpid = 2089864310
# iteration : 1223, zpid = 2089864354
# iteration : 1224, zpid = 2086572667
# iteration : 1225, zpid = 2086804380
# iteration : 1226, zpid = 2089864276
# iteration : 1227, zpid = 2081228638
# iteration : 1228, zpid = 2089864281
# iteration : 1229, zpid = 2084323042
# iteration : 1230, zpid = 2089864267
# iteration : 1231, zpid = 2089864265
# iteration : 1232, zpid = 2089202430
# iteration : 1233, zpid = 2088541448
# iteration : 1234, zpid = 2091707834
# iteration : 1235, zpid = 2092981524
# iteration : 1236, zpid = 2087956048
# iteration : 1237, zpid = 2089725386
# iteration : 1238, zpid = 2082921809
# iteration : 1239, zpid = 2078317529
# iteration : 1240, zpid = 2093135793
# iteration : 1241, zpid = 2071964676
# iteration : 1242, zpid = 2078342780
# iteration : 1243, zpid = 2090351837
# iteration : 1244, zpid = 2087552937
# iteration : 1245, zpid = 2093135802
# iteration : 1246, zpid = 2080057346
# iteration : 1247, zpid = 2090609272
# iteration : 1248, zpid = 2090609276
# iteration : 1249, zpid = 2081846122
# iteration : 1250, zpid = 2077402104
# iteration : 1251, zpid = 2079134777
# iteration : 1252, zpid = 2093001321
# iteration : 1253, zpid = 2078171597
# iteration : 1254, zpid = 2056838617
# iteration : 1255, zpid = 2080074863
# iteration : 1256, zpid = 2085062276
# iteration : 1257, zpid = 2056039795
# iteration : 1258, zpid = 2056265520
# iteration : 1259, zpid = 2056265522
# iteration : 1260, zpid = 2056003631
# iteration : 1261, zpid = 2056088550
# iteration : 1262, zpid = 2055959815
# iteration : 1263, zpid = 2055959814
# iteration : 1264, zpid = 2056169630
# iteration : 1265, zpid = 2056265515
# iteration : 1266, zpid = 2056265517
# iteration : 1267, zpid = 2055812934
# iteration : 1268, zpid = 2055882268
# iteration : 1269, zpid = 2056265516
# iteration : 1270, zpid = 2055205279
# iteration : 1271, zpid = 2056265503
# iteration : 1272, zpid = 2056265521
# iteration : 1273, zpid = 2056265523
# iteration : 1274, zpid = 2056265518
# iteration : 1275, zpid = 2056265505
# iteration : 1276, zpid = 2056265508
# iteration : 1277, zpid = 2056265507
# iteration : 1278, zpid = 2055289782
# iteration : 1279, zpid = 2055451437
# iteration : 1280, zpid = 2055313362
# iteration : 1281, zpid = 2055444760
# iteration : 1282, zpid = 2065660734
# iteration : 1283, zpid = 2056462896
# iteration : 1284, zpid = 2079758252
# iteration : 1285, zpid = 2055464806
# iteration : 1286, zpid = 2077262313
# iteration : 1287, zpid = 2078551156
# iteration : 1288, zpid = 2078779347
# iteration : 1289, zpid = 2055766976
# iteration : 1290, zpid = 2055540180
# iteration : 1291, zpid = 2058084167
# iteration : 1292, zpid = 2055815646
# iteration : 1293, zpid = 2087411002
# iteration : 1294, zpid = 2060690666
# iteration : 1295, zpid = 2113970526
# iteration : 1296, zpid = 2057579458
# iteration : 1297, zpid = 2055200560
# iteration : 1298, zpid = 2057856660
# iteration : 1299, zpid = 2058055664
# iteration : 1300, zpid = 2058413984
# iteration : 1301, zpid = 2091867276
# iteration : 1302, zpid = 2055984322
# iteration : 1303, zpid = 2087384847
# iteration : 1304, zpid = 2058033450
# iteration : 1305, zpid = 2057455016
# iteration : 1306, zpid = 2092939934
# iteration : 1307, zpid = 2092912744
# iteration : 1308, zpid = 2092471675
# iteration : 1309, zpid = 2058413968
# iteration : 1310, zpid = 2093014243
# iteration : 1311, zpid = 2058413981
# iteration : 1312, zpid = 2056929628
# iteration : 1313, zpid = 2056840771
# iteration : 1314, zpid = 2057768158
# iteration : 1315, zpid = 2055923510
# iteration : 1316, zpid = 2087417323
# iteration : 1317, zpid = 2057676827
# iteration : 1318, zpid = 2056239195
# iteration : 1319, zpid = 2058413969
# iteration : 1320, zpid = 2055905994
# iteration : 1321, zpid = 2090981095
# iteration : 1322, zpid = 2093128801
# iteration : 1323, zpid = 2090699441
# iteration : 1324, zpid = 2055984305
# iteration : 1325, zpid = 2055905993
# iteration : 1326, zpid = 2090579065
# iteration : 1327, zpid = 2055984314
# iteration : 1328, zpid = 2056055897
# iteration : 1329, zpid = 2090699442
# iteration : 1330, zpid = 2078296897
# iteration : 1331, zpid = 2056025061
# iteration : 1332, zpid = 2076616358
# iteration : 1333, zpid = 2091500681
# iteration : 1334, zpid = 2078919027
# iteration : 1335, zpid = 2078357280
# iteration : 1336, zpid = 2079357615
# iteration : 1337, zpid = 2079357616
# iteration : 1338, zpid = 2087644366
# iteration : 1339, zpid = 2087644348
# iteration : 1340, zpid = 2088437004
# iteration : 1341, zpid = 2088477242
# iteration : 1342, zpid = 2080039665
# iteration : 1343, zpid = 2066608517
# iteration : 1344, zpid = 2088874211
# iteration : 1345, zpid = 2055802454
# iteration : 1346, zpid = 2088477235
# iteration : 1347, zpid = 2080412818
# iteration : 1348, zpid = 2085770154
# iteration : 1349, zpid = 2055524419
# iteration : 1350, zpid = 2089266855
# iteration : 1351, zpid = 2067539160
# iteration : 1352, zpid = 2089266839
# iteration : 1353, zpid = 2089266883
# iteration : 1354, zpid = 2091500656
# iteration : 1355, zpid = 2088874209
# iteration : 1356, zpid = 2091500651
# iteration : 1357, zpid = 294972284
# iteration : 1358, zpid = 294972290
# iteration : 1359, zpid = 294972304
# iteration : 1360, zpid = 294972413
# iteration : 1361, zpid = 294972355
# iteration : 1362, zpid = 294972348
# iteration : 1363, zpid = 294972382
# ...
# iteration : 2406, zpid = 36485456
# iteration : 2407, zpid = 36559890
# iteration : 2408, zpid = 2080562238
# iteration : 2409, zpid = 36529727
# iteration : 2410, zpid = 2055476277
# iteration : 2411, zpid = 36571528
# iteration : 2412, zpid = 36445154
# iteration : 2413, zpid = 36459183
# iteration : 2414, zpid = 2096607983
# iteration : 2415, zpid = 2068009461
# iteration : 2416, zpid = 63761187
# iteration : 2417, zpid = 36446578
# iteration : 2418, zpid = 36538991
# iteration : 2419, zpid = 36430147
# iteration : 2420, zpid = 2055482475
# iteration : 2421, zpid = 2092929664
# iteration : 2422, zpid = 36458505
# An error occurred during the request: 'NoneType' object is not subscriptable
# iteration : 2423, zpid = 81750009
# iteration : 2424, zpid = 36556609
# iteration : 2425, zpid = 2062427998
# iteration : 2426, zpid = 2086870878
# iteration : 2427, zpid = 2055486335
# iteration : 2428, zpid = 36435083
# iteration : 2429, zpid = 36519770
# iteration : 2430, zpid = 36495802
# iteration : 2431, zpid = 2055488804
# iteration : 2432, zpid = 2070550354
# iteration : 2433, zpid = 36439238
# iteration : 2434, zpid = 36539075
# iteration : 2435, zpid = 36461478
# iteration : 2436, zpid = 36574228
# iteration : 2437, zpid = 36505592
# iteration : 2438, zpid = 2055493833
# iteration : 2439, zpid = 72227662
# An error occurred during the request: 'NoneType' object is not subscriptable
# iteration : 2440, zpid = 36472184
# iteration : 2441, zpid = 36565144
# iteration : 2442, zpid = 36562239
# iteration : 2443, zpid = 131677394
# iteration : 2444, zpid = 234654382
# iteration : 2445, zpid = 36433297
# iteration : 2446, zpid = 36529005
# iteration : 2447, zpid = 36598597
# iteration : 2448, zpid = 36552546
# iteration : 2449, zpid = 2111953803
# iteration : 2450, zpid = 36560767
# iteration : 2451, zpid = 2115730495
# iteration : 2452, zpid = 2079353494
# iteration : 2453, zpid = 36459263
# iteration : 2454, zpid = 241969634
# An error occurred during the request: 'NoneType' object is not subscriptable
# iteration : 2455, zpid = 2094522779
# iteration : 2456, zpid = 36483299
# iteration : 2457, zpid = 36536857
# iteration : 2458, zpid = 36439291
# iteration : 2459, zpid = 36594073
# iteration : 2460, zpid = 2055522894
# iteration : 2461, zpid = 36599196
# iteration : 2462, zpid = 36491324
# iteration : 2463, zpid = 36514623
# iteration : 2464, zpid = 36430079
# iteration : 2465, zpid = 36435864
# iteration : 2466, zpid = 36560327
# iteration : 2467, zpid = 2068668283
# iteration : 2468, zpid = 2081380607
# iteration : 2469, zpid = 36566347
# iteration : 2470, zpid = 2068499299
# iteration : 2471, zpid = 36434672
# An error occurred during the request: 'NoneType' object is not subscriptable
# iteration : 2472, zpid = 2055974613
# iteration : 2473, zpid = 36585414
# iteration : 2474, zpid = 2106499799
# iteration : 2475, zpid = 36452421
# iteration : 2476, zpid = 36477922
# iteration : 2477, zpid = 36533901
# An error occurred during the request: 'NoneType' object is not subscriptable
# iteration : 2478, zpid = 36509964
# iteration : 2479, zpid = 36593140
# iteration : 2480, zpid = 36450129
# iteration : 2481, zpid = 36566548
# iteration : 2482, zpid = 2070204465
# iteration : 2483, zpid = 36599276
# iteration : 2484, zpid = 36560873
# iteration : 2485, zpid = 2079231561
# iteration : 2486, zpid = 36616658
# iteration : 2487, zpid = 36542626
# iteration : 2488, zpid = 2061901735
# iteration : 2489, zpid = 36435934
# iteration : 2490, zpid = 36475494
# iteration : 2491, zpid = 2085381781
# iteration : 2492, zpid = 2112246287
# iteration : 2493, zpid = 111109311
# iteration : 2494, zpid = 2055620817
# iteration : 2495, zpid = 2062676438
# iteration : 2496, zpid = 36431861
# iteration : 2497, zpid = 2094214346
# iteration : 2498, zpid = 2058519444
# iteration : 2499, zpid = 36548044
# iteration : 2500, zpid = 36518057
# iteration : 2501, zpid = 2055590041
# iteration : 2502, zpid = 36517622
# iteration : 2503, zpid = 36436949
# iteration : 2504, zpid = 36433230
# iteration : 2505, zpid = 2103606521
# iteration : 2506, zpid = 90005213
# An error occurred during the request: 'NoneType' object is not subscriptable
# iteration : 2507, zpid = 36528315
# iteration : 2508, zpid = 2070453219
# iteration : 2509, zpid = 36542526
# iteration : 2510, zpid = 36503498
# iteration : 2511, zpid = 36522854
# iteration : 2512, zpid = 2072304070
# iteration : 2513, zpid = 2117896913
# iteration : 2514, zpid = 36482818
# iteration : 2515, zpid = 36465283
# iteration : 2516, zpid = 36448186
# iteration : 2517, zpid = 36529826
# iteration : 2518, zpid = 2080385920
# iteration : 2519, zpid = 36475977
# iteration : 2520, zpid = 36482567
# iteration : 2521, zpid = 36454785
# iteration : 2522, zpid = 36439421
# iteration : 2523, zpid = 2056145157
# iteration : 2524, zpid = 36434964
# iteration : 2525, zpid = 2089106277
# iteration : 2526, zpid = 36456536
# iteration : 2527, zpid = 36543690
# An error occurred during the request: 'NoneType' object is not subscriptable
# iteration : 2528, zpid = 36599394
# iteration : 2529, zpid = 2068670713
# iteration : 2530, zpid = 36508633
# iteration : 2531, zpid = 2088301170
# iteration : 2532, zpid = 36491862
# iteration : 2533, zpid = 36531568
# iteration : 2534, zpid = 36558778
# iteration : 2535, zpid = 2057549205
# iteration : 2536, zpid = 2055677320
# iteration : 2537, zpid = 36566360
# iteration : 2538, zpid = 36561430
# iteration : 2539, zpid = 36429337
# iteration : 2540, zpid = 2067039225
# iteration : 2541, zpid = 121916180
# An error occurred during the request: 'NoneType' object is not subscriptable
# iteration : 2542, zpid = 36521214
# iteration : 2543, zpid = 2080674068
# iteration : 2544, zpid = 36453427
# iteration : 2545, zpid = 2093512194
# iteration : 2546, zpid = 36536676
# iteration : 2547, zpid = 36532471
# iteration : 2548, zpid = 2082603479
# iteration : 2549, zpid = 131244001
# iteration : 2550, zpid = 36475656
# iteration : 2551, zpid = 36561713
# iteration : 2552, zpid = 2055693694
# iteration : 2553, zpid = 36474824
# iteration : 2554, zpid = 2060829375
# iteration : 2555, zpid = 2113813537
# iteration : 2556, zpid = 36611366
# iteration : 2557, zpid = 36573927
# iteration : 2558, zpid = 2056554283
# iteration : 2559, zpid = 2055699282
# iteration : 2560, zpid = 2055699819
# iteration : 2561, zpid = 36445622
# iteration : 2562, zpid = 2057259913
# iteration : 2563, zpid = 36472852
# iteration : 2564, zpid = 2095062290
# iteration : 2565, zpid = 36439950
# iteration : 2566, zpid = 2084762721
# iteration : 2567, zpid = 2071122745
# iteration : 2568, zpid = 36457965
# iteration : 2569, zpid = 36429705
# iteration : 2570, zpid = 36446233
# iteration : 2571, zpid = 36496831
# iteration : 2572, zpid = 36557844
# iteration : 2573, zpid = 36429137
# iteration : 2574, zpid = 2071218161
# iteration : 2575, zpid = 36562255
# iteration : 2576, zpid = 2069597031
# iteration : 2577, zpid = 36542453
# iteration : 2578, zpid = 2113162081
# iteration : 2579, zpid = 2070261192
# iteration : 2580, zpid = 36430264
# An error occurred during the request: 'NoneType' object is not subscriptable
# iteration : 2581, zpid = 36536781
# iteration : 2582, zpid = 58238286
# iteration : 2583, zpid = 36488555
# iteration : 2584, zpid = 36538419
# iteration : 2585, zpid = 36432987
# iteration : 2586, zpid = 36429513
# iteration : 2587, zpid = 2056033544
# iteration : 2588, zpid = 36474559
# iteration : 2589, zpid = 36522652
# iteration : 2590, zpid = 2057564331
# iteration : 2591, zpid = 36453899
# iteration : 2592, zpid = 2055974973
# iteration : 2593, zpid = 36433425
# iteration : 2594, zpid = 2078869762
# iteration : 2595, zpid = 2065068090
# iteration : 2596, zpid = 36458860
# iteration : 2597, zpid = 36514243
# iteration : 2598, zpid = 2055773516
# iteration : 2599, zpid = 36474727
# iteration : 2600, zpid = 2082168606
# iteration : 2601, zpid = 36460901
# iteration : 2602, zpid = 36433394
# iteration : 2603, zpid = 2104383626
# iteration : 2604, zpid = 2118087746
# iteration : 2605, zpid = 2085980610
# iteration : 2606, zpid = 2057533173
# iteration : 2607, zpid = 36446592
# iteration : 2608, zpid = 36502052
# iteration : 2609, zpid = 36624127
# iteration : 2610, zpid = 36429793
# iteration : 2611, zpid = 2092465300
# iteration : 2612, zpid = 2057610387
# iteration : 2613, zpid = 36562191
# iteration : 2614, zpid = 36525296
# iteration : 2615, zpid = 2055803083
# iteration : 2616, zpid = 36451751
# iteration : 2617, zpid = 131240802
# iteration : 2618, zpid = 81749614
# iteration : 2619, zpid = 36560418
# An error occurred during the request: 'NoneType' object is not subscriptable
# iteration : 2620, zpid = 2055809027
# iteration : 2621, zpid = 2105437523
# iteration : 2622, zpid = 2055819142
# iteration : 2623, zpid = 2109646224
# iteration : 2624, zpid = 2061761190
# iteration : 2625, zpid = 2055827012
# iteration : 2626, zpid = 36461627
# An error occurred during the request: 'NoneType' object is not subscriptable
# iteration : 2627, zpid = 36559639
# iteration : 2628, zpid = 36560634
# iteration : 2629, zpid = 36545927
# iteration : 2630, zpid = 36441845
# iteration : 2631, zpid = 2055834163
# iteration : 2632, zpid = 36477135
# iteration : 2633, zpid = 36460847
# iteration : 2634, zpid = 2055864744
# iteration : 2635, zpid = 2120293671
# iteration : 2636, zpid = 36449890
# iteration : 2637, zpid = 2055875434
# iteration : 2638, zpid = 2055876464
# iteration : 2639, zpid = 2055878208
# iteration : 2640, zpid = 36429409
# iteration : 2641, zpid = 2130802257
# iteration : 2642, zpid = 2055889752
# iteration : 2643, zpid = 36516414
# iteration : 2644, zpid = 36561582
# iteration : 2645, zpid = 36531596
# iteration : 2646, zpid = 2097833144
# iteration : 2647, zpid = 2055907281
# iteration : 2648, zpid = 2110597360
# iteration : 2649, zpid = 2068412766
# iteration : 2650, zpid = 2101620466
# iteration : 2651, zpid = 2065465616
# iteration : 2652, zpid = 36574003
# iteration : 2653, zpid = 2121504312
# iteration : 2654, zpid = 2055924440
# iteration : 2655, zpid = 90005746
# iteration : 2656, zpid = 2086351296
# iteration : 2657, zpid = 36445526
# iteration : 2658, zpid = 36441356
# iteration : 2659, zpid = 36435827
# iteration : 2660, zpid = 36631552
# iteration : 2661, zpid = 2055926661
# iteration : 2662, zpid = 294976494
# iteration : 2663, zpid = 36560954
# iteration : 2664, zpid = 36512143
# iteration : 2665, zpid = 36599121
# iteration : 2666, zpid = 2055940860
# iteration : 2667, zpid = 36464524
# iteration : 2668, zpid = 2055952332
# iteration : 2669, zpid = 2055959561
# iteration : 2670, zpid = 2066775014
# iteration : 2671, zpid = 2055940693
# iteration : 2672, zpid = 2094436221
# iteration : 2673, zpid = 36477070
# iteration : 2674, zpid = 36447679
# iteration : 2675, zpid = 2079134499
# iteration : 2676, zpid = 36630091
# iteration : 2677, zpid = 2069181583
# iteration : 2678, zpid = 2055984378
# iteration : 2679, zpid = 36489569
# iteration : 2680, zpid = 36514007
# iteration : 2681, zpid = 67870832
# An error occurred during the request: 'NoneType' object is not subscriptable
# iteration : 2682, zpid = 2078689830
# iteration : 2683, zpid = 2056012203
# iteration : 2684, zpid = 36534419
# iteration : 2685, zpid = 81750016
# iteration : 2686, zpid = 36598505
# iteration : 2687, zpid = 36511369
# iteration : 2688, zpid = 2056033771
# iteration : 2689, zpid = 36460596
# iteration : 2690, zpid = 90008340
# iteration : 2691, zpid = 36435095
# iteration : 2692, zpid = 36599027
# iteration : 2693, zpid = 36618454
# iteration : 2694, zpid = 2056291487
# iteration : 2695, zpid = 36434991
# iteration : 2696, zpid = 2057364626
# iteration : 2697, zpid = 2069602343
# iteration : 2698, zpid = 2106899147
# iteration : 2699, zpid = 36481457
# iteration : 2700, zpid = 36504614
# iteration : 2701, zpid = 2056083455
# iteration : 2702, zpid = 2056083456
# iteration : 2703, zpid = 36522037
# iteration : 2704, zpid = 2092208768
# iteration : 2705, zpid = 2056079505
# iteration : 2706, zpid = 36620193
# iteration : 2707, zpid = 36437814
# iteration : 2708, zpid = 241969835
# iteration : 2709, zpid = 36504236
# iteration : 2710, zpid = 2088481912
# iteration : 2711, zpid = 36530310
# iteration : 2712, zpid = 36532959
# iteration : 2713, zpid = 2058948068
# iteration : 2714, zpid = 36581257
# iteration : 2715, zpid = 36440292
# iteration : 2716, zpid = 2106894269
# iteration : 2717, zpid = 36456498
# iteration : 2718, zpid = 2056154978
# iteration : 2719, zpid = 2081750589
# iteration : 2720, zpid = 36474257
# iteration : 2721, zpid = 2057178644
# iteration : 2722, zpid = 2056159265
# iteration : 2723, zpid = 36475890
# iteration : 2724, zpid = 2056194300
# iteration : 2725, zpid = 2089394620
# iteration : 2726, zpid = 2104453654
# iteration : 2727, zpid = 36523219
# iteration : 2728, zpid = 2104927191
# iteration : 2729, zpid = 2056218566
# iteration : 2730, zpid = 2056224607
# iteration : 2731, zpid = 36559977
# iteration : 2732, zpid = 2116826130
# iteration : 2733, zpid = 36433117
# iteration : 2734, zpid = 2056232424
# iteration : 2735, zpid = 36499191
# iteration : 2736, zpid = 2056261347
# iteration : 2737, zpid = 36525988
# iteration : 2738, zpid = 2056279323
# iteration : 2739, zpid = 36551159
# iteration : 2740, zpid = 36557882
# iteration : 2741, zpid = 36511599
# iteration : 2742, zpid = 2056209653
# iteration : 2743, zpid = 36536482
# iteration : 2744, zpid = 36428953
# iteration : 2745, zpid = 2059131364
# iteration : 2746, zpid = 36536754
# iteration : 2747, zpid = 36428890
# iteration : 2748, zpid = 2069236956
# iteration : 2749, zpid = 36451322
# iteration : 2750, zpid = 2104823353
# iteration : 2751, zpid = 36537041
# iteration : 2752, zpid = 36555305
# iteration : 2753, zpid = 2056097474
# iteration : 2754, zpid = 36483059
# iteration : 2755, zpid = 2057483412
# iteration : 2756, zpid = 72225865
# iteration : 2757, zpid = 36616678
# iteration : 2758, zpid = 36546864
# iteration : 2759, zpid = 2056390764
# iteration : 2760, zpid = 36438171
# iteration : 2761, zpid = 36491775
# iteration : 2762, zpid = 2099805350
# iteration : 2763, zpid = 2098511717
# iteration : 2764, zpid = 2072762202
# iteration : 2765, zpid = 2056422368
# iteration : 2766, zpid = 36429007
# iteration : 2767, zpid = 36435389
# An error occurred during the request: 'NoneType' object is not subscriptable
# iteration : 2768, zpid = 36554996
# iteration : 2769, zpid = 2056438658
# iteration : 2770, zpid = 36439142
# iteration : 2771, zpid = 2067324203
# iteration : 2772, zpid = 36469773
# iteration : 2773, zpid = 36574006
# iteration : 2774, zpid = 36458992
# iteration : 2775, zpid = 36431801
# iteration : 2776, zpid = 36603319
# iteration : 2777, zpid = 36442133
# iteration : 2778, zpid = 36442161
# iteration : 2779, zpid = 36597701
# iteration : 2780, zpid = 36535904
# iteration : 2781, zpid = 2059777459
# iteration : 2782, zpid = 36472867
# iteration : 2783, zpid = 36498897
# iteration : 2784, zpid = 2057417995
# iteration : 2785, zpid = 2056536288
# iteration : 2786, zpid = 2085197065
# iteration : 2787, zpid = 36535798
# iteration : 2788, zpid = 36515098
# iteration : 2789, zpid = 2062910130
# iteration : 2790, zpid = 2123468052
# iteration : 2791, zpid = 36519514
# iteration : 2792, zpid = 36561031
# iteration : 2793, zpid = 2092725904
# iteration : 2794, zpid = 2071034914
# iteration : 2795, zpid = 2056934205
# iteration : 2796, zpid = 36569921
# iteration : 2797, zpid = 2067840633
# iteration : 2798, zpid = 36446575
# iteration : 2799, zpid = 2130171237
# iteration : 2800, zpid = 2113131327
# iteration : 2801, zpid = 2057118203
# iteration : 2802, zpid = 2057118200
# iteration : 2803, zpid = 2056606125
# iteration : 2804, zpid = 36472814
# iteration : 2805, zpid = 36538567
# iteration : 2806, zpid = 2056920722
# iteration : 2807, zpid = 36458511
# iteration : 2808, zpid = 36598246
# iteration : 2809, zpid = 2067384939
# iteration : 2810, zpid = 2063223262
# iteration : 2811, zpid = 36482736
# iteration : 2812, zpid = 36440397
# iteration : 2813, zpid = 36472538
# iteration : 2814, zpid = 2056990110
# iteration : 2815, zpid = 36553947
# iteration : 2816, zpid = 36472502
# iteration : 2817, zpid = 2089837959
# iteration : 2818, zpid = 2057029468
# iteration : 2819, zpid = 36614719
# iteration : 2820, zpid = 2095497407
# iteration : 2821, zpid = 36501303
# iteration : 2822, zpid = 36538479
# iteration : 2823, zpid = 36462010
# iteration : 2824, zpid = 2060800454
# iteration : 2825, zpid = 2057644510
# iteration : 2826, zpid = 36436482
# iteration : 2827, zpid = 36562643
# iteration : 2828, zpid = 2057188610
# iteration : 2829, zpid = 2057188609
# iteration : 2830, zpid = 2057188611
# iteration : 2831, zpid = 2057188612
# iteration : 2832, zpid = 2085611523
# iteration : 2833, zpid = 2104322436
# iteration : 2834, zpid = 2057283402
# iteration : 2835, zpid = 2057295855

# %%
main_details_df

# save new dataframe 

import os # package for checking/ removing file
save_path = 'D:/dataSets/msc_group_project/main_information.csv'

# delete file path if it exists, this is needed as dataset keeps being modified
if os.path.exists(save_path):
    os.remove(save_path)
    
main_details_df.to_csv(save_path, index=False)

# %%
address_details_df

import os # package for checking/ removing file
save_path = 'D:/dataSets/msc_group_project/addresses.csv'

# delete file path if it exists, this is needed as dataset keeps being modified
if os.path.exists(save_path):
    os.remove(save_path)
    
address_details_df.to_csv(save_path, index=False)

# %%
indoor_features_df

import os # package for checking/ removing file
save_path = 'D:/dataSets/msc_group_project/interior_features.csv'

# delete file path if it exists, this is needed as dataset keeps being modified
if os.path.exists(save_path):
    os.remove(save_path)
    
indoor_features_df.to_csv(save_path, index=False)

# %%
exterior_features_df

import os # package for checking/ removing file
save_path = 'D:/dataSets/msc_group_project/exterior_features.csv'

# delete file path if it exists, this is needed as dataset keeps being modified
if os.path.exists(save_path):
    os.remove(save_path)
    
exterior_features_df.to_csv(save_path, index=False)

# %%
at_a_glance_df

import os # package for checking/ removing file
save_path = 'D:/dataSets/msc_group_project/quick_glance_features.csv'

# delete file path if it exists, this is needed as dataset keeps being modified
if os.path.exists(save_path):
    os.remove(save_path)
    
at_a_glance_df.to_csv(save_path, index=False)

# %%
fees_df

import os # package for checking/ removing file
save_path = 'D:/dataSets/msc_group_project/all_fees.csv'

# delete file path if it exists, this is needed as dataset keeps being modified
if os.path.exists(save_path):
    os.remove(save_path)
    
fees_df.to_csv(save_path, index=False)

# %%
price_history_df

import os # package for checking/ removing file
save_path = 'D:/dataSets/msc_group_project/price_history.csv'

# delete file path if it exists, this is needed as dataset keeps being modified
if os.path.exists(save_path):
    os.remove(save_path)
    
price_history_df.to_csv(save_path, index=False)

# %%
schools_nearby_df

import os # package for checking/ removing file
save_path = 'D:/dataSets/msc_group_project/nearby_schools.csv'

# delete file path if it exists, this is needed as dataset keeps being modified
if os.path.exists(save_path):
    os.remove(save_path)
    
schools_nearby_df.to_csv(save_path, index=False)
