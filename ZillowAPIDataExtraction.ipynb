# %%
import requests

url = "https://zillow-com1.p.rapidapi.com/propertyExtendedSearch"

querystring = {"location":"baltimore, md","page":"1","status_type":"ForRent"}

headers = {
    "X-RapidAPI-Key": "0f64ef61f3msh8589bcbe6519721p1fd4adjsn7b6792b52973",
    "X-RapidAPI-Host": "zillow-com1.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())

json.load()
# Out:
# {'props': [{'units': [{'beds': '1', 'price': '$1,199+'}], 'listingStatus': 'FOR_RENT', 'zpid': '39.308994--76.62804', 'longitude': -76.62804, 'buildingName': 'Bolton St 1713', 'address': '1713 Bolton St, Baltimore, MD', 'detailUrl': '/b/bolton-st-1713-baltimore-md-5j8728/', 'isBuilding': True, 'hasImage': True, 'lotId': 1049911687, 'imgSrc': 'https://photos.zillowstatic.com/fp/e3819b051b082ceecf67c8c86e47360f-p_e.jpg', 'latitude': 39.308994}, {'units': [{'beds': '0', 'price': '$930+'}, {'beds': '1', 'price': '$1,347+'}], 'listingStatus': 'FOR_RENT', 'zpid': '39.289722--76.61699', 'longitude': -76.61699, 'buildingName': 'Vivo Living Baltimore', 'address': '101 W Fayette St, Baltimore, MD', 'detailUrl': '/apartments/baltimore-md/vivo-living-baltimore/9PcnGx/', 'isBuilding': True, 'hasImage': True, 'lotId': 2090479304, 'imgSrc': 'https://photos.zillowstatic.com/fp/a7568313a2fe28ec2a0df7d516227dac-p_e.jpg', 'latitude': 39.289722}, {'units': [{'beds': '0', 'price': '$830+'}, {'beds': '1', 'price': '$930+'}, {'beds': '2', 'price': '$1,130+'}], 'listingStatus': 'FOR_RENT', 'zpid': '39.339527--76.601456', 'longitude': -76.601456, 'buildingName': 'Maplewood Apartments', 'address': '956 Argonne Dr, Baltimore, MD', 'detailUrl': '/apartments/baltimore-md/maplewood-apartments/5Xt94F/', 'isBuilding': True, 'hasImage': True, 'lotId': 1002386396, 'imgSrc': 'https://photos.zillowstatic.com/fp/fc2da78a5219a7153981fdb1dd429e8e-p_e.jpg', 'latitude': 39.339527}, {'units': [{'beds': '1', 'price': '$988+'}, {'beds': '2', 'price': '$1,583+'}, {'beds': '3', 'price': '$1,835+'}], 'listingStatus': 'FOR_RENT', 'zpid': '39.366913--76.58104', 'longitude': -76.58104, 'buildingName': 'The Renaissance Club', 'address': '1712 Waverly Way, Baltimore, MD', 'detailUrl': '/apartments/baltimore-md/the-renaissance-club/5Xt3yT/', 'isBuilding': True, 'hasImage': True, 'lotId': 1002374207, 'imgSrc': 'https://photos.zillowstatic.com/fp/01bb80ae9214483048c82a3b968377bb-p_e.jpg', 'latitude': 39.366913}, {'units': [{'beds': '1', 'price': '$1,225+'}, {'beds': '2', 'price': '$1,395+'}, {'beds': '3', 'price': '$1,800+'}], 'listingStatus': 'FOR_RENT', 'zpid': '39.370182--76.682945', 'longitude': -76.682945, 'buildingName': 'Flora Park', 'address': '6310 Greenspring Ave, Baltimore, MD', 'detailUrl': '/apartments/baltimore-md/flora-park/5Xt3bV/', 'isBuilding': True, 'hasImage': True, 'lotId': 1002373326, 'imgSrc': 'https://photos.zillowstatic.com/fp/a48bfc49573a605a3acb80effb402127-p_e.jpg', 'latitude': 39.370182}, {'units': [{'beds': '0', 'price': '$1,835+'}, {'beds': '1', 'price': '$2,085+'}, {'beds': '2', 'price': '$3,500+'}], 'listingStatus': 'FOR_RENT', 'zpid': '39.283234--76.58841', 'longitude': -76.58841, 'buildingName': 'Elms Fells Point', 'address': '2001 Aliceanna St, Baltimore, MD', 'detailUrl': '/apartments/baltimore-md/elms-fells-point/5YYqRv/', 'isBuilding': True, 'hasImage': True, 'lotId': 1006349010, 'imgSrc': 'https://photos.zillowstatic.com/fp/cf24caf418ad193c1e1006ccd9f9cf31-p_e.jpg', 'latitude': 39.283234}, {'units': [{'beds': '0', 'price': '$1,674+'}, {'beds': '1', 'price': '$1,588+'}, {'beds': '2', 'price': '$2,519+'}], 'listingStatus': 'FOR_RENT', 'zpid': '39.26839--76.59934', 'longitude': -76.59934, 'buildingName': 'McHenry Row', 'address': '1700 Whetstone Way, Baltimore, MD', 'detailUrl': '/apartments/baltimore-md/mchenry-row/5XrF4P/', 'isBuilding': True, 'hasImage': True, 'lotId': 1002160710, 'imgSrc': 'https://photos.zillowstatic.com/fp/4fe48247d917a72c5fb2962345db2dc2-p_e.jpg', 'latitude': 39.26839}, {'units': [{'beds': '0', 'price': '$1,610+'}, {'beds': '1', 'price': '$1,707+'}, {'beds': '2', 'price': '$2,147+'}], 'listingStatus': 'FOR_RENT', 'zpid': '39.268703--76.59835', 'longitude': -76.59835, 'buildingName': 'Porter Street', 'address': '1401 Porter St, Baltimore, MD', 'detailUrl': '/b/porter-street-middle-river-md-Bgt5Vy/', 'isBuilding': True, 'hasImage': True, 'lotId': 2455107758, 'imgSrc': 'https://photos.zillowstatic.com/fp/a5edf4d937f8e37d4a5 ...

# %%
import requests
import time

url = "https://zillow-com1.p.rapidapi.com/propertyExtendedSearch"

headers = {
    "X-RapidAPI-Key": "0f64ef61f3msh8589bcbe6519721p1fd4adjsn7b6792b52973",
    "X-RapidAPI-Host": "zillow-com1.p.rapidapi.com"
}

def extendedSearchQuery(current_page):
    querystring = {"location": "baltimore, md", "page": str(current_page), "status_type": "ForRent"}
    try:
        response = requests.get(url, headers=headers, params=querystring)
        if response.status_code == 200:
            return response
        else:
            return None
    except requests.exceptions.RequestException as e:
        print(f"An error occurred: {e}")
        return None

combined_data = {}
total_number_of_pages = 20
for i in range(total_number_of_pages):
    response = extendedSearchQuery(i + 1)
    if response is not None:
        page_data = response.json()
        
        # Check if 'props' exists in the response
        if "props" in page_data:
            page_props = page_data["props"]
            
            # Iterate through the props list on each page
            for prop in page_props:
                if "units" in prop:
                    # Get the units list
                    units = prop["units"]
                    
                    # Create temporary unit price keys based on the number of units
                    for idx, unit in enumerate(units):
                        num_bedrooms = int(unit['beds'])
                        price = unit['price']
                        key = f'unit_{num_bedrooms}_bedroom'
                        
                        # Update the prop dictionary with the individual unit keys
                        prop[key] = price
                    
                    # Remove the original "units" key
                    del prop["units"]
        
        combined_data["Page " + str(i + 1)] = page_data
    else:
        # Handle the case where the request failed
        combined_data["Page " + str(i + 1)] = "Request failed"

    if i % 2 == 0 and i <= total_number_of_pages:
        # If we have made 2 requests and it's not the last iteration, sleep for 1 second
        time.sleep(2)

# %% [markdown]
# Save file to json so that code doesn't need to make call to api everytime notebook is used

# %%
combined_data

file_path = "D:/DataSets/combined_data.json"  # Replace with your desired file path

with open(file_path, "w") as json_file:
    json.dump(combined_data, json_file)

# %%
file_path = "D:/DataSets/combined_data.json" 

with open(file_path, "r") as json_file:
    combined_data = json.load(json_file)
# Out:
# dict

# %%
combined_data
# Out:
# {'Page 1': {'props': [{'listingStatus': 'FOR_RENT',
#     'zpid': '39.28158--76.61414',
#     'longitude': -76.61414,
#     'buildingName': 'Arrive Federal Hill',
#     'address': '611 S Charles St, Baltimore, MD',
#     'detailUrl': '/apartments/baltimore-md/arrive-federal-hill/9PdKvk/',
#     'isBuilding': True,
#     'hasImage': True,
#     'lotId': 2090543288,
#     'imgSrc': 'https://photos.zillowstatic.com/fp/56d7660181c7479269bef36e6f5c048c-p_e.jpg',
#     'latitude': 39.28158,
#     'unit_0_bedroom': '$1,765+',
#     'unit_1_bedroom': '$1,685+',
#     'unit_2_bedroom': '$2,424+'},
#    {'listingStatus': 'FOR_RENT',
#     'zpid': '39.288685--76.620094',
#     'longitude': -76.620094,
#     'buildingName': 'Redwood Campus Center',
#     'address': '300 W Redwood St, Baltimore, MD',
#     'detailUrl': '/apartments/baltimore-md/redwood-campus-center/ByN4cS/',
#     'isBuilding': True,
#     'hasImage': True,
#     'lotId': 2532871615,
#     'imgSrc': 'https://photos.zillowstatic.com/fp/4944c97ead4f910291e2064476797f10-p_e.jpg',
#     'latitude': 39.288685,
#     'unit_0_bedroom': '$1,500+',
#     'unit_1_bedroom': '$1,795+'},
#    {'listingStatus': 'FOR_RENT',
#     'zpid': '39.335617--76.6207',
#     'longitude': -76.6207,
#     'buildingName': 'Broadview Apartments',
#     'address': '105 W 39th St, Baltimore, MD',
#     'detailUrl': '/apartments/baltimore-md/broadview-apartments/5Xhv8S/',
#     'isBuilding': True,
#     'hasImage': True,
#     'lotId': 1001416599,
#     'imgSrc': 'https://photos.zillowstatic.com/fp/078d5b0a63bd992d7b0bc0d3d0ce5f3b-p_e.jpg',
#     'latitude': 39.335617,
#     'unit_0_bedroom': '$1,270+',
#     'unit_1_bedroom': '$1,540+',
#     'unit_2_bedroom': '$2,750+'},
#    {'listingStatus': 'FOR_RENT',
#     'zpid': '39.292084--76.61599',
#     'longitude': -76.61599,
#     'buildingName': 'The Apartments at Charles Plaza',
#     'address': '222 N Charles St, Baltimore, MD',
#     'detailUrl': '/apartments/baltimore-md/the-apartments-at-charles-plaza/5XhvHB/',
#     'isBuilding': True,
#     'hasImage': True,
#     'lotId': 1001416928,
#     'imgSrc': 'https://photos.zillowstatic.com/fp/759d2919183579b4c3151fe7e67483f2-p_e.jpg',
#     'latitude': 39.292084,
#     'unit_0_bedroom': '$1,068+',
#     'unit_1_bedroom': '$1,170+',
#     'unit_2_bedroom': '$1,506+'},
#    {'listingStatus': 'FOR_RENT',
#     'zpid': '39.377323--76.66296',
#     'longitude': -76.66296,
#     'buildingName': 'Copper Village and Quarry Village',
#     'address': '6617 Bonnie Ridge Dr, Baltimore, MD',
#     'detailUrl': '/apartments/pikesville-md/copper-village-and-quarry-village/5Xhv9s/',
#     'isBuilding': True,
#     'hasImage': True,
#     'lotId': 1001416668,
#     'imgSrc': 'https://photos.zillowstatic.com/fp/4c51f468da9dafb84d6c2ccb2aed9e00-p_e.jpg',
#     'latitude': 39.377323,
#     'unit_1_bedroom': '$1,192+',
#     'unit_2_bedroom': '$1,358+',
#     'unit_3_bedroom': '$1,748+'},
#    {'listingStatus': 'FOR_RENT',
#     'zpid': '39.289722--76.61699',
#     'longitude': -76.61699,
#     'buildingName': 'Vivo Living Baltimore',
#     'address': '101 W Fayette St, Baltimore, MD',
#     'detailUrl': '/apartments/baltimore-md/vivo-living-baltimore/9PcnGx/',
#     'isBuilding': True,
#     'hasImage': True,
#     'lotId': 2090479304,
#     'imgSrc': 'https://photos.zillowstatic.com/fp/a7568313a2fe28ec2a0df7d516227dac-p_e.jpg',
#     'latitude': 39.289722,
#     'unit_0_bedroom': '$930+',
#     'unit_1_bedroom': '$1,347+'},
#    {'listingStatus': 'FOR_RENT',
#     'zpid': '39.28329--76.7084',
#     'longitude': -76.7084,
#     'buildingName': 'Jamestowne Apartments',
#     'address': '5364 Jamestowne Ct, Baltimore, MD',
#     'detailUrl': '/apartments/baltimore-md/jamestowne-apartments/5XrhxH/',
#     'isBuilding': True,
#     'hasImage': True,
#     'lotId': 1002218083,
#     'imgSrc': 'https://photos.zillowstatic.com/fp/e7c9506ce5c2a9cca364c0580cb4d967-p_e.jpg',
#     'latitude': 39.28329,
#     'unit_0_bedroom': '$935+',
#     'unit_2_bedroom': '$1,340+',
#     'unit_3_bedroom': '$1,530+'},
#    {'listingStatus': 'FOR_RENT',
#     'zpid': '39.31938--76.7026',
#     'longitude': -76.7026,
#     'buildingName': 'Fairway Ridge Apartments and Townhomes',
#     'address': '4998 W Forest Park Ave, Gwynn Oak, MD',
#     'detailUrl': '/apartments/baltimore-md/fairway-ridge-apartments-and-townhomes/BMPh89/',
#     'isBuilding': True,
#     'hasImage': True,
#     'lotId': 2360120875,
#     'imgSrc': 'https://photos.zillowstatic.com/fp/5b47963920e881829ebab8f1428d9b25-p_e.jpg',
#     'latitude': 39.31938,
#     'unit_0_bedroom': '$1,100+',
#     'unit_2_bedroom': '$1,305+',
#     'unit_3_bedroom': '$1,595+'},
#    {'listingStatus': 'FOR_RENT',
#     'zpid': '39.339527--76.601456',
#     'longitude': -76.601456,
#     'buildingName': 'Maplewood Apartments',
#     'address': '956 Argonne Dr, Baltimore, MD',
#     'detailUrl': '/apartments/baltimore-md/maplewood-apartments/5Xt94F/',
#     'isBuilding': True,
#     'hasImage': True,
#     'lotId': 1002386396,
#     'imgSrc': 'https://photos.zillowstatic.com/fp/fc2da78a5219a7153981fdb1dd429e8e-p_e.jpg',
#     'latitude': 39.339527,
#     'unit_0_bedroom': '$830+',
#     'unit_1_bedroom': '$930+',
#     'unit_2_bedroom': '$1,130+'},
#    {'listingStatus': 'FOR_RENT',
#     'zpid': '39.253685--76.651726',
#     'longitude': -76.651726,
#     'buildingName': 'Arbuta Arms Apartments*',
#     'address': '2600 W Patapsco Ave, Baltimore, MD',
#     'detailUrl': '/apartments/baltimore-md/arbuta-arms-apartments*/5XhvDC/',
#     'isBuilding': True,
#     'hasImage': True,
#     'lotId': 1001416782,
#     'imgSrc': 'https://photos.zillowstatic.com/fp/dc611e565114681c2b9da7d59ea15088-p_e.jpg',
#     'latitude': 39.253685,
#     'unit_1_bedroom': '$1,058+',
#     'unit_2_bedroom': '$1,138+'},
#    {'listingStatus': 'FOR_RENT',
#     'zpid': '39.347942--76.59814',
#     'longitude': -76.59814,
#     'buildingName': 'Winston Apartments',
#     'address': '1260 Rossiter Ave, Baltimore, MD',
#     'detailUrl': '/apartments/baltimore-md/winston-apartments/5XrHBj/',
#     'isBuilding': True,
#     'hasImage': True,
#     'lotId': 1002165822,
#     'imgSrc': 'https://photos.zillowstatic.com/fp/a4d32f516468058789e487e26b170686-p_e.jpg',
#     'latitude': 39.347942,
#     'unit_2_bedroom': '$1,050+'},
#    {'listingStatus': 'FOR_RENT',
#     'zpid': '39.287617--76.622',
#     'longitude': -76.622,
#     'buildingName': 'Marlboro Classic Apt & Redwood Square',
#     'address': '410 W Lombard St, Baltimore, MD',
#     'detailUrl': '/apartments/baltimore-md/marlboro-classic-apt-%26-redwood-square/5XnsKY/',
#     'isBuilding': True,
#     'hasImage': True,
#     'lotId': 1001882839,
#     'imgSrc': 'https://photos.zillowstatic.com/fp/de8c20ad33f16500ad8bc21c2cb16374-p_e.jpg',
#     'latitude': 39.287617,
#     'unit_0_bedroom': '$1,171+',
#     'unit_1_bedroom': '$1,276+',
#     'unit_2_bedroom': '$1,596+'},
#    {'listingStatus': 'FOR_RENT',
#     'zpid': '39.305336--76.614426',
#     'longitude': -76.614426,
#     'buildingName': 'The Mount Royal',
#     'address': '103 E Mount Royal Ave, Baltimore, MD',
#     'detailUrl': '/apartments/baltimore-md/the-mount-royal/5hJhz7/',
#     'isBuilding': True,
#     'hasImage': True,
#     'lotId': 1045160058,
#     'imgSrc': 'https://photos.zillowstatic.com/fp/9b0ded15774d378426fcd4e0a3947485-p_e.jpg',
#     'latitude': 39.305336,
#     'unit_0_bedroom': '$1,398+',
#     'unit_1_bedroom': '$1,788+'},
#    {'listingStatus': 'FOR_RENT',
#     'zpid': '39.3698--76.67563',
#     'longitude': -76.67563,
#     'buildingName': 'Falls Village Apartments',
#     'address': '6222 Green Meadow Pkwy, Baltimore, MD',
#     'detailUrl': '/apartments/baltimore-md/falls-village-apartments/5XtNSG/',
#     'isBuilding': True,
#     'hasImage': True,
#     'lotId': 1002413788,
#     'imgSrc': 'https://photos.zillowstatic.com/fp/0eae3990031a0d4e0069c6a53a5c9293-p_e.jpg',
#     'latitude': 39.3698,
#     'unit_1_bedroom': '$1,180+',
#     'unit_2_bedroom': '$1,315+'},
#    {'listingStatus': 'FOR_RENT',
#     'zpid': '39.36707--76.69338',
#     'longitude': -76.69338,
#     'buildingName': 'Cross Country Manor Apartments',
#     'address': '3301 Clarks Ln, Baltimore, MD',
#     'detailUrl': '/apartments/baltimore-md/cross-country-manor-apartments/5XhvFv/',
#     'isBuilding': True,
#     'hasImage': True,
#     'lotId': 1001416866,
#     'imgSrc': 'https://photos.zillowstatic.com/fp/427ec5ace632ba508edebcc8ace74ebd-p_e.jpg',
#     'latitude': 39.36707,
#     'unit_1_bedroom': '$1,165+',
#     'unit_2_bedroom': '$1,275+'},
#    {'listingStatus': 'FOR_RENT',
#     'zpid': '39.283234--76.58841',
#     'longitude': -76.58841,
#     'buildingName': 'Elms Fells Point',
#     'address': '2001 Aliceanna St, Baltimore, MD',
#     'detailUrl': '/apartments/baltimore-md/elms-fells-point/5YYqRv/',
#     'isBuilding': True,
#     'hasImage': True,
#     'lotId': 1006349010,
#     'imgSrc': 'https://photos.zillowstatic.com/fp/cf24caf418ad193c1e1006ccd9f9cf31-p_e.jpg',
#     'latitude': 39.283234,
#     'unit_0_bedroom': '$1,835+',
#     'unit_1_bedroom': '$2,085+',
#     'unit_2_bedroom': '$3,500+'},
#    {'listingStatus': 'FOR_RENT',
#     'zpid': '39.284973--76.60259',
#     'longitude': -76.60259,
#     'buildingName': 'Avalon 555 President',
#     'address': '555 President St, Baltimore, MD',
#     'detailUrl': '/apartments/baltimore-md/avalon-555-president/BMBRwx/',
#     'isBuilding': True,
#     'hasImage': True,
#     'lotId': 2358797473,
#     'imgSrc': 'https://photos.zillowstatic.com/fp/a840054664282b54c864c0e05757a1ce-p_e.jpg',
#     'latitude': 39.284973,
#     'unit_0_bedroom': '$1,855+',
#     'unit_1_bedroom': '$2,075+',
#     'unit_2_bedroom': '$3,095+',
#     'unit_3_bedroom': '$3,750+'},
#    {'dateSold': None,
#     'propertyType': 'SINGLE_FAMILY',
#     'lotAreaValue': None,
#     'address': '5111 Woolverton Ave, Baltimore, MD 21215',
#     'variableData': None,
#     'zestimate': 128000,
#     'imgSrc': 'https://photos.zillowstatic.com/fp/432ab1f615d61e85bad2f1854c265cdc-p_e.jpg',
#     'price': 1800,
#     'detailUrl': '/homedetails/5111-Woolverton-Ave-Baltimore-MD-21215/36595746_zpid/',
#     'bedrooms': 3,
#     'contingentListingType': None,
#     'longitude': -76.66987,
#     'latitude': 39.351593,
#     'listingStatus': 'FOR_RENT',
#     'zpid': '36595746',
#     'listingSubType': {},
#     'rentZestimate': 1736,
#     'daysOnZillow': 1,
#     'bathrooms': 2,
#     'livingArea': 1248,
#     'country': 'USA',
#     'currency': 'USD',
#     'lotAreaUnit': None,
#     'hasImage': True},
#    {'listingStatus': 'FOR_RENT',
#     'zpid': '39.307278--76.57543',
#     'longitude': -76.57543,
#     'buildingName': '1401 North Potomac Street - Studio',
#     'address': '1401 N Potomac St, Baltimore, MD',
#     'detailUrl': '/b/1401-north-potomac-street-1-baltimore-md-5j88j6/',
#     'isBuilding': True,
#     'hasImage': True,
#     'lotId': 1049915801,
#     'imgSrc': 'https://photos.zillowstatic.com/fp/6e2afcd914aac8cc37315bc69c3e3152-p_e.jpg',
#     'latitude': 39.307278,
#     'unit_1_bedroom': '$900+'},
#    {'dateSold': None,
#     'propertyType': 'SINGLE_FAMILY',
#     'lotAreaValue': None,
#     'address': '910 N Calvert St, Baltimore, MD 21202',
#     'variableData': None,
#     'zestimate': 467000,
#     'imgSrc': 'https://photos.zillowstatic.com/fp/9949aad066418d9a6be036e9ace57e03-p_e.jpg',
#     'price': 3200,
#     'detailUrl': '/homedetails/910-N-Calvert-St-Baltimore-MD-21202/122476484_zpid/',
#     'bedrooms': 7,
#     'contingentListingType': None,
#     'longitude': -76.61338,
#     'latitude': 39.300182,
#     'listingStatus': 'FOR_RENT',
#     'zpid': '122476484',
#     'listingSubType': {},
#     'rentZestimate': 3244,
#     'daysOnZillow': 1,
#     'bathrooms': 2.5,
#     'livingArea': 3500,
#     'country': 'USA',
#     'currency': 'USD',
#     'lotAreaUnit': None,
#     'hasImage': True},
#    {'listingStatus': 'FOR_RENT',
#     'zpid': '39.29264--76.61161',
#     'longitude': -76.61161,
#     'buildingName': '222 Saratoga',
#     'address': '222 E Saratoga St, Baltimore, MD',
#     'detailUrl': '/apartments/baltimore-md/222-saratoga/5XrH3P/',
#     'isBuilding': True,
#     'hasImage': True,
#     'lotId': 1002165463,
#     'imgSrc': 'https://photos.zillowstatic.com/fp/8ab91bb6d8c72c2fdd3408f84ff165f2-p_e.jpg',
#     'latitude': 39.29264,
#     'unit_0_bedroom': '$1,520+',
#     'unit_1_bedroom': '$1,730+',
#     'unit_2_bedroom': '$1,975+'},
#    {'dateSold': None,
#     'propertyType': 'TOWNHOUSE',
#     'lotAreaValue': None,
#     'address': '1656 Wadsworth Way, Baltimore, MD 21239',
#     'variableData': None,
#     'zestimate': 207500,
#     'imgSrc': 'https://photos.zillowstatic.com/fp/78a7b51c4e92afe9d4a3154c742019f3-p_e.jpg',
#     'price': 1850,
#     'detailUrl': '/homedetails/1656-Wadsworth-Way-Baltimore-MD-21239/36619950_zpid/',
#     'bedrooms': 3,
#     'contingentListingType': None,
#     'longitude': -76.58054,
#     'latitude': 39.361797,
#     'listingStatus': 'FOR_RENT',
#     'zpid': '36619950',
#     'listingSubType': {},
#     'rentZestimate': 2250,
#     'daysOnZillow': 1,
#     'bathrooms': 1,
#     'livingArea': 1520,
#     'country': 'USA',
#     'currency': 'USD',
#     'lotAreaUnit': None,
#     'hasImage': True},
#    {'dateSold': None,
#     'propertyType': 'APARTMENT',
#     'lotAreaValue': None,
#     'address': '2 bed, 1.0 bath, $1,099, 3612 Brooklyn Ave #B, Brooklyn, MD 21225',
#     'variableData': None,
#     'unit': '# B',
#     'zestimate': None,
#     'imgSrc': 'https://photos.zillowstatic.com/fp/604b6921f60f71aa8cc54cfbf3c4fd5f-p_e.jpg',
#     'price': 1099,
#     'detailUrl': '/b/2-bed,-1.0-bath,-%241,099-baltimore-md-99MTb5/',
#     'bedrooms': 2,
#     'contingentListingType': None,
#     'longitude': -76.59986,
#     'latitude': 39.23494,
#     'listingStatus': 'FOR_RENT',
#     'zpid': '2055277637',
#     'listingSubType': {},
#     'rentZestimate': None,
#     'daysOnZillow': 1,
#     'bathrooms': 1,
#     'livingArea': None,
#     'country': 'USA',
#     'currency': 'USD',
#     'lotAreaUnit': None,
#     'hasImage': True},
#    {'dateSold': None,
#     'propertyType': 'SINGLE_FAMILY',
#     'lotAreaValue': None,
#     'address': '3200 Chelsea Ter, Baltimore, MD 21216',
#     'variableData': None,
#     'zestimate': 429800,
#     'imgSrc': 'https://photos.zillowstatic.com/fp/348790832b613a3761d2ae7d91c861dd-p_e.jpg',
#     'price': 4300,
#     'detailUrl': '/homedetails/3200-Chelsea-Ter-Baltimore-MD-21216/36489308_zpid/',
#     'bedrooms': 7,
#     'contingentListingType': None,
#     'longitude': -76.68368,
#     'latitude': 39.323837,
#     'listingStatus': 'FOR_RENT',
#     'zpid': '36489308',
#     'listingSubType': {},
#     'rentZestimate': 3652,
#     'daysOnZillow': 1,
#     'bathrooms': 5,
#     'livingArea': 2978,
#     'country': 'USA',
#     'currency': 'USD',
#     'lotAreaUnit': None,
#     'hasImage': True},
#    {'dateSold': None,
#     'propertyType': 'SINGLE_FAMILY',
#     'lotAreaValue': None,
#     'address': '2005 N Wolfe St, Baltimore, MD 21213',
#     'variableData': None,
#     'zestimate': 98800,
#     'imgSrc': 'https://photos.zillowstatic.com/fp/27f55443c4aa2620bc9eb3eb72c6f1fd-p_e.jpg',
#     'price': 1849,
#     'detailUrl': '/homedetails/2005-N-Wolfe-St-Baltimore-MD-21213/36447466_zpid/',
#     'bedrooms': 4,
#     'contingentListingType': None,
#     'longitude': -76.59144,
#     'latitude': 39.31349,
#     'listingStatus': 'FOR_RENT',
#     'zpid': '36447466',
#     'listingSubType': {},
#     'rentZestimate': 1936,
#     'daysOnZillow': 1,
#     'bathrooms': 2,
#     'livingArea': None,
#     'country': 'USA',
#     'currency': 'USD',
#     'lotAreaUnit': None,
#     'hasImage': True},
#    {'dateSold': None,
#     'propertyType': 'SINGLE_FAMILY',
#     'lotAreaValue': None,
#     'address': '3408 W Mulberry St, Baltimore, MD 21229',
#     'variableData': None,
#     'zestimate': 92700,
#     'imgSrc': 'https://photos.zillowstatic.com/fp/09ea454b66b8c1cdb83fbadf0db75cee-p_e.jpg',
#     'price': 1499,
#     'detailUrl': '/homedetails/3408-W-Mulberry-St-Baltimore-MD-21229/36529692_zpid/',
#     'bedrooms': 3,
#     'contingentListingType': None,
#     'longitude': -76.67498,
#     'latitude': 39.292065,
#     'listingStatus': 'FOR_RENT',
#     'zpid': '36529692',
#     'listingSubType': {},
#     'rentZestimate': 1500,
#     'daysOnZillow': 1,
#     'bathrooms': 1,
#     'livingArea': None,
#     'country': 'USA',
#     'currency': 'USD',
#     'lotAreaUnit': None,
#     'hasImage': True},
#    {'listingStatus': 'FOR_RENT',
#     'zpid': '39.278637--76.69517',
#     'longitude': -76.69517,
#     'buildingName': 'Caral Gardens Apartments and Townhomes',
#     'address': '402 Colleen Rd, Baltimore, MD',
#     'detailUrl': '/apartments/baltimore-md/caral-gardens-apartments-and-townhomes/5XhvG6/',
#     'isBuilding': True,
#     'hasImage': True,
#     'lotId': 1001416875,
#     'imgSrc': 'https://photos.zillowstatic.com/fp/7b60c11cd054f7f51349ed9f9c547426-p_e.jpg',
#     'latitude': 39.278637,
#     'unit_1_bedroom': '$1,030+',
#     'unit_2_bedroom': '$1,320+'},
#    {'listingStatus': 'FOR_RENT',
#     'zpid': '39.28593--76.687126',
#     'longitude': -76.687126,
#     'buildingName': 'Woodington West Apartments',
#     'address': '2 N Woodington Rd, Baltimore, MD',
#     'detailUrl': '/b/woodington-west-apartments-baltimore-md-9PdHxw/',
#     'isBuilding': True,
#     'hasImage': True,
#     'lotId': 2090538593,
#     'imgSrc': 'https://photos.zillowstatic.com/fp/9d7835d01a780d5c89ba2646518f582e-p_e.jpg',
#     'latitude': 39.28593,
#     'unit_1_bedroom': '$1,175+',
#     'unit_2_bedroom': '$1,280+'},
#    {'listingStatus': 'FOR_RENT',
#     'zpid': '39.277287--76.69793',
#     'longitude': -76.69793,
#     'buildingName': 'Williston Apartments & Townhomes',
#     'address': '501 Hazlett Ave, Baltimore, MD',
#     'detailUrl': '/b/williston-apartments-%26-townhomes-baltimore-md-99Mpf4/',
#     'isBuilding': True,
#     'hasImage': True,
#     'lotId': 2019775592,
#     'imgSrc': 'https://photos.zillowstatic.com/fp/c5ae14b8e30cb7952d215f720f9591ea-p_e.jpg',
#     'latitude': 39.277287,
#     'unit_2_bedroom': '$1,315+',
#     'unit_3_bedroom': '$1,580+'},
#    {'listingStatus': 'FOR_RENT',
#     'zpid': '39.28621--76.54855',
#     'longitude': -76.54855,
#     'buildingName': 'Lofts at Yard 56',
#     'address': '560 Bayview Blvd, Baltimore, MD',
#     'detailUrl': '/apartments/baltimore-md/lofts-at-yard-56/CYsNFj/',
#     'isBuilding': True,
#     'hasImage': True,
#     'lotId': 2702911918,
#     'imgSrc': 'https://photos.zillowstatic.com/fp/75bfae5ed2d4e5402d51f39eec30a172-p_e.jpg',
#     'latitude': 39.28621,
#     'unit_1_bedroom': '$1,540+',
#     'unit_2_bedroom': '$2,225+',
#     'unit_3_bedroom': '$3,315+'},
#    {'listingStatus': 'FOR_RENT',
#     'zpid': '39.25187--76.61695',
#     'longitude': -76.61695,
#     'buildingName': 'Middle Branch Manor',
#     'address': '2868 Potee St, Brooklyn, MD',
#     'detailUrl': '/apartments/baltimore-md/middle-branch-manor/5XzPsN/',
#     'isBuilding': True,
#     'hasImage': True,
#     'lotId': 1003005420,
#     'imgSrc': 'https://photos.zillowstatic.com/fp/78a22ad536e8521fa82481a628ddcd1a-p_e.jpg',
#     'latitude': 39.25187,
#     'unit_1_bedroom': '$1,029+',
#     'unit_2_bedroom': '$1,049+',
#     'unit_3_bedroom': '$1,289+'},
#    {'listingStatus': 'FOR_RENT',
#     'zpid': '39.309673--76.70236',
#     'longitude': -76.70236,
#     'buildingName': 'Windsor Forest',
#     'address': '5006 Windsor Mill Rd, Gwynn Oak, MD',
#     'detailUrl': '/apartments/baltimore-md/windsor-forest/5YyC5Y/',
#     'isBuilding': True,
#     'hasImage': True,
#     'lotId': 1008626660,
#     'imgSrc': 'https://photos.zillowstatic.com/fp/97c146146dafeaa144afe300fca96a3d-p_e.jpg',
#     'latitude': 39.309673,
#     'unit_1_bedroom': '$1,129+',
#     'unit_2_bedroom': '$1,229+',
#     'unit_3_bedroom': '$1,589+'},
#    {'listingStatus': 'FOR_RENT',
#     'zpid': '39.29312--76.6154',
#     'longitude': -76.6154,
#     'buildingName': 'Browns Arcade (Residential)',
#     'address': '324 N Charles St, Baltimore, MD',
#     'detailUrl': '/b/browns-arcade-%28residential%29-baltimore-md-CYxhM4/',
#     'isBuilding': True,
#     'hasImage': True,
#     'lotId': 2703421191,
#     'imgSrc': 'https://photos.zillowstatic.com/fp/daf131a1ff989260fd745c384c023dbc-p_e.jpg',
#     'latitude': 39.29312,
#     'unit_1_bedroom': '$1,290+',
#     'unit_2_bedroom': '$1,690+',
#     'unit_3_bedroom': '$2,090+'},
#    {'listingStatus': 'FOR_RENT',
#     'zpid': '39.29227--76.61243',
#     'longitude': -76.61243,
#     'buildingName': '225 N Calvert',
#     'address': '225 N Calvert St, Baltimore, MD',
#     'detailUrl': '/apartments/baltimore-md/225-n-calvert/9v3qb4/',
#     'isBuilding': True,
#     'hasImage': True,
#     'lotId': 2231193099,
#     'imgSrc': 'https://photos.zillowstatic.com/fp/6c9642821c04fd195e7ca034423f8760-p_e.jpg',
#     'latitude': 39.29227,
#     'unit_1_bedroom': '$1,579+',
#     'unit_2_bedroom': '$2,267+'},
#    {'dateSold': None,
#     'propertyType': 'APARTMENT',
#     'lotAreaValue': None,
#     'address': '817 S Bond Street Unit 2, 817 S Bond St, Baltimore, MD 21231',
#     'variableData': None,
#     'zestimate': None,
#     'imgSrc': 'https://photos.zillowstatic.com/fp/cd8dae8edaf24585ab4dcf4aa4e30538-p_e.jpg',
#     'price': 1700,
#     'detailUrl': '/homedetails/817-S-Bond-St-Baltimore-MD-21231/36435285_zpid/',
#     'bedrooms': 2,
#     'contingentListingType': None,
#     'longitude': -76.59485,
#     'latitude': 39.281986,
#     'listingStatus': 'FOR_RENT',
#     'zpid': '36435285',
#     'listingSubType': {},
#     'rentZestimate': 1343,
#     'daysOnZillow': 1,
#     'bathrooms': 1,
#     'livingArea': 900,
#     'country': 'USA',
#     'currency': 'USD',
#     'lotAreaUnit': None,
#     'hasImage': True},
#    {'dateSold': None,
#     'propertyType': 'APARTMENT',
#     'lotAreaValue': None,
#     'address': '817 S Bond Street Unit 2, 817 S Bond St #277D59571, Baltimore, MD 21231',
#     'variableData': None,
#     'unit': '# 277D59571',
#     'zestimate': None,
#     'imgSrc': 'https://photos.zillowstatic.com/fp/e5a87690a84431d6334919535c51f538-p_e.jpg',
#     'price': 1550,
#     'detailUrl': '/b/817-s-bond-street-unit-2-baltimore-md-9PdMXV/',
#     'bedrooms': 1,
#     'contingentListingType': None,
#     'longitude': -76.59485,
#     'latitude': 39.281986,
#     'listingStatus': 'FOR_RENT',
#     'zpid': '2055543639',
#     'listingSubType': {},
#     'rentZestimate': None,
#     'daysOnZillow': 1,
#     'bathrooms': 1,
#     'livingArea': 750,
#     'country': 'USA',
#     'currency': 'USD',
#     'lotAreaUnit': None,
#     'hasImage': True},
#    {'listingStatus': 'FOR_RENT',
#     'zpid': '39.28214--76.53441',
#     'longitude': -76.53441,
#     'buildingName': "6605 O'Donnell Street",
#     'address': '6605 Odonnell St, Baltimore, MD',
#     'detailUrl': '/b/6605-o%27donnell-street-baltimore-md-5rxM4B/',
#     'isBuilding': True,
#     'hasImage': True,
#     'lotId': 1089235365,
#     'imgSrc': 'https://photos.zillowstatic.com/fp/df7cb085d0000a46c51184c084b2c016-p_e.jpg',
#     'latitude': 39.28214,
#     'unit_1_bedroom': '$1,000+',
#     'unit_2_bedroom': '$1,125+'},
#    {'listingStatus': 'FOR_RENT',
#     'zpid': '39.32495--76.616295',
#     'longitude': -76.616295,
#     'buildingName': '3012 Saint Paul Street',
#     'address': '3012 Saint Paul St, Baltimore, MD',
#     'detailUrl': '/b/3012-saint-paul-street-baltimore-md-5j88zG/',
#     'isBuilding': True,
#     'hasImage': True,
#     'lotId': 1049916446,
#     'imgSrc': 'https://photos.zillowstatic.com/fp/a7233257cb21987a7b84074be8f0054b-p_e.jpg',
#     'latitude': 39.32495,
#     'unit_1_bedroom': '$1,150+'},
#    {'dateSold': None,
#     'propertyType': 'APARTMENT',
#     'lotAreaValue': None,
#     'address': '3038 St. Paul St., 3038 Saint Paul St APT 3, Baltimore, MD 21218',
#     'variableData': None,
#     'unit': 'Apt 3',
#     'zestimate': None,
#     'imgSrc': 'https://photos.zillowstatic.com/fp/36955a1d36570e60a610015b6d8688e3-p_e.jpg',
#     'price': 1195,
#     'detailUrl': '/b/3038-st.-paul-st.-baltimore-md-5XypQN/',
#     'bedrooms': 1,
#     'contingentListingType': None,
#     'longitude': -76.61633,
#     'latitude': 39.325592,
#     'listingStatus': 'FOR_RENT',
#     'zpid': '2089472172',
#     'listingSubType': {},
#     'rentZestimate': 1250,
#     'daysOnZillow': 1,
#     'bathrooms': 1,
#     'livingArea': None,
#     'country': 'USA',
#     'currency': 'USD',
#     'lotAreaUnit': None,
#     'hasImage': True},
#    {'dateSold': None,
#     'propertyType': 'APARTMENT',
#     'lotAreaValue': None,
#     'address': 'Hickory Heights Apartments, 4221-4233 Hickory Ave #F, Baltimore, MD 21211',
#     'variableData': None,
#     'unit': '# F',
#     'zestimate': None,
#     'imgSrc': 'https://photos.zillowstatic.com/fp/f33242ef8d235c67a4da920aaede5472-p_e.jpg',
#     'price': 1275,
#     'detailUrl': '/b/hickory-heights-apartments-baltimore-md-Bj5XQ2/',
#     'bedrooms': 2,
#     'contingentListingType': None,
#     'longitude': -76.63481,
#     'latitude': 39.334675,
#     'listingStatus': 'FOR_RENT',
#     'zpid': '2057316977',
#     'listingSubType': {},
#     'rentZestimate': 1175,
#     'daysOnZillow': 1,
#     'bathrooms': 1,
#     'livingArea': 650,
#     'country': 'USA',
#     'currency': 'USD',
#     'lotAreaUnit': None,
#     'hasImage': True},
#    {'dateSold': None,
#     'propertyType': 'APARTMENT',
#     'lotAreaValue': None,
#     'address': '1901 Gough Street, 1901 Gough St, Baltimore, MD 21231',
#     'variableData': None,
#     'zestimate': 606900,
#     'imgSrc': 'https://maps.googleapis.com/maps/api/staticmap?mobile=false&sensor=true&maptype=satellite&size=575x242&zoom=17&center=39.287574768066406,-76.5900650024414&key=AIzaSyBJsNQO5ZeG-XAbqqWLKwG08fWITSxg33w&signature=dJ8myGS4ySd30AaWJg8N2Ak9uO0=',
#     'price': 4400,
#     'detailUrl': '/homedetails/1901-Gough-St-Baltimore-MD-21231/36436238_zpid/',
#     'bedrooms': 0,
#     'contingentListingType': None,
#     'longitude': -76.590065,
#     'latitude': 39.287575,
#     'listingStatus': 'FOR_RENT',
#     'zpid': '36436238',
#     'listingSubType': {},
#     'rentZestimate': 4297,
#     'daysOnZillow': 1,
#     'bathrooms': 1,
#     'livingArea': 1250,
#     'country': 'USA',
#     'currency': 'USD',
#     'lotAreaUnit': None,
#     'hasImage': None}],
#   'resultsPerPage': 41,
#   'totalPages': 20,
#   'totalResultCount': 2303,
#   'schools': {},
#   'currentPage': 1},
#  'Page 2': {'props': [{'dateSold': None,
#     'propertyType': 'APARTMENT',
#     'lotAreaValue': None,
#     'address': "37th St W 902 - PM Hold All Funds - Funds Rec'd. 08/31/23, 902 W 37th St, Baltimore, MD 21211",
#     'variableData': None,
#     'zestimate': None,
#     'imgSrc': 'https://photos.zillowstatic.com/fp/68c26e4d735ff7012bbafe27d4863b88-p_e.jpg',
#     'price': 1075,
#     'detailUrl': '/homedetails/902-W-37th-St-Baltimore-MD-21211/36478383_zpid/',
#     'bedrooms': 1,
#     'contingentListingType': None,
#     'longitude': -76.6316,
#     'latitude': 39.33293,
#     'listingStatus': 'FOR_RENT',
#     'zpid': '36478383',
#     'listingSubType': {},
#     'rentZestimate': 1529,
#     'daysOnZillow': 1,
#     'bathrooms': 1,
#     'livingArea': None,
#     'country': 'USA',
#     'currency': 'USD',
#     'lotAreaUnit': None,
#     'hasImage': True},
#    {'listingStatus': 'FOR_RENT',
#     'zpid': '39.288425--76.62149',
#     'longitude': -76.62149,
#     'buildingName': '405 W Redwood Apartments',
#     'address': '405 W Redwood St, Baltimore, MD',
#     'detailUrl': '/b/405-w-redwood-apartments-baltimore-md-9Pcnw2/',
#     'isBuilding': True,
#     'hasImage': True,
#     'lotId': 2090480875,
#     'imgSrc': 'https://photos.zillowstatic.com/fp/9d77582b28d16ddac8ef3335d8a2778c-p_e.jpg',
#     'latitude': 39.288425,
#     'unit_0_bedroom': '$1,455+',
#     'unit_1_bedroom': '$1,474+'},
#    {'listingStatus': 'FOR_RENT',
#     'zpid': '39.280582--76.588036',
#     'longitude': -76.588036,
#     'buildingName': 'The Crescent at Fells Point by Windsor',
#     'address': '951 Fell St, Baltimore, MD',
#     'detailUrl': '/apartments/baltimore-md/the-crescent-at-fells-point-by-windsor/5XhvHf/',
#     'isBuilding': True,
#     'hasImage': True,
#     'lotId': 1001416952,
#     'imgSrc': 'https://photos.zillowstatic.com/fp/8392f9c242870a61f86d411ae93f7cb4-p_e.jpg',
#     'latitude': 39.280582,
#     'unit_1_bedroom': '$2,145+',
#     'unit_2_bedroom': '$2,625+'},
#    {'listingStatus': 'FOR_RENT',
#     'zpid': '39.30899--76.70826',
#     'longitude': -76.70826,
#     'buildingName': 'Gwynnbrook Townhomes',
#     'address': '5136 Oaklawn Rd, Gwynn Oak, MD',
#     'detailUrl': '/apartments/baltimore-md/gwynnbrook-townhomes/5YyCDT/',
#     'isBuilding': True,
#     'hasImage': True,
#     'lotId': 1008626999,
#     'imgSrc': 'https://photos.zillowstatic.com/fp/679370c1b0f537753bcc9727792c6b24-p_e.jpg',
#     'latitude': 39.30899,
#     'unit_1_bedroom': '$1,215+',
#     'unit_2_bedroom': '$1,290+',
#     'unit_3_bedroom': '$1,515+'},
#    {'listingStatus': 'FOR_RENT',
#     'zpid': '39.299053--76.61715',
#     'longitude': -76.61715,
#     'buildingName': 'Cathedral Commons',
#     'address': '511-513 Cathedral St, Baltimore, MD',
#     'detailUrl': '/b/cathedral-commons-baltimore-md-Bqmy38/',
#     'isBuilding': True,
#     'hasImage': True,
#     'lotId': 2494859947,
#     'imgSrc': 'https://photos.zillowstatic.com/fp/ba57faba04f5c3451d28527bec95f3a0-p_e.jpg',
#     'latitude': 39.299053,
#     'unit_0_bedroom': '$1,025+',
#     'unit_1_bedroom': '$1,400+'},
#    {'dateSold': None,
#     'propertyType': 'TOWNHOUSE',
#     'lotAreaValue': None,
#     'address': '415 N Collington Ave, Baltimore, MD 21231',
#     'variableData': None,
#     'zestimate': 334200,
#     'imgSrc': 'https://photos.zillowstatic.com/fp/3e1fd047fbf2040b49c5cbc374ee3dda-p_e.jpg',
#     'price': 1650,
#     'detailUrl': '/homedetails/415-N-Collington-Ave-Baltimore-MD-21231/36439179_zpid/',
#     'bedrooms': 3,
#     'contingentListingType': None,
#     'longitude': -76.58622,
#     'latitude': 39.2961,
#     'listingStatus': 'FOR_RENT',
#     'zpid': '36439179',
#     'listingSubType': {},
#     'rentZestimate': 1800,
#     'daysOnZillow': 1,
#     'bathrooms': 1.5,
#     'livingArea': 2010,
#     'country': 'USA',
#     'currency': 'USD',
#     'lotAreaUnit': None,
#     'hasImage': True},
#    {'listingStatus': 'FOR_RENT',
#     'zpid': '39.279465--76.563515',
#     'longitude': -76.563515,
#     'buildingName': 'Aura Brewers Hill',
#     'address': '1211 S Eaton St, Baltimore, MD',
#     'detailUrl': '/apartments/baltimore-md/aura-brewers-hill/BR5GWN/',
#     'isBuilding': True,
#     'hasImage': True,
#     'lotId': 2381245815,
#     'imgSrc': 'https://photos.zillowstatic.com/fp/04b222d1ad8462029e1320716f6791d5-p_e.jpg',
#     'latitude': 39.279465,
#     'unit_1_bedroom': '$1,655+',
#     'unit_2_bedroom': '$2,665+',
#     'unit_3_bedroom': '$3,825+'},
#    {'listingStatus': 'FOR_RENT',
#     'zpid': '39.2892--76.614105',
#     'longitude': -76.614105,
#     'buildingName': 'Arrive Inner Harbor',
#     'address': '10 Light St, Baltimore, MD',
#     'detailUrl': '/apartments/baltimore-md/arrive-inner-harbor/5Z7HmH/',
#     'isBuilding': True,
#     'hasImage': True,
#     'lotId': 1009461459,
#     'imgSrc': 'https://photos.zillowstatic.com/fp/58be93794b4b6f71e755704fbb3be2ad-p_e.jpg',
#     'latitude': 39.2892,
#     'unit_0_bedroom': '$1,285+',
#     'unit_1_bedroom': '$1,570+',
#     'unit_2_bedroom': '$2,540+'},
#    {'listingStatus': 'FOR_RENT',
#     'zpid': '39.297417--76.61307',
#     'longitude': -76.61307,
#     'buildingName': 'Waterloo Place Apartments',
#     'address': '690 N Calvert St, Baltimore, MD',
#     'detailUrl': '/apartments/baltimore-md/waterloo-place-apartments/5Xr8Cb/',
#     'isBuilding': True,
#     'hasImage': True,
#     'lotId': 1002149058,
#     'imgSrc': 'https://photos.zillowstatic.com/fp/b488222b7bba5f322303d3cf1bca2da6-p_e.jpg',
#     'latitude': 39.297417,
#     'unit_1_bedroom': '$1,441+',
#     'unit_2_bedroom': '$1,700+'},
#    {'listingStatus': 'FOR_RENT',
#     'zpid': '39.279285--76.562675',
#     'longitude': -76.562675,
#     'buildingName': 'The Lucie',
#     'address': '3850 Boston St, Baltimore, MD',
#     'detailUrl': '/apartments/baltimore-md/the-lucie/Bdp5G8/',
#     'isBuilding': True,
#     'hasImage': True,
#     'lotId': 2443106931,
#     'imgSrc': 'https://photos.zillowstatic.com/fp/419fc78b73e569846120784725ac7ecd-p_e.jpg',
#     'latitude': 39.279285,
#     'unit_0_bedroom': '$1,565+',
#     'unit_1_bedroom': '$1,948+',
#     'unit_2_bedroom': '$2,558+'},
#    {'listingStatus': 'FOR_RENT',
#     'zpid': '39.278893--76.56493',
#     'longitude': -76.56493,
#     'buildingName': 'The Porter Brewers Hill',
#     'address': '3700 Toone St, Baltimore, MD',
#     'detailUrl': '/apartments/baltimore-md/the-porter-brewers-hill/5YDbtm/',
#     'isBuilding': True,
#     'hasImage': True,
#     'lotId': 1004323637,
#     'imgSrc': 'https://photos.zillowstatic.com/fp/0dcba49fba25f4c72c9655b409c47e49-p_e.jpg',
#     'latitude': 39.278893,
#     'unit_1_bedroom': '$1,693+',
#     'unit_2_bedroom': '$2,571+'},
#    {'listingStatus': 'FOR_RENT',
#     'zpid': '39.342876--76.65849',
#     'longitude': -76.65849,
#     'buildingName': 'The Village at Jones Falls',
#     'address': '2530 Edgecombe Cir N, Baltimore, MD',
#     'detailUrl': '/apartments/baltimore-md/the-village-at-jones-falls/5XhvD3/',
#     'isBuilding': True,
#     'hasImage': True,
#     'lotId': 1001416774,
#     'imgSrc': 'https://photos.zillowstatic.com/fp/dd9c89d74cc6d1f230fb102b8f4226f0-p_e.jpg',
#     'latitude': 39.342876,
#     'unit_1_bedroom': '$1,005+',
#     'unit_2_bedroom': '$1,215+',
#     'unit_3_bedroom': '$1,365+'},
#    {'listingStatus': 'FOR_RENT',
#     'zpid': '39.303894--76.61639',
#     'longitude': -76.61639,
#     'buildingName': 'Queen Anne Belvedere',
#     'address': '1214 N Charles St, Baltimore, MD',
#     'detailUrl': '/apartments/baltimore-md/queen-anne-belvedere/5XyQqt/',
#     'isBuilding': True,
#     'hasImage': True,
#     'lotId': 1002890099,
#     'imgSrc': 'https://photos.zillowstatic.com/fp/da06169a073277abbf2df5d3cab6df6d-p_e.jpg',
#     'latitude': 39.303894,
#     'unit_1_bedroom': '$1,417+',
#     'unit_2_bedroom': '$1,626+'},
#    {'listingStatus': 'FOR_RENT',
#     'zpid': '39.281326--76.589264',
#     'longitude': -76.589264,
#     'buildingName': 'Union Wharf Apartments',
#     'address': '915 S Wolfe St, Baltimore, MD',
#     'detailUrl': '/apartments/baltimore-md/union-wharf-apartments/5XpJKP/',
#     'isBuilding': True,
#     'hasImage': True,
#     'lotId': 1001933252,
#     'imgSrc': 'https://photos.zillowstatic.com/fp/58f0e287be6edbbcbac0bec5a718ee46-p_e.jpg',
#     'latitude': 39.281326,
#     'unit_1_bedroom': '$2,120+',
#     'unit_2_bedroom': '$2,999+'},
#    {'listingStatus': 'FOR_RENT',
#     'zpid': '39.308994--76.62804',
#     'longitude': -76.62804,
#     'buildingName': 'Bolton St 1713',
#     'address': '1713 Bolton St, Baltimore, MD',
#     'detailUrl': '/b/bolton-st-1713-baltimore-md-5j8728/',
#     'isBuilding': True,
#     'hasImage': True,
#     'lotId': 1049911687,
#     'imgSrc': 'https://photos.zillowstatic.com/fp/e3819b051b082ceecf67c8c86e47360f-p_e.jpg',
#     'latitude': 39.308994,
#     'unit_1_bedroom': '$1,199+'},
#    {'dateSold': None,
#     'propertyType': 'APARTMENT',
#     'lotAreaValue': None,
#     'address': 'The Renaissance Club, 1712 Waverly Way #6013, Baltimore, MD 21239',
#     'variableData': None,
#     'unit': '# 6013',
#     'zestimate': None,
#     'imgSrc': 'https://photos.zillowstatic.com/fp/01bb80ae9214483048c82a3b968377bb-p_e.jpg',
#     'price': 1653,
#     'detailUrl': '/apartments/baltimore-md/the-renaissance-club/5Xt3yT/',
#     'bedrooms': 2,
#     'contingentListingType': None,
#     'longitude': -76.58104,
#     'latitude': 39.366913,
#     'listingStatus': 'FOR_RENT',
#     'zpid': '2063176009',
#     'listingSubType': {},
#     'rentZestimate': 1616,
#     'daysOnZillow': 1,
#     'bathrooms': 1,
#     'livingArea': 750,
#     'country': 'USA',
#     'currency': 'USD',
#     'lotAreaUnit': None,
#     'hasImage': True},
#    {'listingStatus': 'FOR_RENT',
#     'zpid': '39.370182--76.682945',
#     'longitude': -76.682945,
#     'buildingName': 'Flora Park',
#     'address': '6310 Greenspring Ave, Baltimore, MD',
#     'detailUrl': '/apartments/baltimore-md/flora-park/5Xt3bV/',
#     'isBuilding': True,
#     'hasImage': True,
#     'lotId': 1002373326,
#     'imgSrc': 'https://photos.zillowstatic.com/fp/a48bfc49573a605a3acb80effb402127-p_e.jpg',
#     'latitude': 39.370182,
#     'unit_1_bedroom': '$1,225+',
#     'unit_2_bedroom': '$1,395+',
#     'unit_3_bedroom': '$1,800+'},
#    {'listingStatus': 'FOR_RENT',
#     'zpid': '39.26839--76.59934',
#     'longitude': -76.59934,
#     'buildingName': 'McHenry Row',
#     'address': '1700 Whetstone Way, Baltimore, MD',
#     'detailUrl': '/apartments/baltimore-md/mchenry-row/5XrF4P/',
#     'isBuilding': True,
#     'hasImage': True,
#     'lotId': 1002160710,
#     'imgSrc': 'https://photos.zillowstatic.com/fp/4fe48247d917a72c5fb2962345db2dc2-p_e.jpg',
#     'latitude': 39.26839,
#     'unit_0_bedroom': '$1,667+',
#     'unit_1_bedroom': '$1,521+',
#     'unit_2_bedroom': '$2,511+'},
#    {'listingStatus': 'FOR_RENT',
#     'zpid': '39.268703--76.59835',
#     'longitude': -76.59835,
#     'buildingName': 'Porter Street',
#     'address': '1401 Porter St, Baltimore, MD',
#     'detailUrl': '/b/porter-street-middle-river-md-Bgt5Vy/',
#     'isBuilding': True,
#     'hasImage': True,
#     'lotId': 2455107758,
#     'imgSrc': 'https://photos.zillowstatic.com/fp/a5edf4d937f8e37d4a5e6ac736367f5f-p_e.jpg',
#     'latitude': 39.268703,
#     'unit_0_bedroom': '$1,660+',
#     'unit_1_bedroom': '$1,661+',
#     'unit_2_bedroom': '$2,147+'},
#    {'listingStatus': 'FOR_RENT',
#     'zpid': '39.276196--76.61741',
#     'longitude': -76.61741,
#     'buildingName': '101 Cross Street',
#     'address': '101 W Cross St, Baltimore, MD',
#     'detailUrl': '/apartments/baltimore-md/101-cross-street/9PdJnJ/',
#     'isBuilding': True,
#     'hasImage': True,
#     'lotId': 2090540571,
#     'imgSrc': 'https://photos.zillowstatic.com/fp/4992183033f22c8a28c0d6a256b27cfd-p_e.jpg',
#     'latitude': 39.276196,
#     'unit_0_bedroom': '$1,713+',
#     'unit_1_bedroom': '$1,872+',
#     'unit_2_bedroom': '$2,349+'},
#    {'listingStatus': 'FOR_RENT',
#     'zpid': '39.282993--76.60144',
#     'longitude': -76.60144,
#     'buildingName': 'Spinnaker Bay at Harbor East',
#     'address': '707 President St, Baltimore, MD',
#     'detailUrl': '/apartments/baltimore-md/spinnaker-bay-at-harbor-east/5XmDBZ/',
#     'isBuilding': True,
#     'hasImage': True,
#     'lotId': 1001688016,
#     'imgSrc': 'https://photos.zillowstatic.com/fp/f1a36cd4265001f7c86fe1ba38585183-p_e.jpg',
#     'latitude': 39.282993,
#     'unit_1_bedroom': '$1,780+',
#     'unit_2_bedroom': '$2,933+',
#     'unit_3_bedroom': '$3,447+'},
#    {'dateSold': None,
#     'propertyType': 'APARTMENT',
#     'lotAreaValue': None,
#     'address': 'Hilltop Gardens, 3912 W Northern Pkwy #HILLTOP391, Baltimore, MD 21215',
#     'variableData': None,
#     'unit': '# HILLTOP391',
#     'zestimate': None,
#     'imgSrc': 'https://photos.zillowstatic.com/fp/074e47a1e409d3fcc1d6fa042d6991cb-p_e.jpg',
#     'price': 1100,
#     'detailUrl': '/apartments/baltimore-md/hilltop-gardens/5ZbXW4/',
#     'bedrooms': 1,
#     'contingentListingType': None,
#     'longitude': -76.68978,
#     'latitude': 39.34961,
#     'listingStatus': 'FOR_RENT',
#     'zpid': '2056117183',
#     'listingSubType': {},
#     'rentZestimate': 1250,
#     'daysOnZillow': 1,
#     'bathrooms': 1,
#     'livingArea': 583,
#     'country': 'USA',
#     'currency': 'USD',
#     'lotAreaUnit': None,
#     'hasImage': True},
#    {'dateSold': None,
#     'propertyType': 'APARTMENT',
#     'lotAreaValue': None,
#     'address': '2001 Eastern Avenue, 2001 Eastern Ave #EA2001-B, Baltimore, MD 21231',
#     'variableData': None,
#     'unit': '# EA2001-B',
#     'zestimate': None,
#     'imgSrc': 'https://photos.zillowstatic.com/fp/a438929bc3419be839d50da86e09db7c-p_e.jpg',
#     'price': 1650,
#     'detailUrl': '/b/2001-eastern-avenue-baltimore-md-5j87Xs/',
#     'bedrooms': 2,
#     'contingentListingType': None,
#     'longitude': -76.58861,
#     'latitude': 39.285606,
#     'listingStatus': 'FOR_RENT',
#     'zpid': '2056297996',
#     'listingSubType': {},
#     'rentZestimate': 1650,
#     'daysOnZillow': 1,
#     'bathrooms': 1,
#     'livingArea': 690,
#     'country': 'USA',
#     'currency': 'USD',
#     'lotAreaUnit': None,
#     'hasImage': True},
#    {'listingStatus': 'FOR_RENT',
#     'zpid': '39.361916--76.67885',
#     'longitude': -76.67885,
#     'buildingName': 'Brook View Apartments',
#     'address': '5921 Western Run Dr, Baltimore, MD',
#     'detailUrl': '/apartments/baltimore-md/brook-view-apartments/5XhvDD/',
#     'isBuilding': True,
#     'hasImage': True,
#     'lotId': 1001416783,
#     'imgSrc': 'https://photos.zillowstatic.com/fp/dc24263764f3917be8acef4322f8524e-p_e.jpg',
#     'latitude': 39.361916,
#     'unit_1_bedroom': '$1,225+',
#     'unit_2_bedroom': '$1,445+',
#     'unit_3_bedroom': '$1,941+'},
#    {'listingStatus': 'FOR_RENT',
#     'zpid': '39.29016--76.57284',
#     'longitude': -76.57284,
#     'buildingName': '101 Ellwood',
#     'address': '101 S Ellwood Ave, Baltimore, MD',
#     'detailUrl': '/apartments/baltimore-md/101-ellwood/5XqyK9/',
#     'isBuilding': True,
#     'hasImage': True,
#     'lotId': 1002130122,
#     'imgSrc': 'https://photos.zillowstatic.com/fp/aa23ee143f7dcb14bdb21cb8fd2d6de8-p_e.jpg',
#     'latitude': 39.29016,
#     'unit_0_bedroom': '$1,495+',
#     'unit_1_bedroom': '$1,495+',
#     'unit_2_bedroom': '$1,995+'},
#    {'listingStatus': 'FOR_RENT',
#     'zpid': '39.298782--76.61688',
#     'longitude': -76.61688,
#     'buildingName': 'The Morison',
#     'address': '18 W Madison St, Baltimore, MD',
#     'detailUrl': '/b/the-morison-baltimore-md-5bDdNw/',
#     'isBuilding': True,
#     'hasImage': None,
#     'lotId': 1015856824,
#     'imgSrc': 'https://maps.googleapis.com/maps/api/staticmap?mobile=false&sensor=true&maptype=satellite&size=575x242&zoom=17&center=39.29878234863281,-76.61688232421875&key=AIzaSyBJsNQO5ZeG-XAbqqWLKwG08fWITSxg33w&signature=mguUfx1YGnePLDjGLlvUlQX38UI=',
#     'latitude': 39.298782,
#     'unit_0_bedroom': '$1,249+',
#     'unit_1_bedroom': '$1,379+'},
#    {'listingStatus': 'FOR_RENT',
#     'zpid': '39.335953--76.707245',
#     'longitude': -76.707245,
#     'buildingName': 'Seton Park',
#     'address': '3601 Parkview Ave, Gwynn Oak, MD',
#     'detailUrl': '/apartments/baltimore-md/seton-park/5Y2wdx/',
#     'isBuilding': True,
#     'hasImage': True,
#     'lotId': 1003184984,
#     'imgSrc': 'https://photos.zillowstatic.com/fp/b5eaf4065d3d1ae7c8155eeb1511ad1a-p_e.jpg',
#     'latitude': 39.335953,
#     'unit_2_bedroom': '$1,229+'},
#    {'listingStatus': 'FOR_RENT',
#     'zpid': '39.371468--76.69321',
#     'longitude': -76.69321,
#     'buildingName': 'Fallstaff Manor',
#     'address': '3014 Romaric Ct, Baltimore, MD',
#     'detailUrl': '/apartments/baltimore-md/fallstaff-manor/5XhvQQ/',
#     'isBuilding': True,
#     'hasImage': True,
#     'lotId': 1001417283,
#     'imgSrc': 'https://photos.zillowstatic.com/fp/f4bc6ff1ee98d700bd0257451043fbaf-p_e.jpg',
#     'latitude': 39.371468,
#     'unit_1_bedroom': '$1,349+',
#     'unit_2_bedroom': '$1,529+'},
#    {'listingStatus': 'FOR_RENT',
#     'zpid': '39.37198--76.58447',
#     'longitude': -76.58447,
#     'buildingName': 'Park Crescent',
#     'address': '6535 Falkirk Rd, Baltimore, MD',
#     'detailUrl': '/apartments/baltimore-md/park-crescent/5XqvQ2/',
#     'isBuilding': True,
#     'hasImage': True,
#     'lotId': 1002123157,
#     'imgSrc': 'https://photos.zillowstatic.com/fp/5b0f096569d0acce25d87f9eabfce895-p_e.jpg',
#     'latitude': 39.37198,
#     'unit_1_bedroom': '$1,299+',
#     'unit_2_bedroom': '$1,399+'},
#    {'listingStatus': 'FOR_RENT',
#     'zpid': '39.37039--76.600136',
#     'longitude': -76.600136,
#     'buildingName': 'Walker Manor',
#     'address': '1018K Woodson Rd, Baltimore, MD',
#     'detailUrl': '/b/walker-manor-baltimore-md-Bp5WJ6/',
#     'isBuilding': True,
#     'hasImage': True,
#     'lotId': 2485042893,
#     'imgSrc': 'https://photos.zillowstatic.com/fp/c68fa84dafdee7b88016637809c8c888-p_e.jpg',
#     'latitude': 39.37039,
#     'unit_1_bedroom': '$1,349+',
#     'unit_2_bedroom': '$1,519+',
#     'unit_3_bedroom': '$2,049+'},
#    {'dateSold': None,
#     'propertyType': 'TOWNHOUSE',
#     'lotAreaValue': None,
#     'address': '2119 E Federal St, Baltimore, MD 21213',
#     'variableData': None,
#     'zestimate': 84100,
#     'imgSrc': 'https://maps.googleapis.com/maps/api/staticmap?mobile=false&sensor=true&maptype=satellite&size=575x242&zoom=17&center=39.30862045288086,-76.587890625&key=AIzaSyBJsNQO5ZeG-XAbqqWLKwG08fWITSxg33w&signature=aBVuZxvxC-GhuDvSuXWJyvwAUek=',
#     'price': 1500,
#     'detailUrl': '/homedetails/2119-E-Federal-St-Baltimore-MD-21213/36453124_zpid/',
#     'bedrooms': 3,
#     'contingentListingType': None,
#     'longitude': -76.58789,
#     'latitude': 39.30862,
#     'listingStatus': 'FOR_RENT',
#     'zpid': '36453124',
#     'listingSubType': {},
#     'rentZestimate': 1300,
#     'daysOnZillow': 1,
#     'bathrooms': 1,
#     'livingArea': 1890,
#     'country': 'USA',
#     'currency': 'USD',
#     'lotAreaUnit': None,
#     'hasImage': None},
#    {'listingStatus': 'FOR_RENT',
#     'zpid': '39.29938--76.61758',
#     'longitude': -76.61758,
#     'buildingName': 'Flats at Professional Arts Bldg',
#     'address': '101 W Read St, Baltimore, MD',
#     'detailUrl': '/apartments/baltimore-md/flats-at-professional-arts-bldg/5XjDMz/',
#     'isBuilding': True,
#     'hasImage': None,
#     'lotId': 1001453179,
#     'imgSrc': 'https://maps.googleapis.com/maps/api/staticmap?mobile=false&sensor=true&maptype=satellite&size=575x242&zoom=17&center=39.299381256103516,-76.6175765991211&key=AIzaSyBJsNQO5ZeG-XAbqqWLKwG08fWITSxg33w&signature=lHhAct_MSd_ouVP37C4YNPHiGRM=',
#     'latitude': 39.29938,
#     'unit_1_bedroom': '$1,211+',
#     'unit_2_bedroom': '$2,027+'},
#    {'listingStatus': 'FOR_RENT',
#     'zpid': '39.290173--76.612885',
#     'longitude': -76.612885,
#     'buildingName': 'The Harriet at the Equitable Building',
#     'address': '10 N Calvert St, Baltimore, MD',
#     'detailUrl': '/apartments/baltimore-md/the-harriet-at-the-equitable-building/5j3fD9/',
#     'isBuilding': True,
#     'hasImage': True,
#     'lotId': 1049388760,
#     'imgSrc': 'https://photos.zillowstatic.com/fp/730e6fdf923bfb2dc7ad147548c977dd-p_e.jpg',
#     'latitude': 39.290173,
#     'unit_0_bedroom': '$1,384+',
#     'unit_1_bedroom': '$1,405+',
#     'unit_2_bedroom': '$1,884+'},
#    {'listingStatus': 'FOR_RENT',
#     'zpid': '39.287888--76.61979',
#     'longitude': -76.61979,
#     'buildingName': 'Camden Court',
#     'address': '300 W Lombard St, Baltimore, MD',
#     'detailUrl': '/apartments/baltimore-md/camden-court/5Xhv9B/',
#     'isBuilding': True,
#     'hasImage': True,
#     'lotId': 1001416634,
#     'imgSrc': 'https://photos.zillowstatic.com/fp/35ed5478b5abb983d7dc6bf9b9a948ce-p_e.jpg',
#     'latitude': 39.287888,
#     'unit_0_bedroom': '$1,365+',
#     'unit_1_bedroom': '$1,400+',
#     'unit_2_bedroom': '$1,500+',
#     'unit_3_bedroom': '$2,155+'},
#    {'listingStatus': 'FOR_RENT',
#     'zpid': '39.283775--76.61374',
#     'longitude': -76.61374,
#     'buildingName': '414 Light Street',
#     'address': '414 Light St, Baltimore, MD',
#     'detailUrl': '/apartments/baltimore-md/414-light-street/99KqyK/',
#     'isBuilding': True,
#     'hasImage': True,
#     'lotId': 2019543443,
#     'imgSrc': 'https://photos.zillowstatic.com/fp/872ccc2da754500d2e24dd68598028b3-p_e.jpg',
#     'latitude': 39.283775,
#     'unit_0_bedroom': '$1,902+',
#     'unit_1_bedroom': '$2,139+',
#     'unit_2_bedroom': '$3,596+'},
#    {'listingStatus': 'FOR_RENT',
#     'zpid': '39.302444--76.619484',
#     'longitude': -76.619484,
#     'buildingName': 'Symphony Center Apartments',
#     'address': '1020 Park Ave, Baltimore, MD',
#     'detailUrl': '/apartments/baltimore-md/symphony-center-apartments/5XjDKv/',
#     'isBuilding': True,
#     'hasImage': True,
#     'lotId': 1001453077,
#     'imgSrc': 'https://photos.zillowstatic.com/fp/2fd2c6ef3934ad3781592043ceb2056a-p_e.jpg',
#     'latitude': 39.302444,
#     'unit_2_bedroom': '$2,066+'},
#    {'dateSold': None,
#     'propertyType': 'SINGLE_FAMILY',
#     'lotAreaValue': None,
#     'address': '705 Baker St, Baltimore, MD 21217',
#     'variableData': None,
#     'zestimate': 71000,
#     'imgSrc': 'https://photos.zillowstatic.com/fp/5428e0297603db94c095b577a62d7f61-p_e.jpg',
#     'price': 1500,
#     'detailUrl': '/homedetails/705-Baker-St-Baltimore-MD-21217/90004173_zpid/',
#     'bedrooms': 2,
#     'contingentListingType': None,
#     'longitude': -76.64146,
#     'latitude': 39.30723,
#     'listingStatus': 'FOR_RENT',
#     'zpid': '90004173',
#     'listingSubType': {},
#     'rentZestimate': 1229,
#     'daysOnZillow': 1,
#     'bathrooms': 2,
#     'livingArea': 845,
#     'country': 'USA',
#     'currency': 'USD',
#     'lotAreaUnit': None,
#     'hasImage': True},
#    {'dateSold': None,
#     'propertyType': 'SINGLE_FAMILY',
#     'lotAreaValue': None,
#     'address': '815 W Cross St, Baltimore, MD 21230',
#     'variableData': {'text': '3D Tour', 'type': '3D_HOME'},
#     'zestimate': 354500,
#     'imgSrc': 'https://photos.zillowstatic.com/fp/c3f1f4b3b9d2219eae16c079a4232435-p_e.jpg',
#     'price': 2100,
#     'detailUrl': '/homedetails/815-W-Cross-St-Baltimore-MD-21230/36534476_zpid/',
#     'bedrooms': 3,
#     'contingentListingType': None,
#     'longitude': -76.62912,
#     'latitude': 39.280033,
#     'listingStatus': 'FOR_RENT',
#     'zpid': '36534476',
#     'listingSubType': {},
#     'rentZestimate': 2761,
# ...
#     'bedrooms': 1,
#     'contingentListingType': None,
#     'longitude': -76.59121,
#     'latitude': 39.23021,
#     'listingStatus': 'FOR_RENT',
#     'zpid': '2056990110',
#     'listingSubType': {},
#     'rentZestimate': 799,
#     'daysOnZillow': 1,
#     'bathrooms': 1,
#     'livingArea': None,
#     'country': 'USA',
#     'currency': 'USD',
#     'lotAreaUnit': None,
#     'hasImage': True},
#    {'dateSold': None,
#     'propertyType': 'SINGLE_FAMILY',
#     'lotAreaValue': None,
#     'address': '4109 Morrison Ct, Baltimore, MD 21226',
#     'variableData': None,
#     'zestimate': 114800,
#     'imgSrc': 'https://photos.zillowstatic.com/fp/6714a004cfa7f63d2ce7d60e92f1fd25-p_e.jpg',
#     'price': 1199,
#     'detailUrl': '/homedetails/4109-Morrison-Ct-Baltimore-MD-21226/36553947_zpid/',
#     'bedrooms': 2,
#     'contingentListingType': None,
#     'longitude': -76.58789,
#     'latitude': 39.228104,
#     'listingStatus': 'FOR_RENT',
#     'zpid': '36553947',
#     'listingSubType': {},
#     'rentZestimate': 1149,
#     'daysOnZillow': 1,
#     'bathrooms': 1,
#     'livingArea': None,
#     'country': 'USA',
#     'currency': 'USD',
#     'lotAreaUnit': None,
#     'hasImage': True},
#    {'dateSold': None,
#     'propertyType': 'SINGLE_FAMILY',
#     'lotAreaValue': None,
#     'address': '2714 Maryland Ave, Baltimore, MD 21218',
#     'variableData': None,
#     'zestimate': 332300,
#     'imgSrc': 'https://photos.zillowstatic.com/fp/bbdef694d686d8f996c6ec1593d62e8a-p_e.jpg',
#     'price': 2100,
#     'detailUrl': '/homedetails/2714-Maryland-Ave-Baltimore-MD-21218/36472502_zpid/',
#     'bedrooms': 5,
#     'contingentListingType': None,
#     'longitude': -76.61894,
#     'latitude': 39.320957,
#     'listingStatus': 'FOR_RENT',
#     'zpid': '36472502',
#     'listingSubType': {},
#     'rentZestimate': 2466,
#     'daysOnZillow': 1,
#     'bathrooms': 2,
#     'livingArea': 2238,
#     'country': 'USA',
#     'currency': 'USD',
#     'lotAreaUnit': None,
#     'hasImage': True},
#    {'dateSold': None,
#     'propertyType': 'APARTMENT',
#     'lotAreaValue': None,
#     'address': '223 E. Preston St, 223 E Preston St APT BSMT, Baltimore, MD 21202',
#     'variableData': None,
#     'unit': 'Apt Bsmt',
#     'zestimate': None,
#     'imgSrc': 'https://photos.zillowstatic.com/fp/6227dc8aee29be1c981f3eb198c655fe-p_e.jpg',
#     'price': 1075,
#     'detailUrl': '/b/223-e.-preston-st-baltimore-md-9PcqMj/',
#     'bedrooms': 2,
#     'contingentListingType': None,
#     'longitude': -76.61211,
#     'latitude': 39.30442,
#     'listingStatus': 'FOR_RENT',
#     'zpid': '2089837959',
#     'listingSubType': {},
#     'rentZestimate': 1175,
#     'daysOnZillow': 1,
#     'bathrooms': 1,
#     'livingArea': 33,
#     'country': 'USA',
#     'currency': 'USD',
#     'lotAreaUnit': None,
#     'hasImage': True},
#    {'dateSold': None,
#     'propertyType': 'APARTMENT',
#     'lotAreaValue': None,
#     'address': '2414 Saint Paul, 2414 Saint Paul St, Baltimore, MD 21218',
#     'variableData': None,
#     'unit': '# 11013562',
#     'zestimate': None,
#     'imgSrc': 'https://photos.zillowstatic.com/fp/e7ec521349516bf3d0e70699b860b79b-p_e.jpg',
#     'price': 850,
#     'detailUrl': '/b/2414-saint-paul-baltimore-md-5j88yM/',
#     'bedrooms': 0,
#     'contingentListingType': None,
#     'longitude': -76.61559,
#     'latitude': 39.31683,
#     'listingStatus': 'FOR_RENT',
#     'zpid': '2057029468',
#     'listingSubType': {},
#     'rentZestimate': 763,
#     'daysOnZillow': 1,
#     'bathrooms': 1,
#     'livingArea': 200,
#     'country': 'USA',
#     'currency': 'USD',
#     'lotAreaUnit': None,
#     'hasImage': True},
#    {'dateSold': None,
#     'propertyType': 'TOWNHOUSE',
#     'lotAreaValue': None,
#     'address': '710 Beaverbrook Rd, Baltimore, MD 21212',
#     'variableData': None,
#     'zestimate': 256300,
#     'imgSrc': 'https://photos.zillowstatic.com/fp/32c7a13eded0af526d96a6f790c28312-p_e.jpg',
#     'price': 1945,
#     'detailUrl': '/homedetails/710-Beaverbrook-Rd-Baltimore-MD-21212/36614719_zpid/',
#     'bedrooms': 4,
#     'contingentListingType': None,
#     'longitude': -76.60576,
#     'latitude': 39.358513,
#     'listingStatus': 'FOR_RENT',
#     'zpid': '36614719',
#     'listingSubType': {},
#     'rentZestimate': 2199,
#     'daysOnZillow': 1,
#     'bathrooms': 2.5,
#     'livingArea': 1554,
#     'country': 'USA',
#     'currency': 'USD',
#     'lotAreaUnit': None,
#     'hasImage': True},
#    {'dateSold': None,
#     'propertyType': 'APARTMENT',
#     'lotAreaValue': None,
#     'address': '910 S. Wolfe St, 910 S Wolfe St, Baltimore, MD 21231',
#     'variableData': None,
#     'zestimate': None,
#     'imgSrc': 'https://photos.zillowstatic.com/fp/f6f787cfc023c55eab6851736b96656c-p_e.jpg',
#     'price': 1950,
#     'detailUrl': '/b/910-s.-wolfe-st-baltimore-md-9xqLNd/',
#     'bedrooms': 2,
#     'contingentListingType': None,
#     'longitude': -76.589966,
#     'latitude': 39.281734,
#     'listingStatus': 'FOR_RENT',
#     'zpid': '2095497407',
#     'listingSubType': {},
#     'rentZestimate': 3044,
#     'daysOnZillow': 1,
#     'bathrooms': 2,
#     'livingArea': None,
#     'country': 'USA',
#     'currency': 'USD',
#     'lotAreaUnit': None,
#     'hasImage': True},
#    {'dateSold': None,
#     'propertyType': 'TOWNHOUSE',
#     'lotAreaValue': None,
#     'address': '3219 Gwynns Falls Pkwy, Baltimore, MD 21216',
#     'variableData': None,
#     'zestimate': 119400,
#     'imgSrc': 'https://photos.zillowstatic.com/fp/5788a113313cb4ad2c4b6a20c694e49b-p_e.jpg',
#     'price': 1550,
#     'detailUrl': '/homedetails/3219-Gwynns-Falls-Pkwy-Baltimore-MD-21216/36501303_zpid/',
#     'bedrooms': 3,
#     'contingentListingType': None,
#     'longitude': -76.67209,
#     'latitude': 39.31394,
#     'listingStatus': 'FOR_RENT',
#     'zpid': '36501303',
#     'listingSubType': {},
#     'rentZestimate': 1536,
#     'daysOnZillow': 1,
#     'bathrooms': 1.5,
#     'livingArea': 1152,
#     'country': 'USA',
#     'currency': 'USD',
#     'lotAreaUnit': None,
#     'hasImage': True},
#    {'dateSold': None,
#     'propertyType': 'TOWNHOUSE',
#     'lotAreaValue': None,
#     'address': '1416 Marshall St, Baltimore, MD 21230',
#     'variableData': None,
#     'zestimate': 363900,
#     'imgSrc': 'https://photos.zillowstatic.com/fp/3fca1ec606151e6c4ce44715afc0d9ce-p_e.jpg',
#     'price': 2250,
#     'detailUrl': '/homedetails/1416-Marshall-St-Baltimore-MD-21230/36538479_zpid/',
#     'bedrooms': 3,
#     'contingentListingType': None,
#     'longitude': -76.612785,
#     'latitude': 39.27381,
#     'listingStatus': 'FOR_RENT',
#     'zpid': '36538479',
#     'listingSubType': {},
#     'rentZestimate': 2594,
#     'daysOnZillow': 1,
#     'bathrooms': 2,
#     'livingArea': 1690,
#     'country': 'USA',
#     'currency': 'USD',
#     'lotAreaUnit': None,
#     'hasImage': True},
#    {'dateSold': None,
#     'propertyType': 'SINGLE_FAMILY',
#     'lotAreaValue': None,
#     'address': '3129 Eastern Ave, Baltimore, MD 21224',
#     'variableData': None,
#     'zestimate': 277100,
#     'imgSrc': 'https://photos.zillowstatic.com/fp/3c764d37355f2be71432cecfe56f299b-p_e.jpg',
#     'price': 999,
#     'detailUrl': '/homedetails/3129-Eastern-Ave-Baltimore-MD-21224/36432736_zpid/',
#     'bedrooms': 1,
#     'contingentListingType': None,
#     'longitude': -76.571915,
#     'latitude': 39.286194,
#     'listingStatus': 'FOR_RENT',
#     'zpid': '36432736',
#     'listingSubType': {},
#     'rentZestimate': 1764,
#     'daysOnZillow': 1,
#     'bathrooms': 1,
#     'livingArea': None,
#     'country': 'USA',
#     'currency': 'USD',
#     'lotAreaUnit': None,
#     'hasImage': True},
#    {'dateSold': None,
#     'propertyType': 'SINGLE_FAMILY',
#     'lotAreaValue': None,
#     'address': '2558 Aisquith St, Baltimore, MD 21218',
#     'variableData': None,
#     'zestimate': 109800,
#     'imgSrc': 'https://photos.zillowstatic.com/fp/201a611bac56b0ecddd74ea844879cc9-p_e.jpg',
#     'price': 1325,
#     'detailUrl': '/homedetails/2558-Aisquith-St-Baltimore-MD-21218/36462010_zpid/',
#     'bedrooms': 2,
#     'contingentListingType': None,
#     'longitude': -76.59701,
#     'latitude': 39.318893,
#     'listingStatus': 'FOR_RENT',
#     'zpid': '36462010',
#     'listingSubType': {},
#     'rentZestimate': 1485,
#     'daysOnZillow': 1,
#     'bathrooms': 1,
#     'livingArea': 1125,
#     'country': 'USA',
#     'currency': 'USD',
#     'lotAreaUnit': None,
#     'hasImage': True},
#    {'dateSold': None,
#     'propertyType': 'TOWNHOUSE',
#     'lotAreaValue': None,
#     'address': '1003 S Charles St APT 2, Baltimore, MD 21230',
#     'variableData': None,
#     'unit': 'Apt 2',
#     'zestimate': 172200,
#     'imgSrc': 'https://photos.zillowstatic.com/fp/553fa747771d53129305afd35c17f15e-p_e.jpg',
#     'price': 1350,
#     'detailUrl': '/homedetails/1003-S-Charles-St-APT-2-Baltimore-MD-21230/2060800454_zpid/',
#     'bedrooms': 2,
#     'contingentListingType': None,
#     'longitude': -76.6142,
#     'latitude': 39.27801,
#     'listingStatus': 'FOR_RENT',
#     'zpid': '2060800454',
#     'listingSubType': {},
#     'rentZestimate': 1625,
#     'daysOnZillow': 1,
#     'bathrooms': 1,
#     'livingArea': 750,
#     'country': 'USA',
#     'currency': 'USD',
#     'lotAreaUnit': None,
#     'hasImage': True},
#    {'dateSold': None,
#     'propertyType': 'SINGLE_FAMILY',
#     'lotAreaValue': None,
#     'address': '912 N Ashburton St, Baltimore, MD 21216',
#     'variableData': None,
#     'zestimate': None,
#     'imgSrc': 'https://photos.zillowstatic.com/fp/0cb4732e94636e215f5de7991b6bd7f4-p_e.jpg',
#     'price': 1599,
#     'detailUrl': '/homedetails/912-N-Ashburton-St-Baltimore-MD-21216/2057644510_zpid/',
#     'bedrooms': 3,
#     'contingentListingType': None,
#     'longitude': -76.661896,
#     'latitude': 39.298504,
#     'listingStatus': 'FOR_RENT',
#     'zpid': '2057644510',
#     'listingSubType': {},
#     'rentZestimate': 1450,
#     'daysOnZillow': 1,
#     'bathrooms': 1.5,
#     'livingArea': 896,
#     'country': 'USA',
#     'currency': 'USD',
#     'lotAreaUnit': None,
#     'hasImage': True},
#    {'dateSold': None,
#     'propertyType': 'SINGLE_FAMILY',
#     'lotAreaValue': None,
#     'address': '417 S Washington St, Baltimore, MD 21231',
#     'variableData': None,
#     'zestimate': 384600,
#     'imgSrc': 'https://photos.zillowstatic.com/fp/064130a32b43f17e85a50479fa85bc62-p_e.jpg',
#     'price': 2300,
#     'detailUrl': '/homedetails/417-S-Washington-St-Baltimore-MD-21231/36436482_zpid/',
#     'bedrooms': 3,
#     'contingentListingType': None,
#     'longitude': -76.58861,
#     'latitude': 39.286163,
#     'listingStatus': 'FOR_RENT',
#     'zpid': '36436482',
#     'listingSubType': {},
#     'rentZestimate': 2199,
#     'daysOnZillow': 1,
#     'bathrooms': 2,
#     'livingArea': 1882,
#     'country': 'USA',
#     'currency': 'USD',
#     'lotAreaUnit': None,
#     'hasImage': True},
#    {'dateSold': None,
#     'propertyType': 'SINGLE_FAMILY',
#     'lotAreaValue': None,
#     'address': '316 Gusryan St, Baltimore, MD 21224',
#     'variableData': None,
#     'zestimate': 191500,
#     'imgSrc': 'https://photos.zillowstatic.com/fp/b84d65e234a79fb0f2784a7eff80b4fb-p_e.jpg',
#     'price': 1600,
#     'detailUrl': '/homedetails/316-Gusryan-St-Baltimore-MD-21224/36562643_zpid/',
#     'bedrooms': 2,
#     'contingentListingType': None,
#     'longitude': -76.54132,
#     'latitude': 39.290176,
#     'listingStatus': 'FOR_RENT',
#     'zpid': '36562643',
#     'listingSubType': {},
#     'rentZestimate': 1450,
#     'daysOnZillow': 1,
#     'bathrooms': 2,
#     'livingArea': 840,
#     'country': 'USA',
#     'currency': 'USD',
#     'lotAreaUnit': None,
#     'hasImage': True},
#    {'dateSold': None,
#     'propertyType': 'APARTMENT',
#     'lotAreaValue': None,
#     'address': 'Spacious 1&2 Br, 5009 Norwood Ave #A5, Gwynn Oak, MD 21207',
#     'variableData': None,
#     'unit': '# A5',
#     'zestimate': None,
#     'imgSrc': 'https://photos.zillowstatic.com/fp/66679431a548c5461a8a2f23c7cda913-p_e.jpg',
#     'price': 925,
#     'detailUrl': '/b/spacious-1%262-br-baltimore-md-63KhND/',
#     'bedrooms': 1,
#     'contingentListingType': None,
#     'longitude': -76.70013,
#     'latitude': 39.32923,
#     'listingStatus': 'FOR_RENT',
#     'zpid': '2057188610',
#     'listingSubType': {},
#     'rentZestimate': 1082,
#     'daysOnZillow': 1,
#     'bathrooms': 1,
#     'livingArea': 675,
#     'country': 'USA',
#     'currency': 'USD',
#     'lotAreaUnit': None,
#     'hasImage': True},
#    {'dateSold': None,
#     'propertyType': 'APARTMENT',
#     'lotAreaValue': None,
#     'address': 'Haddon Hill Apartments (5512 -5514 Haddon Ave), 5512 Haddon Ave APT T1, Gwynn Oak, MD 21207',
#     'variableData': None,
#     'unit': 'Apt T1',
#     'zestimate': None,
#     'imgSrc': 'https://photos.zillowstatic.com/fp/41d3e934a906308985ee0707e52c027d-p_e.jpg',
#     'price': 995,
#     'detailUrl': '/b/haddon-hill-apartments-%285512-5514-haddon-ave%29-baltimore-md-5gjqjS/',
#     'bedrooms': 2,
#     'contingentListingType': None,
#     'longitude': -76.70322,
#     'latitude': 39.337494,
#     'listingStatus': 'FOR_RENT',
#     'zpid': '2057188609',
#     'listingSubType': {},
#     'rentZestimate': 1175,
#     'daysOnZillow': 1,
#     'bathrooms': 1,
#     'livingArea': 800,
#     'country': 'USA',
#     'currency': 'USD',
#     'lotAreaUnit': None,
#     'hasImage': True},
#    {'dateSold': None,
#     'propertyType': 'APARTMENT',
#     'lotAreaValue': None,
#     'address': 'Garden Style Apartment in Gwynn Oak/Seton Neighborhood, 5525 Cadillac Ave #6, Gwynn Oak, MD 21207',
#     'variableData': None,
#     'unit': '# 6',
#     'zestimate': None,
#     'imgSrc': 'https://photos.zillowstatic.com/fp/800ce84f7bee122b6f71a1215b2f3acf-p_e.jpg',
#     'price': 975,
#     'detailUrl': '/b/garden-style-apartment-in-gwynn-oak-seton-neighborhood-baltimore-md-5gjqjT/',
#     'bedrooms': 2,
#     'contingentListingType': None,
#     'longitude': -76.70252,
#     'latitude': 39.337917,
#     'listingStatus': 'FOR_RENT',
#     'zpid': '2057188611',
#     'listingSubType': {},
#     'rentZestimate': 1019,
#     'daysOnZillow': 1,
#     'bathrooms': 1,
#     'livingArea': None,
#     'country': 'USA',
#     'currency': 'USD',
#     'lotAreaUnit': None,
#     'hasImage': True},
#    {'dateSold': None,
#     'propertyType': 'APARTMENT',
#     'lotAreaValue': None,
#     'address': 'Liberty Heights Apartments (3701 Liberty Heights), 3701 Liberty Heights Ave #B2, Baltimore, MD 21215',
#     'variableData': None,
#     'unit': '# B2',
#     'zestimate': None,
#     'imgSrc': 'https://photos.zillowstatic.com/fp/b02dfaf922eefebba78fba65493b20b9-p_e.jpg',
#     'price': 995,
#     'detailUrl': '/b/liberty-heights-apartments-%283701-liberty-heights%29-baltimore-md-5Xqmc7/',
#     'bedrooms': 2,
#     'contingentListingType': None,
#     'longitude': -76.679344,
#     'latitude': 39.326138,
#     'listingStatus': 'FOR_RENT',
#     'zpid': '2057188612',
#     'listingSubType': {},
#     'rentZestimate': 1132,
#     'daysOnZillow': 1,
#     'bathrooms': 1,
#     'livingArea': 800,
#     'country': 'USA',
#     'currency': 'USD',
#     'lotAreaUnit': None,
#     'hasImage': True},
#    {'listingStatus': 'FOR_RENT',
#     'zpid': '39.3383--76.702324',
#     'longitude': -76.702324,
#     'buildingName': 'Cadillac Apartments (5527 Cadillac Ave)',
#     'address': '5527 Cadillac Ave, Gwynn Oak, MD',
#     'detailUrl': '/b/cadillac-apartments-%285527-cadillac-ave%29-baltimore-md-63KhFs/',
#     'isBuilding': True,
#     'hasImage': True,
#     'lotId': 1137512747,
#     'imgSrc': 'https://photos.zillowstatic.com/fp/20f9ed637ad3a6a512a43e077b7accf3-p_e.jpg',
#     'latitude': 39.3383,
#     'unit_2_bedroom': '$975+'},
#    {'dateSold': None,
#     'propertyType': 'SINGLE_FAMILY',
#     'lotAreaValue': None,
#     'address': '3707 W Franklin St #2, Baltimore, MD 21229',
#     'variableData': None,
#     'unit': '# 2',
#     'zestimate': None,
#     'imgSrc': 'https://photos.zillowstatic.com/fp/ee733c715a8dc8f9110f0397e71a291f-p_e.jpg',
#     'price': 990,
#     'detailUrl': '/homedetails/3707-W-Franklin-St-2-Baltimore-MD-21229/2085611523_zpid/',
#     'bedrooms': 2,
#     'contingentListingType': None,
#     'longitude': -76.67868,
#     'latitude': 39.292385,
#     'listingStatus': 'FOR_RENT',
#     'zpid': '2085611523',
#     'listingSubType': {},
#     'rentZestimate': 999,
#     'daysOnZillow': 1,
#     'bathrooms': 1,
#     'livingArea': 594,
#     'country': 'USA',
#     'currency': 'USD',
#     'lotAreaUnit': None,
#     'hasImage': True}],
#   'resultsPerPage': 41,
#   'totalPages': 20,
#   'totalResultCount': 2303,
#   'schools': {},
#   'currentPage': 20}}

# %%
combined_data.keys()
# Out:
# dict_keys(['Page 1', 'Page 2', 'Page 3', 'Page 4', 'Page 5', 'Page 6', 'Page 7', 'Page 8', 'Page 9', 'Page 10', 'Page 11', 'Page 12', 'Page 13', 'Page 14', 'Page 15', 'Page 16', 'Page 17', 'Page 18', 'Page 19', 'Page 20'])

# %%
column_names = []
for i in range(total_number_of_pages):
    for prop in combined_data["Page " + str(i + 1)]["props"]:
        for key in prop.keys():
            if key not in column_names:  # Check if the key is not already in the list
                column_names.append(key)

# Rearrange column ordering
last_element = column_names.pop(10)
column_names.insert(3,last_element)

last_element = column_names.pop()
column_names.insert(15,last_element)

#Insert to GeoLocation feature
column_names.insert(4,"GeoLocation")

column_names
# Out:
# ['listingStatus',
#  'zpid',
#  'longitude',
#  'latitude',
#  'GeoLocation',
#  'buildingName',
#  'address',
#  'detailUrl',
#  'isBuilding',
#  'hasImage',
#  'lotId',
#  'imgSrc',
#  'unit_0_bedroom',
#  'unit_1_bedroom',
#  'unit_2_bedroom',
#  'unit_3_bedroom',
#  'unit_4_bedroom',
#  'dateSold',
#  'propertyType',
#  'lotAreaValue',
#  'variableData',
#  'zestimate',
#  'price',
#  'bedrooms',
#  'contingentListingType',
#  'listingSubType',
#  'rentZestimate',
#  'daysOnZillow',
#  'bathrooms',
#  'livingArea',
#  'country',
#  'currency',
#  'lotAreaUnit',
#  'unit']

# %%
import pandas as pd
df = pd.DataFrame(columns=column_names, dtype= str)

rows = []

for i in range(total_number_of_pages):
    for prop in combined_data["Page " + str(i + 1)]["props"]:
        rows_dict = {}
        for key, value in prop.items():
            rows_dict[key] = str(value)
        rows.append(rows_dict)
    
df = pd.DataFrame(rows)
pd.set_option('display.max_columns', None)

#Reposition unit_4_bedroom
last_column_name = df.columns[-1]
last_column_values = df.pop(last_column_name)
df.insert(15, last_column_name, last_column_values)

#Reposition longitude
last_column_name = df.columns[10]
last_column_values = df.pop(last_column_name)
df.insert(3, last_column_name, last_column_values)

df.insert(2,"GeoLocation", [f"{longitude}, {latitude}" for longitude, latitude in zip(df["longitude"], df["latitude"])])
df
# Out:
#     listingStatus                  zpid            GeoLocation   longitude  \
# 0        FOR_RENT    39.28158--76.61414    -76.61414, 39.28158   -76.61414
# 1        FOR_RENT  39.288685--76.620094  -76.620094, 39.288685  -76.620094
# 2        FOR_RENT    39.335617--76.6207    -76.6207, 39.335617    -76.6207
# 3        FOR_RENT   39.292084--76.61599   -76.61599, 39.292084   -76.61599
# 4        FOR_RENT   39.377323--76.66296   -76.66296, 39.377323   -76.66296
# ..            ...                   ...                    ...         ...
# 815      FOR_RENT            2057188609   -76.70322, 39.337494   -76.70322
# 816      FOR_RENT            2057188611   -76.70252, 39.337917   -76.70252
# 817      FOR_RENT            2057188612  -76.679344, 39.326138  -76.679344
# 818      FOR_RENT    39.3383--76.702324    -76.702324, 39.3383  -76.702324
# 819      FOR_RENT            2085611523   -76.67868, 39.292385   -76.67868
#
#       latitude                             buildingName  \
# 0     39.28158                      Arrive Federal Hill
# 1    39.288685                    Redwood Campus Center
# 2    39.335617                     Broadview Apartments
# 3    39.292084          The Apartments at Charles Plaza
# 4    39.377323        Copper Village and Quarry Village
# ..         ...                                      ...
# 815  39.337494                                      NaN
# 816  39.337917                                      NaN
# 817  39.326138                                      NaN
# 818    39.3383  Cadillac Apartments (5527 Cadillac Ave)
# 819  39.292385                                      NaN
#
#                                                address  \
# 0                      611 S Charles St, Baltimore, MD
# 1                      300 W Redwood St, Baltimore, MD
# 2                         105 W 39th St, Baltimore, MD
# 3                      222 N Charles St, Baltimore, MD
# 4                  6617 Bonnie Ridge Dr, Baltimore, MD
# ..                                                 ...
# 815  Haddon Hill Apartments (5512 -5514 Haddon Ave)...
# 816  Garden Style Apartment in Gwynn Oak/Seton Neig...
# 817  Liberty Heights Apartments (3701 Liberty Heigh...
# 818                   5527 Cadillac Ave, Gwynn Oak, MD
# 819         3707 W Franklin St #2, Baltimore, MD 21229
#
#                                              detailUrl isBuilding hasImage  \
# 0    /apartments/baltimore-md/arrive-federal-hill/9...       True     True
# 1    /apartments/baltimore-md/redwood-campus-center...       True     True
# 2    /apartments/baltimore-md/broadview-apartments/...       True     True
# 3    /apartments/baltimore-md/the-apartments-at-cha...       True     True
# 4    /apartments/pikesville-md/copper-village-and-q...       True     True
# ..                                                 ...        ...      ...
# 815  /b/haddon-hill-apartments-%285512-5514-haddon-...        NaN     True
# 816  /b/garden-style-apartment-in-gwynn-oak-seton-n...        NaN     True
# 817  /b/liberty-heights-apartments-%283701-liberty-...        NaN     True
# 818  /b/cadillac-apartments-%285527-cadillac-ave%29...       True     True
# 819  /homedetails/3707-W-Franklin-St-2-Baltimore-MD...        NaN     True
#
#           lotId                                             imgSrc  \
# 0    2090543288  https://photos.zillowstatic.com/fp/56d7660181c...
# 1    2532871615  https://photos.zillowstatic.com/fp/4944c97ead4...
# 2    1001416599  https://photos.zillowstatic.com/fp/078d5b0a63b...
# 3    1001416928  https://photos.zillowstatic.com/fp/759d2919183...
# 4    1001416668  https://photos.zillowstatic.com/fp/4c51f468da9...
# ..          ...                                                ...
# 815         NaN  https://photos.zillowstatic.com/fp/41d3e934a90...
# 816         NaN  https://photos.zillowstatic.com/fp/800ce84f7be...
# 817         NaN  https://photos.zillowstatic.com/fp/b02dfaf922e...
# 818  1137512747  https://photos.zillowstatic.com/fp/20f9ed637ad...
# 819         NaN  https://photos.zillowstatic.com/fp/ee733c715a8...
#
#     unit_0_bedroom unit_1_bedroom unit_2_bedroom unit_3_bedroom  \
# 0          $1,765+        $1,685+        $2,424+            NaN
# 1          $1,500+        $1,795+            NaN            NaN
# 2          $1,270+        $1,540+        $2,750+            NaN
# 3          $1,068+        $1,170+        $1,506+            NaN
# 4              NaN        $1,192+        $1,358+        $1,748+
# ..             ...            ...            ...            ...
# 815            NaN            NaN            NaN            NaN
# 816            NaN            NaN            NaN            NaN
# 817            NaN            NaN            NaN            NaN
# 818            NaN            NaN          $975+            NaN
# 819            NaN            NaN            NaN            NaN
#
#     unit_4_bedroom dateSold   propertyType lotAreaValue variableData  \
# 0              NaN      NaN            NaN          NaN          NaN
# 1              NaN      NaN            NaN          NaN          NaN
# 2              NaN      NaN            NaN          NaN          NaN
# 3              NaN      NaN            NaN          NaN          NaN
# 4              NaN      NaN            NaN          NaN          NaN
# ..             ...      ...            ...          ...          ...
# 815            NaN     None      APARTMENT         None         None
# 816            NaN     None      APARTMENT         None         None
# 817            NaN     None      APARTMENT         None         None
# 818            NaN      NaN            NaN          NaN          NaN
# 819            NaN     None  SINGLE_FAMILY         None         None
#
#     zestimate price bedrooms contingentListingType listingSubType  \
# 0         NaN   NaN      NaN                   NaN            NaN
# 1         NaN   NaN      NaN                   NaN            NaN
# 2         NaN   NaN      NaN                   NaN            NaN
# 3         NaN   NaN      NaN                   NaN            NaN
# 4         NaN   NaN      NaN                   NaN            NaN
# ..        ...   ...      ...                   ...            ...
# 815      None   995        2                  None             {}
# 816      None   975        2                  None             {}
# 817      None   995        2                  None             {}
# 818       NaN   NaN      NaN                   NaN            NaN
# 819      None   990        2                  None             {}
#
#     rentZestimate daysOnZillow bathrooms livingArea country currency  \
# 0             NaN          NaN       NaN        NaN     NaN      NaN
# 1             NaN          NaN       NaN        NaN     NaN      NaN
# 2             NaN          NaN       NaN        NaN     NaN      NaN
# 3             NaN          NaN       NaN        NaN     NaN      NaN
# 4             NaN          NaN       NaN        NaN     NaN      NaN
# ..            ...          ...       ...        ...     ...      ...
# 815          1175            1         1        800     USA      USD
# 816          1019            1         1       None     USA      USD
# 817          1132            1         1        800     USA      USD
# 818           NaN          NaN       NaN        NaN     NaN      NaN
# 819           999            1         1        594     USA      USD
#
#     lotAreaUnit    unit
# 0           NaN     NaN
# 1           NaN     NaN
# 2           NaN     NaN
# 3           NaN     NaN
# 4           NaN     NaN
# ..          ...     ...
# 815        None  Apt T1
# 816        None     # 6
# 817        None    # B2
# 818         NaN     NaN
# 819        None     # 2
#
# [820 rows x 34 columns]

# %%
df.to_csv('D:/dataSets/property_data_extended.csv', index=False)

# %%
file = open("C:/Users/seanl/Datasets/sample2.json")

json.load(file)
# Out:
# {'firstName': 'Joe',
#  'lastName': 'Jackson',
#  'gender': 'male',
#  'age': 28,
#  'address': {'streetAddress': '101', 'city': 'San Diego', 'state': 'CA'},
#  'phoneNumbers': [{'type': 'home', 'number': '7349282382'}]}

# %%
file = open("C:/Users/seanl/Datasets/sample2.json")

json.load(file)

file2 = open("C:/Users/seanl/Datasets/sample1.json")

data = json.load(file2)
# Use json.dumps with an indentation parameter to format the JSON data
formatted_json = json.dumps(data, indent=3)

print(formatted_json)
# Out:
# {
#    "fruit": "Apple",
#    "size": "Large",
#    "color": "Red"
# }

# %%
import json

# Open and load the first JSON file
file_path1 = "C:/Users/seanl/Datasets/sample2.json"
with open(file_path1, 'r') as file1:
    data1 = json.load(file1)

# Create an empty dictionary
combined_data = {}

# Add the data from the first JSON file twice
combined_data[0] = data1
combined_data[1] = data1

# Use json.dumps with an indentation parameter to format the combined JSON data
formatted_json = json.dumps(combined_data, indent=3)

print(formatted_json)
# Out:
# {
#    "0": {
#       "firstName": "Joe",
#       "lastName": "Jackson",
#       "gender": "male",
#       "age": 28,
#       "address": {
#          "streetAddress": "101",
#          "city": "San Diego",
#          "state": "CA"
#       },
#       "phoneNumbers": [
#          {
#             "type": "home",
#             "number": "7349282382"
#          }
#       ]
#    },
#    "1": {
#       "firstName": "Joe",
#       "lastName": "Jackson",
#       "gender": "male",
#       "age": 28,
#       "address": {
#          "streetAddress": "101",
#          "city": "San Diego",
#          "state": "CA"
#       },
#       "phoneNumbers": [
#          {
#             "type": "home",
#             "number": "7349282382"
#          }
#       ]
#    }
# }
