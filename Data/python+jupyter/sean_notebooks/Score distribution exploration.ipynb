# %%
import pandas as pd

# %%
services_z_scores = pd.read_csv("D:/DataSets/DatabaseTables/neighbourhoodZScores.csv")

# %%
import matplotlib.pyplot as plt

df = services_z_scores.copy()
# Select only the columns with "Count" in their name
count_columns = [col for col in df.columns if 'Count' in col]

# Select the first row of data
row_data = df.loc[0, count_columns]


# Sort the values from high to low
row_data_sorted = row_data.sort_values(ascending=False)

# Plotting the bar chart
row_data_sorted.plot(kind='bar')
plt.title('Counts for the First Row (Sorted)')
plt.xlabel('Categories')
plt.ylabel('Count')
plt.show()

# %%
import matplotlib.pyplot as plt

df = services_z_scores.copy()
# Select only the columns with "Count" in their name
count_columns = [col for col in df.columns if 'Count' in col]

# Select the first row of data
row_data = df.loc[1, count_columns]


# Sort the values from high to low
row_data_sorted = row_data.sort_values(ascending=False)

# Plotting the bar chart
row_data_sorted.plot(kind='bar')
plt.title('Counts for the First Row (Sorted)')
plt.xlabel('Categories')
plt.ylabel('Count')
plt.show()

# %%
import matplotlib.pyplot as plt

df = services_z_scores.copy()
# Select only the columns with "Count" in their name
count_columns = [col for col in df.columns if 'Count' in col]

# Select the first row of data
row_data = df.loc[2, count_columns]


# Sort the values from high to low
row_data_sorted = row_data.sort_values(ascending=False)

# Plotting the bar chart
row_data_sorted.plot(kind='bar')
plt.title('Counts for the First Row (Sorted)')
plt.xlabel('Categories')
plt.ylabel('Count')
plt.show()

# %%
import matplotlib.pyplot as plt

df = services_z_scores.copy()
# Select only the columns with "Count" in their name
count_columns = [col for col in df.columns if 'Count' in col]

# Select the first row of data
row_data = df.loc[3, count_columns]


# Sort the values from high to low
row_data_sorted = row_data.sort_values(ascending=False)

# Plotting the bar chart
row_data_sorted.plot(kind='bar')
plt.title('Counts for the First Row (Sorted)')
plt.xlabel('Categories')
plt.ylabel('Count')
plt.show()

# %%
import matplotlib.pyplot as plt

df = services_z_scores.copy()
# Select only the columns with "Count" in their name
count_columns = [col for col in df.columns if 'Count' in col]

# Select the first row of data
row_data = df.loc[4, count_columns]


# Sort the values from high to low
row_data_sorted = row_data.sort_values(ascending=False)

# Plotting the bar chart
row_data_sorted.plot(kind='bar')
plt.title('Counts for the First Row (Sorted)')
plt.xlabel('Categories')
plt.ylabel('Count')
plt.show()

# %%
import matplotlib.pyplot as plt

df = services_z_scores.copy()

# Select only the columns with "Count" in their name
count_columns = [col for col in df.columns if 'Count' in col]

# Sum the counts for each category (column)
category_totals = df[count_columns].sum()

# Sort the values from high to low
category_totals_sorted = category_totals.sort_values(ascending=False)

# Plotting the bar chart
category_totals_sorted.plot(kind='bar')
plt.title('Total Counts for Each Category (Sorted)')
plt.xlabel('Categories')
plt.ylabel('Total Count')
plt.show()

# %%
category_totals_sorted
# Out:
# transit_stationCount    4668
# restaurantCount         3676
# parkCount               2583
# barCount                2041
# beauty_salonCount       2041
# cafeCount               1425
# pharmacyCount           1349
# hospitalCount           1128
# gymCount                 738
# bankCount                684
# night_clubCount          467
# supermarketCount         299
# fire_stationCount        198
# bus_stationCount         129
# police_stationCount      123
# train_stationCount        22
# dtype: int64

# %%
weights2 = pd.read_csv("D:/datasets/DatabaseTables/weights2.csv")

# %%
import matplotlib.pyplot as plt
import numpy as np

# Sigmoid mapping function
def sigmoid_mapping(x, mean, scale):
    return 1 + 4 / (1 + np.exp(-1.75 * (x - mean) / scale))

# Calculate mean and standard deviation
mean_value = weights2['sum_z_scores'].mean()
scale_value = weights2['sum_z_scores'].std()

# Apply the sigmoid mapping0.05
weights2['mapped_values_sigmoid'] = sigmoid_mapping(weights2['sum_z_scores'], mean_value, scale_value)

# Set a larger figure size
plt.figure(figsize=(12, 8))

# Plotting the sigmoid function
x_values = np.linspace(weights2['sum_z_scores'].min(), weights2['sum_z_scores'].max(), 100)
y_values = sigmoid_mapping(x_values, mean_value, scale_value)

plt.plot(x_values, y_values, color='purple', label='Sigmoid Mapping')

# Plotting vertical lines
for index, row in weights2.iterrows():
    plt.plot([row['sum_z_scores'], row['sum_z_scores']], [0, row['mapped_values_sigmoid']], linestyle='dashed', color='orange')

# Plotting mean line
plt.axvline(x=mean_value, color='green', linestyle='dashed', label='Mean')

plt.scatter(weights2['sum_z_scores'], weights2['mapped_values_sigmoid'], color='red', label='Original Z Scores')
plt.xlabel('Original summed Z Scores for each neighbourhood')
plt.ylabel('Mapped Values for each neighbourhood')
plt.legend()
plt.title('Sigmoid Mapping of Z Scores with Mean Line')
plt.grid(True)
plt.show()
